# %%
import pandas as pd
from tqdm import tqdm
import scanpy as sc
import os
import shutil

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import mvtcr.utils_training as utils
import config.constants_10x as const
from sklearn.metrics import f1_score, classification_report

# from mvtcr.utils_preprocessing import stratified_group_shuffle_split, group_shuffle_split
from mvtcr.evaluation.Imputation import run_imputation_evaluation
from mvtcr.evaluation.Clustering import run_clustering_evaluation
from mvtcr.evaluation.kNN import run_knn_within_set_evaluation
from mvtcr.evaluation.WrapperFunctions import get_model_prediction_function

# %% [markdown]
# # 10x

# %%
model_path = './saved_models/Lee_EAE/DE2500_epoch200'
def load_model(adata, dataset, split, model, donor):
    path_model = model_path+'/trial_0/best_model_by_metric.pt'
    model = utils.load_model(adata, path_model)
    return model

# %%
data_path = r"E:\Python code\Machine learning\JupyterNote\Bio_CRC\Data\EAE\GSE188320\\"

def load_10x_data(donor, split, size=False):
    adata = sc.read_h5ad(data_path + 'p1_preprocessed.h5ad')

    # adata = utils.load_data('10x')
    # if donor is not 'None':
    #     adata = adata[adata.obs['donor'] == f'donor_{donor}']
    # adata = adata[adata.obs['binding_name'].isin(const.HIGH_COUNT_ANTIGENS)]
    
    
    # # subsample to get statistics
    # random_seed = split
    # train_val, test = group_shuffle_split(adata, group_col='clonotype', val_split=0.20, random_seed=random_seed)
    # train, val = group_shuffle_split(train_val, group_col='clonotype', val_split=0.25, random_seed=random_seed)
    
    # adata.obs['binding_label'] = adata.obs['binding_name'].map(adata.uns['specificity_to_label']).astype(int)
    # adata.obs['set'] = 'train'
    # adata.obs.loc[val.obs.index, 'set'] = 'val'
    # adata.obs.loc[test.obs.index, 'set'] = 'test'

    return adata

# %% [markdown]
# ## 10x Specificity

# %%
dataset = '10x'

model_names = []
splits = []
metrics = []
scores = []
donors = []

for donor in tqdm(['1', '2', '3', '4', 'None'], 'donor'):
	for split in tqdm(range(5), 'split'):
		data = load_10x_data(donor, split)

		model = load_model(data, '10x', split, 'supervised', donor)

		model.model = model.model.to('cuda')
		model.supervised_model = model.supervised_model.to(model.device)
		model.model.eval()
		model.supervised_model.eval()

		for source in ['test']:
			data_sub = data[data.obs['set'] == source]

			y_true = data_sub.obs['binding_name'].map(data.uns['specificity_to_label'])

			y_pred = model.predict_label(data_sub, use_mean=True)

			sv_score = classification_report(y_true, y_pred.argmax(1).detach().cpu(), output_dict=True)
			sv_score = sv_score['weighted avg']['f1-score']
            
			model_names.append('mvTCR supervised')
			splits.append(split)
			metrics.append(f'Prediction {source}')
			scores.append(sv_score)
			donors.append(donor)

			test_embedding_func = get_model_prediction_function(model)
			summary = run_imputation_evaluation(data, test_embedding_func, query_source=source,
												label_pred='binding_name')
			knn_score = summary['knn']['weighted avg']['f1-score']

			model_names.append('mvTCR supervised + kNN')
			splits.append(split)
			metrics.append(f'Prediction {source}')
			scores.append(knn_score)
			donors.append(donor)

			best_nmi = -99
			for resolution in [0.01, 0.1, 1.0]:
				cluster_result = run_clustering_evaluation(data, test_embedding_func, 'train',
														   name_label='binding_name',
														   cluster_params={'resolution': resolution,
																		   'num_neighbors': 5})
				best_nmi = max(cluster_result['NMI'], best_nmi)
			model_names.append('mvTCR supervised')
			splits.append(split)
			metrics.append('NMI')
			scores.append(best_nmi)  
			donors.append(donor)

results_10x = {
    'model': model_names,
    'split': splits,
    'metric': metrics,
    'score': scores,
    'donor': donors,
    'dataset': [dataset] * len(splits)
}
results_10x = pd.DataFrame(results_10x)
results_10x.to_csv(f'../results/performance_10x_supervised.csv')
# Out:
# split:   0%|          | 0/5 [00:07<?, ?it/s]
# donor:   0%|          | 0/5 [00:07<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 13
#      10 for split in tqdm(range(5), 'split'):
#      11 	data = load_10x_data(donor, split)
# ---> 13 	model = load_model(data, '10x', split, 'supervised', donor)
#      15 	model.model = model.model.to('cuda')
#      16 	model.supervised_model = model.supervised_model.to(model.device)
#
# Cell In[8], line 4, in load_model(adata, dataset, split, model, donor)
#       2 def load_model(adata, dataset, split, model, donor):
#       3     path_model = model_path+'/trial_0/best_model_by_metric.pt'
# ----> 4     model = utils.load_model(adata, path_model)
#       5     return model
#
# File e:\Python code\Machine learning\JupyterNote\Bio_CRC\mvTCR\mvTCR\mvtcr\utils_preprocessing.py:111, in check_if_input_is_mudata.<locals>.wrapper(mudata_gex_key, mudata_airr_key, *args, **kwargs)
#     108 #actual function call
#     109 #====================
#     110 if func_name in ("get_latent", "load_model", "check_if_valid_adata"):
# --> 111 	result = func(*args, **kwargs)
#     112 elif func_name in ("group_shuffle_split", "stratified_group_shuffle_split"):
#     113 	train, test = func(*args, **kwargs)
#
# File e:\Python code\Machine learning\JupyterNote\Bio_CRC\mvTCR\mvTCR\mvtcr\utils_training.py:86, in load_model(adata, path_model)
#      82 model = model_class(adata, params_architecture, balanced_sampling, metadata, conditional,
#      83                     optimization_mode_params, label_key)
#      85 if available_gpu:
# ---> 86     model.load(path_model)
#      87 else:
#      88     model.load(path_model, map_location=torch.device('cpu'))
#
# File e:\Python code\Machine learning\JupyterNote\Bio_CRC\mvTCR\mvTCR\mvtcr\models\vae_base_model.py:542, in VAEBaseModel.load(self, filepath, map_location)
#     540 """ Load model for evaluation / inference"""
#     541 model_file = torch.load(os.path.join(filepath), map_location=map_location)
# --> 542 self.model.load_state_dict(model_file['state_dict'], strict=False)
#     543 if 'supervised_model' in model_file:
#     544 	self.supervised_model.load_state_dict(model_file['supervised_model'], strict=True)
#
# File e:\Anaconda\envs\mvTCR\lib\site-packages\torch\nn\modules\module.py:2584, in Module.load_state_dict(self, state_dict, strict, assign)
#    2576         error_msgs.insert(
#    2577             0,
#    2578             "Missing key(s) in state_dict: {}. ".format(
#    2579                 ", ".join(f'"{k}"' for k in missing_keys)
#    2580             ),
#    2581         )
#    2583 if len(error_msgs) > 0:
# -> 2584     raise RuntimeError(
#    2585         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2586             self.__class__.__name__, "\n\t".join(error_msgs)
#    2587         )
#    2588     )
#    2589 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for MoEModelTorch:
# 	size mismatch for alpha_encoder.positional_encoding.pe: copying a param with shape torch.Size([21, 1, 16]) from checkpoint, the shape in current model is torch.Size([26, 1, 16]).
# 	size mismatch for alpha_encoder.fc_reduction.weight: copying a param with shape torch.Size([100, 336]) from checkpoint, the shape in current model is torch.Size([100, 416]).
# 	size mismatch for alpha_decoder.fc_upsample.weight: copying a param with shape torch.Size([336, 200]) from checkpoint, the shape in current model is torch.Size([416, 200]).
# 	size mismatch for alpha_decoder.fc_upsample.bias: copying a param with shape torch.Size([336]) from checkpoint, the shape in current model is torch.Size([416]).
# 	size mismatch for alpha_decoder.positional_encoding.pe: copying a param with shape torch.Size([21, 1, 16]) from checkpoint, the shape in current model is torch.Size([26, 1, 16]).
# 	size mismatch for beta_encoder.positional_encoding.pe: copying a param with shape torch.Size([21, 1, 16]) from checkpoint, the shape in current model is torch.Size([26, 1, 16]).
# 	size mismatch for beta_encoder.fc_reduction.weight: copying a param with shape torch.Size([100, 336]) from checkpoint, the shape in current model is torch.Size([100, 416]).
# 	size mismatch for beta_decoder.fc_upsample.weight: copying a param with shape torch.Size([336, 200]) from checkpoint, the shape in current model is torch.Size([416, 200]).
# 	size mismatch for beta_decoder.fc_upsample.bias: copying a param with shape torch.Size([336]) from checkpoint, the shape in current model is torch.Size([416]).
# 	size mismatch for beta_decoder.positional_encoding.pe: copying a param with shape torch.Size([21, 1, 16]) from checkpoint, the shape in current model is torch.Size([26, 1, 16]).

# %%
results_10x.groupby(['model', 'donor', 'metric']).mean()
# Out:
#                                               split     score
# model                  donor metric
# mvTCR supervised       1     NMI                  2  0.629854
#                              Prediction test      2  0.433624
#                        2     NMI                  2  0.541553
#                              Prediction test      2  0.619305
#                        3     NMI                  2  0.052228
#                              Prediction test      2  0.502285
#                        4     NMI                  2  0.633032
#                              Prediction test      2  0.281554
#                        None  NMI                  2  0.609132
#                              Prediction test      2  0.511023
# mvTCR supervised + kNN 1     Prediction test      2  0.634888
#                        2     Prediction test      2  0.862995
#                        3     Prediction test      2  0.894674
#                        4     Prediction test      2  0.766906
#                        None  Prediction test      2  0.838415

# %% [markdown]
# # Minervina Tests

# %%
def load_minervina_model(adata, dataset, split, model):
    path_model = f'../mvTCR/saved_models/journal_2/minervina/splits/{model}/minervina_donor_split_{split}_{model}.pt'
    model = utils.load_model(adata, path_model)
    return model

# %%
from sklearn.preprocessing import OneHotEncoder

def load_minervina_data(split, size=False):
    adata = utils.load_data('minervina/01_annotated_data.h5ad')
    adata.obs['epitope_label'] = adata.obs['epitope'].factorize()[0]

    # subsample to get statistics
    random_seed = split
    train_val, test = group_shuffle_split(adata, group_col='clonotype', val_split=0.20, random_seed=random_seed)
    train, val = group_shuffle_split(train_val, group_col='clonotype', val_split=0.25, random_seed=random_seed)
    
    if size:
        sc.pp.subsample(train, n_obs=size)
            
    adata.obs['set'] = None
    adata.obs.loc[train.obs.index, 'set'] = 'train'
    adata.obs.loc[val.obs.index, 'set'] = 'val'
    adata.obs.loc[test.obs.index, 'set'] = 'test'

    return adata

# %%
dataset = 'minervina'

model_names = []
splits = []
metrics = []
scores = []
donors = []

for donor in tqdm(['None'], 'donor'):
	for split in tqdm(range(5), 'split'):
		data = load_minervina_data(split)
		model = load_minervina_model(data, 'minervina', split, 'supervised')

		model.model = model.model.to('cuda')
		model.supervised_model = model.supervised_model.to(model.device)
		model.model.eval()
		model.supervised_model.eval()

		for source in ['test']:
			data_sub = data[data.obs['set'] == source]

			y_true = data_sub.obs['epitope_label']

			y_pred = model.predict_label(data_sub, use_mean=True)

			sv_score = classification_report(y_true, y_pred.argmax(1).detach().cpu(), output_dict=True)
			sv_score = sv_score['weighted avg']['f1-score']

			model_names.append('mvTCR supervised')
			splits.append(split)
			metrics.append(f'Prediction {source}')
			scores.append(sv_score)
			donors.append(donor)

			test_embedding_func = get_model_prediction_function(model)
			summary = run_imputation_evaluation(data, test_embedding_func, query_source=source,
												label_pred='epitope_label')
			knn_score = summary['knn']['weighted avg']['f1-score']

			model_names.append('mvTCR supervised + kNN')
			splits.append(split)
			metrics.append(f'Prediction {source}')
			scores.append(knn_score)
			donors.append(donor)

			best_nmi = -99
			for resolution in [0.01, 0.1, 1.0]:
				cluster_result = run_clustering_evaluation(data, test_embedding_func, 'train',
														   name_label='epitope_label',
														   cluster_params={'resolution': resolution,
																		   'num_neighbors': 5})
				best_nmi = max(cluster_result['NMI'], best_nmi)
			model_names.append('mvTCR supervised')
			splits.append(split)
			metrics.append('NMI')
			scores.append(best_nmi)
			donors.append(donor)

results_min = {
    'model': model_names,
    'split': splits,
    'metric': metrics,
    'score': scores,
    'donor': donors,
    'dataset': [dataset] * len(splits)
}
results_min = pd.DataFrame(results_min)
results_min.to_csv(f'../results/performance_minervina_supervised.csv')
# Out:
# donor:   0%|                                                                                                                                                                                                                                                      | 0/1 [00:00<?, ?it/s]
# split:   0%|                                                                                                                                                                                                                                                      | 0/5 [00:00<?, ?it/s]
# split:  20%|███████████████████████████████████████████████▌                                                                                                                                                                                              | 1/5 [00:08<00:34,  8.52s/it]
# split:  40%|███████████████████████████████████████████████████████████████████████████████████████████████▏                                                                                                                                              | 2/5 [00:16<00:23,  7.92s/it]
# split:  60%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                                                               | 3/5 [00:22<00:14,  7.30s/it]
# split:  80%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                               | 4/5 [00:30<00:07,  7.50s/it]
# split: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:37<00:00,  7.43s/it]
# donor: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:37<00:00, 37.18s/it]

# %%
results_min.groupby(['model', 'metric']).mean()
# Out:
#                                         split     score
# model                  metric
# mvTCR supervised       NMI                  2  0.720579
#                        Prediction test      2  0.782709
# mvTCR supervised + kNN Prediction test      2  0.829400
