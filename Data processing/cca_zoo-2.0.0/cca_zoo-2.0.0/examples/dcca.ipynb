# %%
"""
Deep CCA
===========================

This example demonstrates how to easily train Deep CCA models and variants
"""

import pytorch_lightning as pl
from matplotlib import pyplot as plt

# %%
import cca_zoo
print(cca_zoo.__file__)
# Out:
# To use iterative methods please install pytorch-lightning from version 2.0.0
# e:\Anaconda\envs\bio\Lib\site-packages\cca_zoo\__init__.py

# %%
# %%
from cca_zoo.deepmodels import (
    DCCA,
    DCCA_EY,
    DCCA_NOI,
    DCCA_SDL,
    BarlowTwins,
    architectures,
)
from cca_zoo.plotting import plot_pairwise_correlations

# %%
from __init__ import example_mnist_data

# %%
# %%
# Data
# -----
LATENT_DIMS = 2
EPOCHS = 10
N_TRAIN = 500
N_VAL = 100

train_loader, val_loader, train_labels = example_mnist_data(N_TRAIN, N_VAL)

encoder_1 = architectures.Encoder(latent_dims=LATENT_DIMS, feature_size=392)
encoder_2 = architectures.Encoder(latent_dims=LATENT_DIMS, feature_size=392)

# %%
# Deep CCA
# ----------------------------
dcca = DCCA(latent_dims=LATENT_DIMS, encoders=[encoder_1, encoder_2])
trainer = pl.Trainer(
    max_epochs=EPOCHS,
    enable_checkpointing=False,
    log_every_n_steps=1,
)
trainer.fit(dcca, train_loader, val_loader)
plot_pairwise_correlations(dcca.transform(train_loader), train_labels, title="DCCA")
plt.show()

# %%
# Deep CCA EigenGame
# ----------------------------
dcca_eg = DCCA_EY(latent_dims=LATENT_DIMS, encoders=[encoder_1, encoder_2], lr=1e-5)
trainer = pl.Trainer(
    max_epochs=EPOCHS,
    enable_checkpointing=False,
    log_every_n_steps=1,
)
trainer.fit(dcca_eg, train_loader, val_loader)
plot_pairwise_correlations(dcca_eg.transform(train_loader), train_labels, title="DCCA-EigenGame")
plt.show()

# %%
# Deep CCA by Non-Linear Orthogonal Iterations
# ----------------------------------------------
dcca_noi = DCCA_NOI(latent_dims=LATENT_DIMS, N=N_TRAIN, encoders=[encoder_1, encoder_2])
trainer = pl.Trainer(
    max_epochs=EPOCHS,
    enable_checkpointing=False,
    log_every_n_steps=1,
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name     | Type       | Params | Mode  | FLOPs
# --------------------------------------------------------
# 0 | encoders | ModuleList | 101 K  | train | 0
# --------------------------------------------------------
# 101 K     Trainable params
# 0         Non-trainable params
# 101 K     Total params
# 0.404     Total estimated model params size (MB)
# 17        Modules in train mode
# 1         Modules in eval mode
# 0         Total Flops
# Sanity Checking DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 103.08it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 23
#      17 dcca = DCCA(latent_dims=LATENT_DIMS, encoders=[encoder_1, encoder_2])
#      18 trainer = pl.Trainer(
#      19     max_epochs=EPOCHS,
#      20     enable_checkpointing=False,
#      21     log_every_n_steps=1,
#      22 )
# ---> 23 trainer.fit(dcca, train_loader, val_loader)
#      24 plot_pairwise_correlations(dcca.transform(train_loader), train_labels, title="DCCA")
#      25 plt.show()
#
# File e:\Anaconda\envs\bio\Lib\site-packages\pytorch_lightning\trainer\trainer.py:584, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path, weights_only)
#     582 self.training = True
#     583 self.should_stop = False
# --> 584 call._call_and_handle_interrupt(
#     585     self,
#     586     self._fit_impl,
#     587     model,
#     588     train_dataloaders,
#     589     val_dataloaders,
#     590     datamodule,
#     591     ckpt_path,
#     592     weights_only,
#     593 )
#
# File e:\Anaconda\envs\bio\Lib\site-packages\pytorch_lightning\trainer\call.py:49, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      47     if trainer.strategy.launcher is not None:
#      48         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 49     return trainer_fn(*args, **kwargs)
#      51 except _TunerExitException:
#      52     _call_teardown_hook(trainer)
#
# File e:\Anaconda\envs\bio\Lib\site-packages\pytorch_lightning\trainer\trainer.py:630, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path, weights_only)
#     623     download_model_from_registry(ckpt_path, self)
#     624 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     625     self.state.fn,
#     626     ckpt_path,
#     627     model_provided=True,
#     628     model_connected=self.lightning_module is not None,
#     629 )
# --> 630 self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#     632 assert self.state.stopped
#     633 self.training = False
#
# File e:\Anaconda\envs\bio\Lib\site-packages\pytorch_lightning\trainer\trainer.py:1079, in Trainer._run(self, model, ckpt_path, weights_only)
#    1074 self._signal_connector.register_signal_handlers()
#    1076 # ----------------------------
#    1077 # RUN THE TRAINER
#    1078 # ----------------------------
# -> 1079 results = self._run_stage()
#    1081 # ----------------------------
#    1082 # POST-Training CLEAN UP
#    1083 # ----------------------------
#    1084 log.debug(f"{self.__class__.__name__}: trainer tearing down")
#
# File e:\Anaconda\envs\bio\Lib\site-packages\pytorch_lightning\trainer\trainer.py:1121, in Trainer._run_stage(self)
#    1119 if self.training:
#    1120     with isolate_rng():
# -> 1121         self._run_sanity_check()
#    1122     with torch.autograd.set_detect_anomaly(self._detect_anomaly):
#    1123         self.fit_loop.run()
#
# File e:\Anaconda\envs\bio\Lib\site-packages\pytorch_lightning\trainer\trainer.py:1150, in Trainer._run_sanity_check(self)
#    1147 call._call_callback_hooks(self, "on_sanity_check_start")
#    1149 # run eval step
# -> 1150 val_loop.run()
#    1152 call._call_callback_hooks(self, "on_sanity_check_end")
#    1154 # reset logger connector
#
# File e:\Anaconda\envs\bio\Lib\site-packages\pytorch_lightning\loops\utilities.py:179, in _no_grad_context.<locals>._decorator(self, *args, **kwargs)
#     177     context_manager = torch.no_grad
#     178 with context_manager():
# --> 179     return loop_run(self, *args, **kwargs)
#
# File e:\Anaconda\envs\bio\Lib\site-packages\pytorch_lightning\loops\evaluation_loop.py:153, in _EvaluationLoop.run(self)
#     151         self.on_iteration_done()
#     152 self._store_dataloader_outputs()
# --> 153 return self.on_run_end()
#
# File e:\Anaconda\envs\bio\Lib\site-packages\pytorch_lightning\loops\evaluation_loop.py:296, in _EvaluationLoop.on_run_end(self)
#     293 self.trainer._logger_connector._evaluation_epoch_end()
#     295 # hook
# --> 296 self._on_evaluation_epoch_end()
#     298 logged_outputs, self._logged_outputs = self._logged_outputs, []  # free memory
#     299 # include any logged outputs on epoch_end
#
# File e:\Anaconda\envs\bio\Lib\site-packages\pytorch_lightning\loops\evaluation_loop.py:378, in _EvaluationLoop._on_evaluation_epoch_end(self)
#     375 trainer = self.trainer
#     377 hook_name = "on_test_epoch_end" if trainer.testing else "on_validation_epoch_end"
# --> 378 call._call_callback_hooks(trainer, hook_name)
#     379 call._call_lightning_module_hook(trainer, hook_name)
#     381 trainer._logger_connector.on_epoch_end()
#
# File e:\Anaconda\envs\bio\Lib\site-packages\pytorch_lightning\trainer\call.py:228, in _call_callback_hooks(trainer, hook_name, monitoring_callbacks, *args, **kwargs)
#     226     if callable(fn):
#     227         with trainer.profiler.profile(f"[Callback]{callback.state_key}.{hook_name}"):
# --> 228             fn(trainer, trainer.lightning_module, *args, **kwargs)
#     230 if pl_module:
#     231     # restore current_fx when nested context
#     232     pl_module._current_fx_name = prev_fx_name
#
# File e:\Anaconda\envs\bio\Lib\site-packages\cca_zoo\deepmodels\callbacks.py:10, in CorrelationCallback.on_validation_epoch_end(self, trainer, pl_module)
#       5 def on_validation_epoch_end(
#       6     self, trainer: Trainer, pl_module: LightningModule
#       7 ) -> None:
#       8     pl_module.log(
#       9         "val/corr",
# ---> 10         pl_module.score(trainer.val_dataloaders[0]).sum(),
#      11     )
#
# TypeError: 'DataLoader' object is not subscriptable

# %%
trainer.fit(dcca_noi, train_loader, val_loader)
plot_pairwise_correlations(
    dcca_noi.transform(train_loader),
    train_labels,
    title="DCCA by Non-Linear Orthogonal Iterations",
)
plt.show()

# %%
# Deep CCA by Stochastic Decorrelation Loss
# ----------------------------------------------
dcca_sdl = DCCA_SDL(latent_dims=LATENT_DIMS, N=N_TRAIN, encoders=[encoder_1, encoder_2])
trainer = pl.Trainer(
    max_epochs=EPOCHS,
    enable_checkpointing=False,
    log_every_n_steps=1,
)
trainer.fit(dcca_sdl, train_loader, val_loader)
plot_pairwise_correlations(
    dcca_sdl.transform(train_loader),
    train_labels,
    title="DCCA by Stochastic Decorrelation",
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 trainer.fit(dcca_noi, train_loader, val_loader)
#       2 plot_pairwise_correlations(
#       3     dcca_noi.transform(train_loader),
#       4     train_labels,
#       5     title="DCCA by Non-Linear Orthogonal Iterations",
#       6 )
#       7 plt.show()
#
# NameError: name 'dcca_noi' is not defined

# %%
# %%
# Deep CCA by Barlow Twins
# ----------------------------------------------
barlowtwins = BarlowTwins(latent_dims=LATENT_DIMS, encoders=[encoder_1, encoder_2])
trainer = pl.Trainer(
    max_epochs=EPOCHS,
    enable_checkpointing=False,
    log_every_n_steps=1,
)
trainer.fit(barlowtwins, train_loader, val_loader)
plot_pairwise_correlations(
    barlowtwins.transform(train_loader), train_labels, title="DCCA by Barlow Twins"
)
plt.show()
