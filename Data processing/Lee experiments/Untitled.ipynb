# %%
import scanpy as sc
import squidpy as sq

sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=80, facecolor="white")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import scanpy as sc
#       2 import squidpy as sq
#       4 sc.settings.verbosity = 3
#
# File ~/.conda/envs/TCR_custom/lib/python3.11/site-packages/scanpy/__init__.py:11
#       7 from typing import TYPE_CHECKING
#       9 from packaging.version import Version
# ---> 11 from ._settings import Verbosity, settings
#      13 if Version(version("anndata")) >= Version("0.11.0rc2"):
#      14     from anndata.io import (
#      15         read_csv,
#      16         read_excel,
#    (...)     22         read_umi_tools,
#      23     )
#
# File ~/.conda/envs/TCR_custom/lib/python3.11/site-packages/scanpy/_settings/__init__.py:10
#       7 from time import time
#       8 from typing import TYPE_CHECKING, Literal, ParamSpec, TypeVar, get_args
# ---> 10 from .. import logging
# ...

# %%
import zarr
zarr.__version__

# %%
squidpy.__version__

# %%
# !pip show squidpy
