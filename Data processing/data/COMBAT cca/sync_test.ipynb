# %%
import socket
print(f"Executing on node: {socket.gethostname()}")
# Out:
# Executing on node: login3.crc.pitt.edu

# %%
a = 1
b = 2

# %%
import numpy as np
c = np.random.randn(1000000)
d = np.random.randn(1000000)
e = c + d
print(e)
# Out:
# [ 1.01984727  0.3404671  -2.09654232 ... -0.82519549 -0.60101755
#  -0.12398202]
