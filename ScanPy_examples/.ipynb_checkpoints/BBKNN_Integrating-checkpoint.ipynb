# %%
import warnings
warnings.filterwarnings("ignore")

import scanpy as sc
import pandas as pd
sc.settings.verbosity = 1  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=80, frameon=False, figsize=(3, 3), facecolor="white")

# %%
! pwd
# Out:
# /ihome/ylee/yiz133/Code

# %%
# !mkdir data
# !wget http://cf.10xgenomics.com/samples/cell-exp/1.1.0/pbmc3k/pbmc3k_filtered_gene_bc_matrices.tar.gz -O data/pbmc3k_filtered_gene_bc_matrices.tar.gz
# !cd data; tar -xzf pbmc3k_filtered_gene_bc_matrices.tar.gz
# !mkdir write
# Out:
# mkdir: cannot create directory ‘data’: File exists
# --2024-08-02 12:43:45--  http://cf.10xgenomics.com/samples/cell-exp/1.1.0/pbmc3k/pbmc3k_filtered_gene_bc_matrices.tar.gz
# Resolving cf.10xgenomics.com (cf.10xgenomics.com)... 104.18.1.173, 104.18.0.173, 2606:4700::6812:1ad, ...
# Connecting to cf.10xgenomics.com (cf.10xgenomics.com)|104.18.1.173|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cf.10xgenomics.com/samples/cell-exp/1.1.0/pbmc3k/pbmc3k_filtered_gene_bc_matrices.tar.gz [following]
# --2024-08-02 12:43:45--  https://cf.10xgenomics.com/samples/cell-exp/1.1.0/pbmc3k/pbmc3k_filtered_gene_bc_matrices.tar.gz
# Connecting to cf.10xgenomics.com (cf.10xgenomics.com)|104.18.1.173|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7621991 (7.3M) [application/x-tar]
# Saving to: ‘data/pbmc3k_filtered_gene_bc_matrices.tar.gz’
#
# 100%[======================================>] 7,621,991   --.-K/s   in 0.1s
#
# 2024-08-02 12:43:45 (67.7 MB/s) - ‘data/pbmc3k_filtered_gene_bc_matrices.tar.gz’ saved [7621991/7621991]

# %%
# Load PBMC data
adata_ref = sc.datasets.pbmc3k_processed()
adata = sc.datasets.pbmc68k_reduced()

# %%
adata_ref
# Out:
# AnnData object with n_obs × n_vars = 2638 × 1838
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'louvain'
#     var: 'n_cells'
#     uns: 'draw_graph', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_tsne', 'X_umap', 'X_draw_graph_fr'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 700 × 765
#     obs: 'bulk_labels', 'n_genes', 'percent_mito', 'n_counts', 'S_score', 'G2M_score', 'phase', 'louvain'
#     var: 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'
#     uns: 'bulk_labels_colors', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
var_names = adata_ref.var_names.intersection(adata.var_names)
adata_ref = adata_ref[:, var_names]
adata = adata[:, var_names]

# %%
adata_ref
# Out:
# View of AnnData object with n_obs × n_vars = 2638 × 208
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'louvain'
#     var: 'n_cells'
#     uns: 'draw_graph', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_tsne', 'X_umap', 'X_draw_graph_fr'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 700 × 208
#     obs: 'bulk_labels', 'n_genes', 'percent_mito', 'n_counts', 'S_score', 'G2M_score', 'phase', 'louvain'
#     var: 'n_counts', 'means', 'dispersions', 'dispersions_norm', 'highly_variable'
#     uns: 'bulk_labels_colors', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
# preprocessing
sc.pp.pca(adata_ref)
sc.pp.neighbors(adata_ref)
sc.tl.umap(adata_ref)
sc.pl.umap(adata_ref, color="louvain")
# Out:
# /ihome/ylee/yiz133/.local/lib/python3.9/site-packages/scanpy/preprocessing/_pca.py:325: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   adata.obsm["X_pca"] = X_pca

# %%
sc.tl.ingest(adata, adata_ref, obs="louvain")
adata.uns["louvain_colors"] = adata_ref.uns["louvain_colors"]  # fix colors
sc.pl.umap(adata, color=["louvain", "bulk_labels"], wspace=0.5)
# Out:
# /ihome/ylee/yiz133/.local/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /ihome/crc/install/python/Anaconda3-2022.10/lib/python3.9/_collections_abc.py:941: ImplicitModificationWarning: Setting element `.obsm['rep']` of view, initializing view as actual.
#   self[key] = other[key]
# /ihome/crc/install/python/Anaconda3-2022.10/lib/python3.9/_collections_abc.py:941: ImplicitModificationWarning: Setting element `.obsm['X_umap']` of view, initializing view as actual.
#   self[key] = other[key]
# /ihome/crc/install/python/Anaconda3-2022.10/lib/python3.9/_collections_abc.py:941: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   self[key] = other[key]

# %%
adata_concat = adata_ref.concatenate(adata, batch_categories=["ref", "new"])
adata_concat
# Out:
# /scratch/slurm-3874228/ipykernel_53596/2959733235.py:1: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata_concat = adata_ref.concatenate(adata, batch_categories=["ref", "new"])
# AnnData object with n_obs × n_vars = 3338 × 208
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'louvain', 'bulk_labels', 'S_score', 'G2M_score', 'phase', 'batch'
#     var: 'n_counts-new', 'means-new', 'dispersions-new', 'dispersions_norm-new', 'highly_variable-new', 'n_cells-ref'
#     obsm: 'X_pca', 'X_umap'

# %%
adata_concat.obs.louvain = adata_concat.obs.louvain.astype("category")
# fix category ordering
adata_concat.obs.louvain.cat.reorder_categories(
    adata_ref.obs.louvain.cat.categories, inplace=True
)
# fix category colors
adata_concat.uns["louvain_colors"] = adata_ref.uns["louvain_colors"]
sc.pl.umap(adata_concat, color=["batch", "louvain"])
# Out:
#                       n_genes  percent_mito  n_counts            louvain  \
# index
# AAACATACAACCAC-1-ref      781      0.030178    2419.0        CD4 T cells
# AAACATTGAGCTAC-1-ref     1352      0.037936    4903.0            B cells
# AAACATTGATCAGC-1-ref     1131      0.008897    3147.0        CD4 T cells
# AAACCGTGCTTCCG-1-ref      960      0.017431    2639.0    CD14+ Monocytes
# AAACCGTGTATGCG-1-ref      522      0.012245     980.0           NK cells
# ...                       ...           ...       ...                ...
# TGGCACCTCCAACA-8-new     1166      0.008840    3733.0    Dendritic cells
# TGTGAGTGCTTTAC-8-new     1014      0.022068    2311.0  FCGR3A+ Monocytes
# TGTTACTGGCGATT-8-new     1079      0.012821    3354.0        CD4 T cells
# TTCAGTACCGGGAA-8-new     1030      0.014169    2823.0            B cells
# TTGAGGTGGAGAGC-8-new     1552      0.010886    4685.0            B cells
#
#                           bulk_labels   S_score  G2M_score phase batch
# index
# AAACATACAACCAC-1-ref              NaN       NaN        NaN   NaN   ref
# AAACATTGAGCTAC-1-ref              NaN       NaN        NaN   NaN   ref
# AAACATTGATCAGC-1-ref              NaN       NaN        NaN   NaN   ref
# AAACCGTGCTTCCG-1-ref              NaN       NaN        NaN   NaN   ref
# AAACCGTGTATGCG-1-ref              NaN       NaN        NaN   NaN   ref
# ...                               ...       ...        ...   ...   ...
# TGGCACCTCCAACA-8-new        Dendritic -0.124456  -0.867484    G1   new
# TGTGAGTGCTTTAC-8-new        Dendritic -0.298056  -0.649070    G1   new
# TGTTACTGGCGATT-8-new  CD4+/CD25 T Reg  0.216895  -0.527338     S   new
# TTCAGTACCGGGAA-8-new          CD19+ B  0.139054  -0.981590     S   new
# TTGAGGTGGAGAGC-8-new        Dendritic -0.148449  -0.674752    G1   new
#
# [3338 rows x 9 columns]

# %% [markdown]
# # Pancreas data

# %%
# !pwd
! ls
# Out:
# /ihome/ylee/yiz133/Code
# data  Integrating.ipynb  pancreas.h5ad	Preprocessing_cluster.ipynb  write

# %%
# note that this collection of batches is already intersected on the genes
adata_all = sc.read(
    "pancreas.h5ad",
    backup_url="https://www.dropbox.com/s/qj1jlm9w10wmt0u/pancreas.h5ad?dl=1",
)

# %%
adata_all
# Out:
# AnnData object with n_obs × n_vars = 14693 × 2448
#     obs: 'celltype', 'sample', 'n_genes', 'batch', 'n_counts', 'louvain'
#     var: 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3'
#     uns: 'celltype_colors', 'louvain', 'neighbors', 'pca', 'sample_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
counts = adata_all.obs.celltype.value_counts()
counts
# remove the 5 minority classes
minority_classes = counts.index[-5:].tolist()  # get the minority classes
adata_all = adata_all[~adata_all.obs.celltype.isin(minority_classes)]  # actually subset
adata_all.obs.celltype.cat.reorder_categories(  # reorder according to abundance
    counts.index[:-5].tolist(), inplace=True
)
# Out:
#                               celltype sample  n_genes batch      n_counts  \
# index
# human1_lib1.final_cell_0001-0   acinar  Baron     3526     0  2.241100e+04
# human1_lib1.final_cell_0002-0   acinar  Baron     4201     0  2.794900e+04
# human1_lib1.final_cell_0003-0   acinar  Baron     2119     0  1.689200e+04
# human1_lib1.final_cell_0004-0   acinar  Baron     2956     0  1.929900e+04
# human1_lib1.final_cell_0005-0   acinar  Baron     2715     0  1.506700e+04
# ...                                ...    ...      ...   ...           ...
# reads.29499-3                   ductal   Wang    19950     3  1.056558e+06
# reads.29500-3                   ductal   Wang    19950     3  9.926309e+05
# reads.29501-3                     beta   Wang    19950     3  1.751338e+06
# reads.29502-3                  dropped   Wang    19950     3  2.163764e+06
# reads.29503-3                     beta   Wang    19950     3  2.038979e+06
#
#                               louvain
# index
# human1_lib1.final_cell_0001-0       2
# human1_lib1.final_cell_0002-0       2
# human1_lib1.final_cell_0003-0       2
# human1_lib1.final_cell_0004-0       2
# human1_lib1.final_cell_0005-0       2
# ...                               ...
# reads.29499-3                      10
# reads.29500-3                      10
# reads.29501-3                      10
# reads.29502-3                      10
# reads.29503-3                      10
#
# [14693 rows x 6 columns]

# %%
# the batch effect
sc.pp.pca(adata_all)
sc.pp.neighbors(adata_all)
sc.tl.umap(adata_all)
sc.pl.umap(
    adata_all, color=["batch", "celltype"], palette=sc.pl.palettes.vega_20_scanpy
)
# Out:
# WARNING: Length of palette colors is smaller than the number of categories (palette length: 20, categories length: 24. Some categories will have the same color.

# %%
# solve with BBKNN
sc.external.pp.bbknn(adata_all, batch_key="batch")
sc.tl.umap(adata_all)
sc.pl.umap(adata_all, color=["batch", "celltype"])
# Out:
# WARNING: consider updating your call to make use of `computation`

# %% [markdown]
# # Mapping onto a reference batch using ingest

# %%
adata_ref = adata_all[adata_all.obs.batch == "0"]
sc.pp.pca(adata_ref)
sc.pp.neighbors(adata_ref)
sc.tl.umap(adata_ref)
sc.pl.umap(adata_ref, color="celltype")

# %%
adata_ref
# Out:
# AnnData object with n_obs × n_vars = 8569 × 2448
#     obs: 'celltype', 'sample', 'n_genes', 'batch', 'n_counts', 'louvain'
#     var: 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3'
#     uns: 'celltype_colors', 'louvain', 'neighbors', 'pca', 'sample_colors', 'umap', 'batch_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
adatas = [adata_all[adata_all.obs.batch == i].copy() for i in ["1", "2", "3"]]
sc.settings.verbosity = 2  # a bit more logging
for iadata, adata in enumerate(adatas):
    print(f"... integrating batch {iadata+1}")
    adata.obs["celltype_orig"] = adata.obs.celltype  # save the original cell type
    sc.tl.ingest(adata, adata_ref, obs="celltype")
# Out:
# ... integrating batch 1
# running ingest
#     finished (0:00:10)
# ... integrating batch 2
# running ingest
#     finished (0:00:06)
# ... integrating batch 3
# running ingest
#     finished (0:00:03)

# %%
adatas
# Out:
# [AnnData object with n_obs × n_vars = 2126 × 2448
#      obs: 'celltype', 'sample', 'n_genes', 'batch', 'n_counts', 'louvain', 'celltype_orig'
#      var: 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3'
#      uns: 'celltype_colors', 'louvain', 'neighbors', 'pca', 'sample_colors', 'umap', 'batch_colors'
#      obsm: 'X_pca', 'X_umap', 'rep'
#      varm: 'PCs'
#      obsp: 'distances', 'connectivities',
#  AnnData object with n_obs × n_vars = 3363 × 2448
#      obs: 'celltype', 'sample', 'n_genes', 'batch', 'n_counts', 'louvain', 'celltype_orig'
#      var: 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3'
#      uns: 'celltype_colors', 'louvain', 'neighbors', 'pca', 'sample_colors', 'umap', 'batch_colors'
#      obsm: 'X_pca', 'X_umap', 'rep'
#      varm: 'PCs'
#      obsp: 'distances', 'connectivities',
#  AnnData object with n_obs × n_vars = 635 × 2448
#      obs: 'celltype', 'sample', 'n_genes', 'batch', 'n_counts', 'louvain', 'celltype_orig'
#      var: 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3'
#      uns: 'celltype_colors', 'louvain', 'neighbors', 'pca', 'sample_colors', 'umap', 'batch_colors'
#      obsm: 'X_pca', 'X_umap', 'rep'
#      varm: 'PCs'
#      obsp: 'distances', 'connectivities']

# %%
adata_ref
# Out:
# AnnData object with n_obs × n_vars = 8569 × 2448
#     obs: 'celltype', 'sample', 'n_genes', 'batch', 'n_counts', 'louvain'
#     var: 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3'
#     uns: 'celltype_colors', 'louvain', 'neighbors', 'pca', 'sample_colors', 'umap', 'batch_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
adata_concat = adata_ref.concatenate(adatas)
adata_concat
# Out:
# AnnData object with n_obs × n_vars = 14693 × 2448
#     obs: 'celltype', 'sample', 'n_genes', 'batch', 'n_counts', 'louvain', 'celltype_orig'
#     var: 'n_cells-0', 'n_cells-1', 'n_cells-2', 'n_cells-3'
#     obsm: 'X_pca', 'X_umap'

# %%
adata_concat.obs.celltype = adata_concat.obs.celltype.astype("category")
# fix category ordering
adata_concat.obs.celltype.cat.reorder_categories(
    adata_ref.obs.celltype.cat.categories)
# fix category coloring
adata_concat.uns["celltype_colors"] = adata_ref.uns["celltype_colors"]
sc.pl.umap(adata_concat, color=["batch", "celltype"])

# %% [markdown]
# ## Evaluating consistency

# %%
adata_query = adata_concat[adata_concat.obs.batch.isin(["1", "2", "3"])]
adata_query.obs
# Out:
#                     celltype  sample  n_genes batch      n_counts louvain  \
# index
# D28.1_1-1-1            alpha  Muraro     5448     1  2.322583e+04       8
# D28.1_13-1-1          ductal  Muraro     5911     1  2.334263e+04      19
# D28.1_15-1-1           alpha  Muraro     5918     1  2.713471e+04       8
# D28.1_17-1-1           alpha  Muraro     4522     1  1.581207e+04       8
# D28.1_2-1-1      endothelial  Muraro     6464     1  3.173151e+04      17
# ...                      ...     ...      ...   ...           ...     ...
# reads.29499-3-3       ductal    Wang    19950     3  1.056558e+06      10
# reads.29500-3-3       ductal    Wang    19950     3  9.926309e+05      10
# reads.29501-3-3         beta    Wang    19950     3  1.751338e+06      10
# reads.29502-3-3       ductal    Wang    19950     3  2.163764e+06      10
# reads.29503-3-3         beta    Wang    19950     3  2.038979e+06      10
#
#                 celltype_orig
# index
# D28.1_1-1-1             alpha
# D28.1_13-1-1           ductal
# D28.1_15-1-1            alpha
# D28.1_17-1-1            alpha
# D28.1_2-1-1       endothelial
# ...                       ...
# reads.29499-3-3        ductal
# reads.29500-3-3        ductal
# reads.29501-3-3          beta
# reads.29502-3-3       dropped
# reads.29503-3-3          beta
#
# [6124 rows x 7 columns]

# %%
obs_query.celltype.cat.categories
# Out:
# Index(['acinar', 'activated_stellate', 'alpha', 'beta', 'delta', 'ductal',
#        'endothelial', 'gamma', 'macrophage', 'mast', 'quiescent_stellate',
#        'schwann', 't_cell'],
#       dtype='object')

# %%
obs_query = adata_query.obs
# intersected categories
conserved_categories = obs_query.celltype.cat.categories.intersection(
    obs_query.celltype_orig.cat.categories
)
# intersect categories
obs_query_conserved = obs_query.loc[
    obs_query.celltype.isin(conserved_categories)
    & obs_query.celltype_orig.isin(conserved_categories)
]

# %%
obs_query_conserved.celltype.cat.remove_unused_categories()
obs_query_conserved.celltype.cat.categories
# Out:
# Index(['acinar', 'activated_stellate', 'alpha', 'beta', 'delta', 'ductal',
#        'endothelial', 'gamma', 'macrophage', 'mast', 'quiescent_stellate',
#        'schwann', 't_cell'],
#       dtype='object')

# %%
obs_query_conserved.celltype_orig.cat.categories
# Out:
# Index(['MHC class II', 'PSC', 'acinar', 'alpha', 'beta', 'co-expression',
#        'delta', 'dropped', 'ductal', 'endothelial', 'epsilon', 'gamma', 'mast',
#        'mesenchymal', 'mesenchyme', 'not applicable', 'unclassified',
#        'unclassified endocrine', 'unclear'],
#       dtype='object')

# %%
obs_query_conserved.celltype_orig.cat.remove_unused_categories()
obs_query_conserved.celltype_orig.cat.categories
# Out:
# Index(['MHC class II', 'PSC', 'acinar', 'alpha', 'beta', 'co-expression',
#        'delta', 'dropped', 'ductal', 'endothelial', 'epsilon', 'gamma', 'mast',
#        'mesenchymal', 'mesenchyme', 'not applicable', 'unclassified',
#        'unclassified endocrine', 'unclear'],
#       dtype='object')

# %%
pd.crosstab(obs_query_conserved.celltype, obs_query_conserved.celltype_orig)
# Out:
# celltype_orig  acinar  alpha  beta  delta  ductal  endothelial  gamma
# celltype
# acinar            171      2     3      0       3            0      3
# alpha               0   1812     3      1      18            0     22
# beta                1     57   804     11       7            0     21
# delta               0      6     4    304       1            0     66
# ductal            237      5     5      0     673            0      0
# endothelial         0      2     0      0       0           36      0
# gamma               0      1     5      0       0            0    204
# mast                0      0     0      0       1            0      0

# %% [markdown]
# ## Visualizing distributions across batche

# %%
sc.tl.embedding_density(adata_concat, groupby="batch")
sc.pl.embedding_density(adata_concat, groupby="batch")
# Out:
# computing density on 'umap'

# %%
for batch in ["1", "2", "3"]:
    sc.pl.umap(adata_concat, color="batch", groups=[batch])
