# %%
import pyreadr

res = pyreadr.read_r("/ix1/ylee/Yifan_Zhang/Code_data/Tumor/GSE139555_2019/GSE139555_tcell_integrated.rds")  # returns a dict-like
res.keys()
obj = list(res.values())[0]
# Out:
# ---------------------------------------------------------------------------
# LibrdataError                             Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pyreadr
# ----> 3 res = pyreadr.read_r("/ix1/ylee/Yifan_Zhang/Code_data/Tumor/GSE139555_2019/GSE139555_tcell_integrated.rds")  # returns a dict-like
#       4 res.keys()
#       5 obj = list(res.values())[0]
#
# File ~/.conda/envs/TCR/lib/python3.11/site-packages/pyreadr/pyreadr.py:66, in read_r(path, use_objects, timezone)
#      64 if not os.path.isfile(filename_bytes):
#      65     raise PyreadrError("File {0} does not exist!".format(filename_bytes))
# ---> 66 parser.parse(filename_bytes)
#      68 result = OrderedDict()
#      69 for table_index, table in enumerate(parser.table_data):
#
# File ~/.conda/envs/TCR/lib/python3.11/site-packages/pyreadr/librdata.pyx:149, in pyreadr.librdata.Parser.parse()
#
# ...
