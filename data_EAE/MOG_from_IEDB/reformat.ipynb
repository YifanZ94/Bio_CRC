# %%
import pandas as pd

# %%
df = pd.read_csv('Filtered_MOG_assays.csv')
df.head()
# Out:
#    IEDB Receptor ID Reference Name           Epitope Name Chain 1 V Gene  \
# 0              1805            2D2  MEVGWYRSPFSRVVHLYRNGK       TRAV9D-4
# 1             19070            NaN  MEVGWYRSPFSRVVHLYRNGK       TRAV9D-4
# 2             26413       T12-1359  MEVGWYRSPFSRVVHLYRNGK    TRAV4D-3*03
# 3             26414         T6-145  MEVGWYRSPFSRVVHLYRNGK    TRAV4D-3*03
# 4             26415          T6-71  MEVGWYRSPFSRVVHLYRNGK    TRAV7D-2*02
#
#    Chain 1 D Gene Chain 1 J Gene   Chain 1 CDR3 Chain 2 V Gene Chain 2 D Gene  \
# 0             NaN            NaN  VYFCALRSYNFGF      TRBV16*04            NaN
# 1             NaN            NaN            NaN       TCRVB8-2            NaN
# 2             NaN      TRAJ31*01   CAAEAGNNRIFF       TRBV13-2          TRBD2
# 3             NaN      TRAJ17*01  CAAGNSAGNKLTF       TRBV13-2          TRBD2
# 4             NaN      TRAJ52*01  CAASGANTGKLTF       TRBV13-2          TRBD2
#
#   Chain 2 J Gene     Chain 2 CDR3  count
# ...

# %%
# df.dropna(inplace=True)
df2 = df[["Chain 1 CDR3", "Chain 2 CDR3", "Epitope Name"]]
df2.dropna(axis=0, inplace=True)
df2['value'] = 1
df2.head()
# Out:
# /scratch/slurm-6128184/ipykernel_650/2234482220.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(axis=0, inplace=True)
# /scratch/slurm-6128184/ipykernel_650/2234482220.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['value'] = 1
#     Chain 1 CDR3     Chain 2 CDR3           Epitope Name  value
# 0  VYFCALRSYNFGF       ASSLDCGANP  MEVGWYRSPFSRVVHLYRNGK      1
# 2   CAAEAGNNRIFF  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 3  CAAGNSAGNKLTF  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# ...

# %%
df2.to_csv('ab_train.csv')

# %%
df3 = df2[["Chain 2 CDR3", "Epitope Name", "value"]]
df3.head()
# Out:
#       Chain 2 CDR3           Epitope Name  value
# 0       ASSLDCGANP  MEVGWYRSPFSRVVHLYRNGK      1
# 2  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 3  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 4  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 5  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1

# %%
df3.to_csv('b_train.csv')

# %%
df3
# Out:
#        Chain 2 CDR3           Epitope Name  value
# 0        ASSLDCGANP  MEVGWYRSPFSRVVHLYRNGK      1
# 2   CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 3   CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 4   CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 5   CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 6   CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 7   CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 8   CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 9   CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 10  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 11  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 12  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 13  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 14  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 15  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 16  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 17  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# 18  CASGETGGNYAEQFF  MEVGWYRSPFSRVVHLYRNGK      1
# ...
