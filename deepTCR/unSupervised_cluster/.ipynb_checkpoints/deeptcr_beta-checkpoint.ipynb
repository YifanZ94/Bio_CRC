# %% [markdown]
# ### Analysis

# %%
import warnings
warnings.filterwarnings('ignore')
from DeepTCR.DeepTCR import DeepTCR_U

# %%
# Instantiate training object
DTCRU = DeepTCR_U('TCR_Analysis')

# Path to your dataset
data_directory = r"E:\Python code\Machine learning\JupyterNote\Bio\deepTCR\DeepTCR_input"

# Load Data from CNS & Spleen directories
DTCRU.Get_Data(directory=data_directory, Load_Prev_Data=False, aggregate_by_aa=True,
               aa_column_beta=0, count_column=1, v_beta_column=2, j_beta_column=3)

print("Data loaded successfully into DeepTCR!")
# Out:
# Loading Data...
# Embedding Sequences...
# Data Loaded
# Data loaded successfully into DeepTCR!

# %%
# Train Variational Autoencoder (VAE) with adjusted parameters
DTCRU.Train_VAE(
    latent_dim=96,          # Reduce latent dimension to prevent overfitting on 20K sequences
    batch_size=5000,         # Reduce batch size to prevent memory overload
    epochs_min=5,            # Ensure at least 5 training epochs
    stop_criterion_window=30, # Increase patience for stopping
    learning_rate=0.001,    # Slightly slower learning rate for better stability
    Load_Prev_Data=False     # Ensure fresh training
)

print("DeepTCR VAE training completed!")
# Out:
# Epoch = 0, Iteration = 0 Total Loss: 7.16651: Recon Loss: 7.13492: Latent Loss: 0.03159: Sparsity Loss: 0.00000: Recon Accuracy: 0.06543
# Epoch = 0, Iteration = 1 Total Loss: 6.94747: Recon Loss: 6.91649: Latent Loss: 0.03098: Sparsity Loss: 0.00000: Recon Accuracy: 0.08232
# Epoch = 0, Iteration = 2 Total Loss: 6.79340: Recon Loss: 6.76092: Latent Loss: 0.03248: Sparsity Loss: 0.00000: Recon Accuracy: 0.10957
# Epoch = 0, Iteration = 3 Total Loss: 6.68188: Recon Loss: 6.64496: Latent Loss: 0.03691: Sparsity Loss: 0.00000: Recon Accuracy: 0.13926
# Epoch = 0, Iteration = 4 Total Loss: 6.60563: Recon Loss: 6.55993: Latent Loss: 0.04570: Sparsity Loss: 0.00000: Recon Accuracy: 0.17877
# Epoch = 0, Iteration = 5 Total Loss: 6.54574: Recon Loss: 6.48910: Latent Loss: 0.05664: Sparsity Loss: 0.00000: Recon Accuracy: 0.20061
# Epoch = 0, Iteration = 6 Total Loss: 6.48482: Recon Loss: 6.42986: Latent Loss: 0.05496: Sparsity Loss: 0.00000: Recon Accuracy: 0.20938
# Epoch = 1, Iteration = 0 Total Loss: 6.38431: Recon Loss: 6.33762: Latent Loss: 0.04669: Sparsity Loss: 0.00000: Recon Accuracy: 0.22440
# Epoch = 1, Iteration = 1 Total Loss: 6.29397: Recon Loss: 6.25243: Latent Loss: 0.04154: Sparsity Loss: 0.00000: Recon Accuracy: 0.23706
# Epoch = 1, Iteration = 2 Total Loss: 6.20504: Recon Loss: 6.16533: Latent Loss: 0.03970: Sparsity Loss: 0.00000: Recon Accuracy: 0.25163
# Epoch = 1, Iteration = 3 Total Loss: 6.13083: Recon Loss: 6.09020: Latent Loss: 0.04062: Sparsity Loss: 0.00000: Recon Accuracy: 0.25310
# Epoch = 1, Iteration = 4 Total Loss: 5.99617: Recon Loss: 5.95336: Latent Loss: 0.04280: Sparsity Loss: 0.00000: Recon Accuracy: 0.26307
# Epoch = 1, Iteration = 5 Total Loss: 5.86376: Recon Loss: 5.81950: Latent Loss: 0.04426: Sparsity Loss: 0.00000: Recon Accuracy: 0.27034
# Epoch = 1, Iteration = 6 Total Loss: 5.71862: Recon Loss: 5.67197: Latent Loss: 0.04665: Sparsity Loss: 0.00000: Recon Accuracy: 0.27564
# Epoch = 2, Iteration = 0 Total Loss: 5.55414: Recon Loss: 5.50638: Latent Loss: 0.04776: Sparsity Loss: 0.00000: Recon Accuracy: 0.29730
# Epoch = 2, Iteration = 1 Total Loss: 5.41335: Recon Loss: 5.36128: Latent Loss: 0.05206: Sparsity Loss: 0.00000: Recon Accuracy: 0.31665
# Epoch = 2, Iteration = 2 Total Loss: 5.23563: Recon Loss: 5.17976: Latent Loss: 0.05587: Sparsity Loss: 0.00000: Recon Accuracy: 0.33827
# Epoch = 2, Iteration = 3 Total Loss: 5.11664: Recon Loss: 5.05143: Latent Loss: 0.06521: Sparsity Loss: 0.00000: Recon Accuracy: 0.35606
# Epoch = 2, Iteration = 4 Total Loss: 4.98162: Recon Loss: 4.90496: Latent Loss: 0.07666: Sparsity Loss: 0.00000: Recon Accuracy: 0.38704
# Epoch = 2, Iteration = 5 Total Loss: 4.77701: Recon Loss: 4.69553: Latent Loss: 0.08148: Sparsity Loss: 0.00000: Recon Accuracy: 0.41081
# Epoch = 2, Iteration = 6 Total Loss: 4.61118: Recon Loss: 4.52820: Latent Loss: 0.08298: Sparsity Loss: 0.00000: Recon Accuracy: 0.42164
# Epoch = 3, Iteration = 0 Total Loss: 4.42947: Recon Loss: 4.34365: Latent Loss: 0.08582: Sparsity Loss: 0.00000: Recon Accuracy: 0.44043
# Epoch = 3, Iteration = 1 Total Loss: 4.22890: Recon Loss: 4.13469: Latent Loss: 0.09420: Sparsity Loss: 0.00000: Recon Accuracy: 0.46240
# Epoch = 3, Iteration = 2 Total Loss: 4.04767: Recon Loss: 3.94539: Latent Loss: 0.10228: Sparsity Loss: 0.00000: Recon Accuracy: 0.47634
# Epoch = 3, Iteration = 3 Total Loss: 3.90989: Recon Loss: 3.80418: Latent Loss: 0.10571: Sparsity Loss: 0.00000: Recon Accuracy: 0.49004
# Epoch = 3, Iteration = 4 Total Loss: 3.68777: Recon Loss: 3.57191: Latent Loss: 0.11586: Sparsity Loss: 0.00000: Recon Accuracy: 0.51596
# Epoch = 3, Iteration = 5 Total Loss: 3.44899: Recon Loss: 3.32474: Latent Loss: 0.12425: Sparsity Loss: 0.00000: Recon Accuracy: 0.53739
# Epoch = 3, Iteration = 6 Total Loss: 3.24468: Recon Loss: 3.11089: Latent Loss: 0.13379: Sparsity Loss: 0.00000: Recon Accuracy: 0.56290
# Epoch = 4, Iteration = 0 Total Loss: 3.09760: Recon Loss: 2.94976: Latent Loss: 0.14783: Sparsity Loss: 0.00000: Recon Accuracy: 0.58521
# Epoch = 4, Iteration = 1 Total Loss: 2.93636: Recon Loss: 2.77647: Latent Loss: 0.15989: Sparsity Loss: 0.00000: Recon Accuracy: 0.60400
# Epoch = 4, Iteration = 2 Total Loss: 2.76661: Recon Loss: 2.60435: Latent Loss: 0.16227: Sparsity Loss: 0.00000: Recon Accuracy: 0.62421
# Epoch = 4, Iteration = 3 Total Loss: 2.58581: Recon Loss: 2.42114: Latent Loss: 0.16467: Sparsity Loss: 0.00000: Recon Accuracy: 0.64241
# Epoch = 4, Iteration = 4 Total Loss: 2.49232: Recon Loss: 2.32110: Latent Loss: 0.17121: Sparsity Loss: 0.00000: Recon Accuracy: 0.64998
# Epoch = 4, Iteration = 5 Total Loss: 2.36416: Recon Loss: 2.18459: Latent Loss: 0.17956: Sparsity Loss: 0.00000: Recon Accuracy: 0.66992
# Epoch = 4, Iteration = 6 Total Loss: 2.17222: Recon Loss: 1.98277: Latent Loss: 0.18944: Sparsity Loss: 0.00000: Recon Accuracy: 0.69155
# Epoch = 5, Iteration = 0 Total Loss: 2.11794: Recon Loss: 1.92084: Latent Loss: 0.19710: Sparsity Loss: 0.00000: Recon Accuracy: 0.69407
# Epoch = 5, Iteration = 1 Total Loss: 1.96530: Recon Loss: 1.76447: Latent Loss: 0.20083: Sparsity Loss: 0.00000: Recon Accuracy: 0.70979
# Epoch = 5, Iteration = 2 Total Loss: 1.83608: Recon Loss: 1.63362: Latent Loss: 0.20247: Sparsity Loss: 0.00000: Recon Accuracy: 0.72519
# Epoch = 5, Iteration = 3 Total Loss: 1.77179: Recon Loss: 1.56663: Latent Loss: 0.20517: Sparsity Loss: 0.00000: Recon Accuracy: 0.73144
# Epoch = 5, Iteration = 4 Total Loss: 1.64567: Recon Loss: 1.43853: Latent Loss: 0.20714: Sparsity Loss: 0.00000: Recon Accuracy: 0.74192
# Epoch = 5, Iteration = 5 Total Loss: 1.58034: Recon Loss: 1.36756: Latent Loss: 0.21278: Sparsity Loss: 0.00000: Recon Accuracy: 0.75384
# Epoch = 5, Iteration = 6 Total Loss: 1.48783: Recon Loss: 1.26888: Latent Loss: 0.21895: Sparsity Loss: 0.00000: Recon Accuracy: 0.76508
# Epoch = 6, Iteration = 0 Total Loss: 1.40110: Recon Loss: 1.18220: Latent Loss: 0.21889: Sparsity Loss: 0.00000: Recon Accuracy: 0.77426
# Epoch = 6, Iteration = 1 Total Loss: 1.36100: Recon Loss: 1.14230: Latent Loss: 0.21869: Sparsity Loss: 0.00000: Recon Accuracy: 0.77309
# Epoch = 6, Iteration = 2 Total Loss: 1.29022: Recon Loss: 1.06971: Latent Loss: 0.22051: Sparsity Loss: 0.00000: Recon Accuracy: 0.78281
# Epoch = 6, Iteration = 3 Total Loss: 1.23024: Recon Loss: 1.00755: Latent Loss: 0.22269: Sparsity Loss: 0.00000: Recon Accuracy: 0.79029
# Epoch = 6, Iteration = 4 Total Loss: 1.17697: Recon Loss: 0.95410: Latent Loss: 0.22287: Sparsity Loss: 0.00000: Recon Accuracy: 0.79623
# Epoch = 6, Iteration = 5 Total Loss: 1.13145: Recon Loss: 0.90536: Latent Loss: 0.22608: Sparsity Loss: 0.00000: Recon Accuracy: 0.80123
# Epoch = 6, Iteration = 6 Total Loss: 1.06467: Recon Loss: 0.83287: Latent Loss: 0.23180: Sparsity Loss: 0.00000: Recon Accuracy: 0.80661
# Epoch = 7, Iteration = 0 Total Loss: 1.04378: Recon Loss: 0.80901: Latent Loss: 0.23477: Sparsity Loss: 0.00000: Recon Accuracy: 0.80848
# Epoch = 7, Iteration = 1 Total Loss: 1.00019: Recon Loss: 0.76098: Latent Loss: 0.23920: Sparsity Loss: 0.00000: Recon Accuracy: 0.81174
# Epoch = 7, Iteration = 2 Total Loss: 0.97418: Recon Loss: 0.73639: Latent Loss: 0.23779: Sparsity Loss: 0.00000: Recon Accuracy: 0.81575
# Epoch = 7, Iteration = 3 Total Loss: 0.96622: Recon Loss: 0.72916: Latent Loss: 0.23706: Sparsity Loss: 0.00000: Recon Accuracy: 0.81906
# Epoch = 7, Iteration = 4 Total Loss: 0.94276: Recon Loss: 0.70574: Latent Loss: 0.23702: Sparsity Loss: 0.00000: Recon Accuracy: 0.81982
# Epoch = 7, Iteration = 5 Total Loss: 0.91185: Recon Loss: 0.67550: Latent Loss: 0.23635: Sparsity Loss: 0.00000: Recon Accuracy: 0.82223
# Epoch = 7, Iteration = 6 Total Loss: 0.89575: Recon Loss: 0.66010: Latent Loss: 0.23565: Sparsity Loss: 0.00000: Recon Accuracy: 0.82466
# Epoch = 8, Iteration = 0 Total Loss: 0.87325: Recon Loss: 0.64130: Latent Loss: 0.23195: Sparsity Loss: 0.00000: Recon Accuracy: 0.82665
# Epoch = 8, Iteration = 1 Total Loss: 0.86734: Recon Loss: 0.63547: Latent Loss: 0.23187: Sparsity Loss: 0.00000: Recon Accuracy: 0.82685
# Epoch = 8, Iteration = 2 Total Loss: 0.84617: Recon Loss: 0.61759: Latent Loss: 0.22858: Sparsity Loss: 0.00000: Recon Accuracy: 0.83042
# Epoch = 8, Iteration = 3 Total Loss: 0.83142: Recon Loss: 0.60529: Latent Loss: 0.22613: Sparsity Loss: 0.00000: Recon Accuracy: 0.83080
# Epoch = 8, Iteration = 4 Total Loss: 0.82709: Recon Loss: 0.60452: Latent Loss: 0.22257: Sparsity Loss: 0.00000: Recon Accuracy: 0.83152
# Epoch = 8, Iteration = 5 Total Loss: 0.81542: Recon Loss: 0.59649: Latent Loss: 0.21893: Sparsity Loss: 0.00000: Recon Accuracy: 0.83219
# Epoch = 8, Iteration = 6 Total Loss: 0.80510: Recon Loss: 0.58808: Latent Loss: 0.21702: Sparsity Loss: 0.00000: Recon Accuracy: 0.83274
# Epoch = 9, Iteration = 0 Total Loss: 0.79838: Recon Loss: 0.58735: Latent Loss: 0.21102: Sparsity Loss: 0.00000: Recon Accuracy: 0.83473
# Epoch = 9, Iteration = 1 Total Loss: 0.79025: Recon Loss: 0.58334: Latent Loss: 0.20691: Sparsity Loss: 0.00000: Recon Accuracy: 0.83428
# Epoch = 9, Iteration = 2 Total Loss: 0.77991: Recon Loss: 0.57791: Latent Loss: 0.20201: Sparsity Loss: 0.00000: Recon Accuracy: 0.83638
# Epoch = 9, Iteration = 3 Total Loss: 0.77282: Recon Loss: 0.57440: Latent Loss: 0.19841: Sparsity Loss: 0.00000: Recon Accuracy: 0.83666
# Epoch = 9, Iteration = 4 Total Loss: 0.76493: Recon Loss: 0.56985: Latent Loss: 0.19508: Sparsity Loss: 0.00000: Recon Accuracy: 0.83821
# Epoch = 9, Iteration = 5 Total Loss: 0.76251: Recon Loss: 0.57089: Latent Loss: 0.19163: Sparsity Loss: 0.00000: Recon Accuracy: 0.83725
# Epoch = 9, Iteration = 6 Total Loss: 0.75768: Recon Loss: 0.56803: Latent Loss: 0.18966: Sparsity Loss: 0.00000: Recon Accuracy: 0.83732
# Epoch = 10, Iteration = 0 Total Loss: 0.75338: Recon Loss: 0.56584: Latent Loss: 0.18753: Sparsity Loss: 0.00000: Recon Accuracy: 0.83791
# Epoch = 10, Iteration = 1 Total Loss: 0.73995: Recon Loss: 0.55621: Latent Loss: 0.18374: Sparsity Loss: 0.00000: Recon Accuracy: 0.83925
# Epoch = 10, Iteration = 2 Total Loss: 0.73936: Recon Loss: 0.55699: Latent Loss: 0.18236: Sparsity Loss: 0.00000: Recon Accuracy: 0.83889
# Epoch = 10, Iteration = 3 Total Loss: 0.73612: Recon Loss: 0.55701: Latent Loss: 0.17912: Sparsity Loss: 0.00000: Recon Accuracy: 0.84021
# Epoch = 10, Iteration = 4 Total Loss: 0.72326: Recon Loss: 0.54818: Latent Loss: 0.17508: Sparsity Loss: 0.00000: Recon Accuracy: 0.84019
# Epoch = 10, Iteration = 5 Total Loss: 0.72014: Recon Loss: 0.54801: Latent Loss: 0.17213: Sparsity Loss: 0.00000: Recon Accuracy: 0.84125
# Epoch = 10, Iteration = 6 Total Loss: 0.71069: Recon Loss: 0.54185: Latent Loss: 0.16884: Sparsity Loss: 0.00000: Recon Accuracy: 0.84121
# Epoch = 11, Iteration = 0 Total Loss: 0.71053: Recon Loss: 0.54393: Latent Loss: 0.16661: Sparsity Loss: 0.00000: Recon Accuracy: 0.84145
# Epoch = 11, Iteration = 1 Total Loss: 0.71558: Recon Loss: 0.55055: Latent Loss: 0.16503: Sparsity Loss: 0.00000: Recon Accuracy: 0.84098
# Epoch = 11, Iteration = 2 Total Loss: 0.70541: Recon Loss: 0.54301: Latent Loss: 0.16241: Sparsity Loss: 0.00000: Recon Accuracy: 0.84166
# Epoch = 11, Iteration = 3 Total Loss: 0.70747: Recon Loss: 0.54851: Latent Loss: 0.15896: Sparsity Loss: 0.00000: Recon Accuracy: 0.84066
# Epoch = 11, Iteration = 4 Total Loss: 0.69748: Recon Loss: 0.53986: Latent Loss: 0.15762: Sparsity Loss: 0.00000: Recon Accuracy: 0.84189
# Epoch = 11, Iteration = 5 Total Loss: 0.69658: Recon Loss: 0.54217: Latent Loss: 0.15441: Sparsity Loss: 0.00000: Recon Accuracy: 0.84264
# Epoch = 11, Iteration = 6 Total Loss: 0.68989: Recon Loss: 0.53838: Latent Loss: 0.15151: Sparsity Loss: 0.00000: Recon Accuracy: 0.84224
# Epoch = 12, Iteration = 0 Total Loss: 0.69135: Recon Loss: 0.54093: Latent Loss: 0.15042: Sparsity Loss: 0.00000: Recon Accuracy: 0.84177
# Epoch = 12, Iteration = 1 Total Loss: 0.68445: Recon Loss: 0.53570: Latent Loss: 0.14875: Sparsity Loss: 0.00000: Recon Accuracy: 0.84289
# Epoch = 12, Iteration = 2 Total Loss: 0.68192: Recon Loss: 0.53512: Latent Loss: 0.14680: Sparsity Loss: 0.00000: Recon Accuracy: 0.84187
# Epoch = 12, Iteration = 3 Total Loss: 0.67700: Recon Loss: 0.53100: Latent Loss: 0.14601: Sparsity Loss: 0.00000: Recon Accuracy: 0.84303
# Epoch = 12, Iteration = 4 Total Loss: 0.67640: Recon Loss: 0.53275: Latent Loss: 0.14365: Sparsity Loss: 0.00000: Recon Accuracy: 0.84296
# Epoch = 12, Iteration = 5 Total Loss: 0.67572: Recon Loss: 0.53320: Latent Loss: 0.14252: Sparsity Loss: 0.00000: Recon Accuracy: 0.84293
# Epoch = 12, Iteration = 6 Total Loss: 0.66857: Recon Loss: 0.52725: Latent Loss: 0.14132: Sparsity Loss: 0.00000: Recon Accuracy: 0.84364
# Epoch = 13, Iteration = 0 Total Loss: 0.66865: Recon Loss: 0.52872: Latent Loss: 0.13993: Sparsity Loss: 0.00000: Recon Accuracy: 0.84319
# Epoch = 13, Iteration = 1 Total Loss: 0.66125: Recon Loss: 0.52308: Latent Loss: 0.13817: Sparsity Loss: 0.00000: Recon Accuracy: 0.84522
# Epoch = 13, Iteration = 2 Total Loss: 0.66283: Recon Loss: 0.52527: Latent Loss: 0.13756: Sparsity Loss: 0.00000: Recon Accuracy: 0.84451
# Epoch = 13, Iteration = 3 Total Loss: 0.65998: Recon Loss: 0.52355: Latent Loss: 0.13643: Sparsity Loss: 0.00000: Recon Accuracy: 0.84424
# Epoch = 13, Iteration = 4 Total Loss: 0.65496: Recon Loss: 0.51972: Latent Loss: 0.13524: Sparsity Loss: 0.00000: Recon Accuracy: 0.84514
# Epoch = 13, Iteration = 5 Total Loss: 0.65607: Recon Loss: 0.52139: Latent Loss: 0.13468: Sparsity Loss: 0.00000: Recon Accuracy: 0.84500
# Epoch = 13, Iteration = 6 Total Loss: 0.65021: Recon Loss: 0.51673: Latent Loss: 0.13348: Sparsity Loss: 0.00000: Recon Accuracy: 0.84627
# Epoch = 14, Iteration = 0 Total Loss: 0.65309: Recon Loss: 0.52067: Latent Loss: 0.13243: Sparsity Loss: 0.00000: Recon Accuracy: 0.84526
# Epoch = 14, Iteration = 1 Total Loss: 0.64414: Recon Loss: 0.51289: Latent Loss: 0.13125: Sparsity Loss: 0.00000: Recon Accuracy: 0.84511
# Epoch = 14, Iteration = 2 Total Loss: 0.64477: Recon Loss: 0.51473: Latent Loss: 0.13004: Sparsity Loss: 0.00000: Recon Accuracy: 0.84551
# Epoch = 14, Iteration = 3 Total Loss: 0.64464: Recon Loss: 0.51560: Latent Loss: 0.12904: Sparsity Loss: 0.00000: Recon Accuracy: 0.84564
# Epoch = 14, Iteration = 4 Total Loss: 0.64708: Recon Loss: 0.51928: Latent Loss: 0.12780: Sparsity Loss: 0.00000: Recon Accuracy: 0.84491
# Epoch = 14, Iteration = 5 Total Loss: 0.64224: Recon Loss: 0.51464: Latent Loss: 0.12760: Sparsity Loss: 0.00000: Recon Accuracy: 0.84683
# Epoch = 14, Iteration = 6 Total Loss: 0.64706: Recon Loss: 0.52061: Latent Loss: 0.12646: Sparsity Loss: 0.00000: Recon Accuracy: 0.84402
# Epoch = 15, Iteration = 0 Total Loss: 0.63222: Recon Loss: 0.50654: Latent Loss: 0.12568: Sparsity Loss: 0.00000: Recon Accuracy: 0.84735
# Epoch = 15, Iteration = 1 Total Loss: 0.63645: Recon Loss: 0.51145: Latent Loss: 0.12500: Sparsity Loss: 0.00000: Recon Accuracy: 0.84670
# Epoch = 15, Iteration = 2 Total Loss: 0.63545: Recon Loss: 0.51162: Latent Loss: 0.12383: Sparsity Loss: 0.00000: Recon Accuracy: 0.84513
# Epoch = 15, Iteration = 3 Total Loss: 0.63196: Recon Loss: 0.50925: Latent Loss: 0.12271: Sparsity Loss: 0.00000: Recon Accuracy: 0.84628
# Epoch = 15, Iteration = 4 Total Loss: 0.63291: Recon Loss: 0.51088: Latent Loss: 0.12203: Sparsity Loss: 0.00000: Recon Accuracy: 0.84591
# Epoch = 15, Iteration = 5 Total Loss: 0.63053: Recon Loss: 0.50931: Latent Loss: 0.12122: Sparsity Loss: 0.00000: Recon Accuracy: 0.84691
# Epoch = 15, Iteration = 6 Total Loss: 0.63137: Recon Loss: 0.51044: Latent Loss: 0.12093: Sparsity Loss: 0.00000: Recon Accuracy: 0.84683
# Epoch = 16, Iteration = 0 Total Loss: 0.62391: Recon Loss: 0.50338: Latent Loss: 0.12053: Sparsity Loss: 0.00000: Recon Accuracy: 0.84789
# Epoch = 16, Iteration = 1 Total Loss: 0.62407: Recon Loss: 0.50441: Latent Loss: 0.11965: Sparsity Loss: 0.00000: Recon Accuracy: 0.84811
# Epoch = 16, Iteration = 2 Total Loss: 0.62633: Recon Loss: 0.50760: Latent Loss: 0.11873: Sparsity Loss: 0.00000: Recon Accuracy: 0.84650
# Epoch = 16, Iteration = 3 Total Loss: 0.62436: Recon Loss: 0.50619: Latent Loss: 0.11817: Sparsity Loss: 0.00000: Recon Accuracy: 0.84756
# Epoch = 16, Iteration = 4 Total Loss: 0.62103: Recon Loss: 0.50326: Latent Loss: 0.11777: Sparsity Loss: 0.00000: Recon Accuracy: 0.84805
# Epoch = 16, Iteration = 5 Total Loss: 0.61757: Recon Loss: 0.49975: Latent Loss: 0.11782: Sparsity Loss: 0.00000: Recon Accuracy: 0.84815
# Epoch = 16, Iteration = 6 Total Loss: 0.62231: Recon Loss: 0.50570: Latent Loss: 0.11661: Sparsity Loss: 0.00000: Recon Accuracy: 0.84831
# Epoch = 17, Iteration = 0 Total Loss: 0.61602: Recon Loss: 0.49967: Latent Loss: 0.11635: Sparsity Loss: 0.00000: Recon Accuracy: 0.84948
# Epoch = 17, Iteration = 1 Total Loss: 0.61775: Recon Loss: 0.50242: Latent Loss: 0.11534: Sparsity Loss: 0.00000: Recon Accuracy: 0.84942
# Epoch = 17, Iteration = 2 Total Loss: 0.61774: Recon Loss: 0.50331: Latent Loss: 0.11443: Sparsity Loss: 0.00000: Recon Accuracy: 0.84836
# Epoch = 17, Iteration = 3 Total Loss: 0.61518: Recon Loss: 0.50092: Latent Loss: 0.11426: Sparsity Loss: 0.00000: Recon Accuracy: 0.84993
# Epoch = 17, Iteration = 4 Total Loss: 0.60831: Recon Loss: 0.49428: Latent Loss: 0.11403: Sparsity Loss: 0.00000: Recon Accuracy: 0.85005
# Epoch = 17, Iteration = 5 Total Loss: 0.61571: Recon Loss: 0.50212: Latent Loss: 0.11359: Sparsity Loss: 0.00000: Recon Accuracy: 0.84948
# Epoch = 17, Iteration = 6 Total Loss: 0.61068: Recon Loss: 0.49704: Latent Loss: 0.11364: Sparsity Loss: 0.00000: Recon Accuracy: 0.85014
# Epoch = 18, Iteration = 0 Total Loss: 0.60759: Recon Loss: 0.49396: Latent Loss: 0.11364: Sparsity Loss: 0.00000: Recon Accuracy: 0.85131
# Epoch = 18, Iteration = 1 Total Loss: 0.60716: Recon Loss: 0.49426: Latent Loss: 0.11290: Sparsity Loss: 0.00000: Recon Accuracy: 0.84994
# Epoch = 18, Iteration = 2 Total Loss: 0.60407: Recon Loss: 0.49200: Latent Loss: 0.11207: Sparsity Loss: 0.00000: Recon Accuracy: 0.85051
# Epoch = 18, Iteration = 3 Total Loss: 0.60160: Recon Loss: 0.48999: Latent Loss: 0.11161: Sparsity Loss: 0.00000: Recon Accuracy: 0.85190
# Epoch = 18, Iteration = 4 Total Loss: 0.60751: Recon Loss: 0.49663: Latent Loss: 0.11088: Sparsity Loss: 0.00000: Recon Accuracy: 0.85147
# Epoch = 18, Iteration = 5 Total Loss: 0.60262: Recon Loss: 0.49239: Latent Loss: 0.11023: Sparsity Loss: 0.00000: Recon Accuracy: 0.85139
# Epoch = 18, Iteration = 6 Total Loss: 0.59963: Recon Loss: 0.48946: Latent Loss: 0.11018: Sparsity Loss: 0.00000: Recon Accuracy: 0.85370
# Epoch = 19, Iteration = 0 Total Loss: 0.60135: Recon Loss: 0.49175: Latent Loss: 0.10960: Sparsity Loss: 0.00000: Recon Accuracy: 0.85181
# Epoch = 19, Iteration = 1 Total Loss: 0.59629: Recon Loss: 0.48603: Latent Loss: 0.11026: Sparsity Loss: 0.00000: Recon Accuracy: 0.85410
# Epoch = 19, Iteration = 2 Total Loss: 0.59938: Recon Loss: 0.48811: Latent Loss: 0.11127: Sparsity Loss: 0.00000: Recon Accuracy: 0.85356
# Epoch = 19, Iteration = 3 Total Loss: 0.59737: Recon Loss: 0.48599: Latent Loss: 0.11138: Sparsity Loss: 0.00000: Recon Accuracy: 0.85340
# Epoch = 19, Iteration = 4 Total Loss: 0.59503: Recon Loss: 0.48367: Latent Loss: 0.11136: Sparsity Loss: 0.00000: Recon Accuracy: 0.85505
# Epoch = 19, Iteration = 5 Total Loss: 0.59981: Recon Loss: 0.48909: Latent Loss: 0.11072: Sparsity Loss: 0.00000: Recon Accuracy: 0.85394
# Epoch = 19, Iteration = 6 Total Loss: 0.59289: Recon Loss: 0.48262: Latent Loss: 0.11027: Sparsity Loss: 0.00000: Recon Accuracy: 0.85521
# Epoch = 20, Iteration = 0 Total Loss: 0.59400: Recon Loss: 0.48412: Latent Loss: 0.10987: Sparsity Loss: 0.00000: Recon Accuracy: 0.85521
# Epoch = 20, Iteration = 1 Total Loss: 0.58818: Recon Loss: 0.47891: Latent Loss: 0.10926: Sparsity Loss: 0.00000: Recon Accuracy: 0.85800
# Epoch = 20, Iteration = 2 Total Loss: 0.58993: Recon Loss: 0.48072: Latent Loss: 0.10921: Sparsity Loss: 0.00000: Recon Accuracy: 0.85558
# Epoch = 20, Iteration = 3 Total Loss: 0.58392: Recon Loss: 0.47493: Latent Loss: 0.10899: Sparsity Loss: 0.00000: Recon Accuracy: 0.85894
# Epoch = 20, Iteration = 4 Total Loss: 0.58511: Recon Loss: 0.47636: Latent Loss: 0.10876: Sparsity Loss: 0.00000: Recon Accuracy: 0.85776
# Epoch = 20, Iteration = 5 Total Loss: 0.58526: Recon Loss: 0.47667: Latent Loss: 0.10859: Sparsity Loss: 0.00000: Recon Accuracy: 0.85938
# Epoch = 20, Iteration = 6 Total Loss: 0.58846: Recon Loss: 0.47981: Latent Loss: 0.10864: Sparsity Loss: 0.00000: Recon Accuracy: 0.85780
# Epoch = 21, Iteration = 0 Total Loss: 0.58359: Recon Loss: 0.47445: Latent Loss: 0.10914: Sparsity Loss: 0.00000: Recon Accuracy: 0.86089
# Epoch = 21, Iteration = 1 Total Loss: 0.57470: Recon Loss: 0.46574: Latent Loss: 0.10896: Sparsity Loss: 0.00000: Recon Accuracy: 0.86169
# Epoch = 21, Iteration = 2 Total Loss: 0.58289: Recon Loss: 0.47347: Latent Loss: 0.10942: Sparsity Loss: 0.00000: Recon Accuracy: 0.86207
# Epoch = 21, Iteration = 3 Total Loss: 0.58365: Recon Loss: 0.47426: Latent Loss: 0.10938: Sparsity Loss: 0.00000: Recon Accuracy: 0.86260
# Epoch = 21, Iteration = 4 Total Loss: 0.57687: Recon Loss: 0.46707: Latent Loss: 0.10980: Sparsity Loss: 0.00000: Recon Accuracy: 0.86444
# Epoch = 21, Iteration = 5 Total Loss: 0.57362: Recon Loss: 0.46487: Latent Loss: 0.10875: Sparsity Loss: 0.00000: Recon Accuracy: 0.86417
# Epoch = 21, Iteration = 6 Total Loss: 0.57426: Recon Loss: 0.46506: Latent Loss: 0.10920: Sparsity Loss: 0.00000: Recon Accuracy: 0.86461
# Epoch = 22, Iteration = 0 Total Loss: 0.57010: Recon Loss: 0.46063: Latent Loss: 0.10946: Sparsity Loss: 0.00000: Recon Accuracy: 0.86681
# Epoch = 22, Iteration = 1 Total Loss: 0.56668: Recon Loss: 0.45695: Latent Loss: 0.10973: Sparsity Loss: 0.00000: Recon Accuracy: 0.86857
# Epoch = 22, Iteration = 2 Total Loss: 0.56691: Recon Loss: 0.45767: Latent Loss: 0.10925: Sparsity Loss: 0.00000: Recon Accuracy: 0.86809
# Epoch = 22, Iteration = 3 Total Loss: 0.56072: Recon Loss: 0.45039: Latent Loss: 0.11033: Sparsity Loss: 0.00000: Recon Accuracy: 0.87030
# Epoch = 22, Iteration = 4 Total Loss: 0.56760: Recon Loss: 0.45661: Latent Loss: 0.11099: Sparsity Loss: 0.00000: Recon Accuracy: 0.87014
# Epoch = 22, Iteration = 5 Total Loss: 0.56278: Recon Loss: 0.45098: Latent Loss: 0.11180: Sparsity Loss: 0.00000: Recon Accuracy: 0.87092
# Epoch = 22, Iteration = 6 Total Loss: 0.56345: Recon Loss: 0.45088: Latent Loss: 0.11257: Sparsity Loss: 0.00000: Recon Accuracy: 0.87170
# Epoch = 23, Iteration = 0 Total Loss: 0.56260: Recon Loss: 0.44945: Latent Loss: 0.11315: Sparsity Loss: 0.00000: Recon Accuracy: 0.87261
# Epoch = 23, Iteration = 1 Total Loss: 0.55718: Recon Loss: 0.44425: Latent Loss: 0.11293: Sparsity Loss: 0.00000: Recon Accuracy: 0.87353
# Epoch = 23, Iteration = 2 Total Loss: 0.55286: Recon Loss: 0.43949: Latent Loss: 0.11337: Sparsity Loss: 0.00000: Recon Accuracy: 0.87525
# Epoch = 23, Iteration = 3 Total Loss: 0.55260: Recon Loss: 0.43829: Latent Loss: 0.11431: Sparsity Loss: 0.00000: Recon Accuracy: 0.87558
# Epoch = 23, Iteration = 4 Total Loss: 0.54881: Recon Loss: 0.43412: Latent Loss: 0.11469: Sparsity Loss: 0.00000: Recon Accuracy: 0.87811
# Epoch = 23, Iteration = 5 Total Loss: 0.54434: Recon Loss: 0.42843: Latent Loss: 0.11591: Sparsity Loss: 0.00000: Recon Accuracy: 0.87884
# Epoch = 23, Iteration = 6 Total Loss: 0.53958: Recon Loss: 0.42328: Latent Loss: 0.11631: Sparsity Loss: 0.00000: Recon Accuracy: 0.88140
# Epoch = 24, Iteration = 0 Total Loss: 0.54527: Recon Loss: 0.42946: Latent Loss: 0.11581: Sparsity Loss: 0.00000: Recon Accuracy: 0.88149
# Epoch = 24, Iteration = 1 Total Loss: 0.54786: Recon Loss: 0.43169: Latent Loss: 0.11617: Sparsity Loss: 0.00000: Recon Accuracy: 0.88007
# Epoch = 24, Iteration = 2 Total Loss: 0.54268: Recon Loss: 0.42598: Latent Loss: 0.11671: Sparsity Loss: 0.00000: Recon Accuracy: 0.88163
# Epoch = 24, Iteration = 3 Total Loss: 0.53324: Recon Loss: 0.41680: Latent Loss: 0.11644: Sparsity Loss: 0.00000: Recon Accuracy: 0.88341
# Epoch = 24, Iteration = 4 Total Loss: 0.53108: Recon Loss: 0.41447: Latent Loss: 0.11661: Sparsity Loss: 0.00000: Recon Accuracy: 0.88409
# Epoch = 24, Iteration = 5 Total Loss: 0.53148: Recon Loss: 0.41448: Latent Loss: 0.11700: Sparsity Loss: 0.00000: Recon Accuracy: 0.88511
# Epoch = 24, Iteration = 6 Total Loss: 0.53200: Recon Loss: 0.41450: Latent Loss: 0.11750: Sparsity Loss: 0.00000: Recon Accuracy: 0.88440
# Epoch = 25, Iteration = 0 Total Loss: 0.53478: Recon Loss: 0.41680: Latent Loss: 0.11798: Sparsity Loss: 0.00000: Recon Accuracy: 0.88642
# Epoch = 25, Iteration = 1 Total Loss: 0.52721: Recon Loss: 0.41013: Latent Loss: 0.11707: Sparsity Loss: 0.00000: Recon Accuracy: 0.88754
# Epoch = 25, Iteration = 2 Total Loss: 0.53250: Recon Loss: 0.41547: Latent Loss: 0.11703: Sparsity Loss: 0.00000: Recon Accuracy: 0.88591
# Epoch = 25, Iteration = 3 Total Loss: 0.52491: Recon Loss: 0.40799: Latent Loss: 0.11692: Sparsity Loss: 0.00000: Recon Accuracy: 0.88806
# Epoch = 25, Iteration = 4 Total Loss: 0.52450: Recon Loss: 0.40746: Latent Loss: 0.11704: Sparsity Loss: 0.00000: Recon Accuracy: 0.88803
# Epoch = 25, Iteration = 5 Total Loss: 0.52819: Recon Loss: 0.41075: Latent Loss: 0.11744: Sparsity Loss: 0.00000: Recon Accuracy: 0.88828
# Epoch = 25, Iteration = 6 Total Loss: 0.51916: Recon Loss: 0.40055: Latent Loss: 0.11861: Sparsity Loss: 0.00000: Recon Accuracy: 0.88998
# Epoch = 26, Iteration = 0 Total Loss: 0.52548: Recon Loss: 0.40735: Latent Loss: 0.11813: Sparsity Loss: 0.00000: Recon Accuracy: 0.88994
# Epoch = 26, Iteration = 1 Total Loss: 0.51708: Recon Loss: 0.39917: Latent Loss: 0.11792: Sparsity Loss: 0.00000: Recon Accuracy: 0.89056
# Epoch = 26, Iteration = 2 Total Loss: 0.51554: Recon Loss: 0.39783: Latent Loss: 0.11772: Sparsity Loss: 0.00000: Recon Accuracy: 0.89094
# Epoch = 26, Iteration = 3 Total Loss: 0.51291: Recon Loss: 0.39509: Latent Loss: 0.11782: Sparsity Loss: 0.00000: Recon Accuracy: 0.89043
# Epoch = 26, Iteration = 4 Total Loss: 0.51181: Recon Loss: 0.39342: Latent Loss: 0.11840: Sparsity Loss: 0.00000: Recon Accuracy: 0.89409
# Epoch = 26, Iteration = 5 Total Loss: 0.50605: Recon Loss: 0.38800: Latent Loss: 0.11805: Sparsity Loss: 0.00000: Recon Accuracy: 0.89409
# Epoch = 26, Iteration = 6 Total Loss: 0.51387: Recon Loss: 0.39617: Latent Loss: 0.11770: Sparsity Loss: 0.00000: Recon Accuracy: 0.89336
# Epoch = 27, Iteration = 0 Total Loss: 0.50276: Recon Loss: 0.38481: Latent Loss: 0.11795: Sparsity Loss: 0.00000: Recon Accuracy: 0.89514
# Epoch = 27, Iteration = 1 Total Loss: 0.50295: Recon Loss: 0.38537: Latent Loss: 0.11758: Sparsity Loss: 0.00000: Recon Accuracy: 0.89535
# Epoch = 27, Iteration = 2 Total Loss: 0.50920: Recon Loss: 0.39183: Latent Loss: 0.11737: Sparsity Loss: 0.00000: Recon Accuracy: 0.89388
# Epoch = 27, Iteration = 3 Total Loss: 0.49953: Recon Loss: 0.38226: Latent Loss: 0.11727: Sparsity Loss: 0.00000: Recon Accuracy: 0.89648
# Epoch = 27, Iteration = 4 Total Loss: 0.50216: Recon Loss: 0.38528: Latent Loss: 0.11688: Sparsity Loss: 0.00000: Recon Accuracy: 0.89580
# Epoch = 27, Iteration = 5 Total Loss: 0.50637: Recon Loss: 0.38899: Latent Loss: 0.11738: Sparsity Loss: 0.00000: Recon Accuracy: 0.89493
# Epoch = 27, Iteration = 6 Total Loss: 0.49712: Recon Loss: 0.37989: Latent Loss: 0.11723: Sparsity Loss: 0.00000: Recon Accuracy: 0.89619
# Epoch = 28, Iteration = 0 Total Loss: 0.50149: Recon Loss: 0.38451: Latent Loss: 0.11698: Sparsity Loss: 0.00000: Recon Accuracy: 0.89614
# Epoch = 28, Iteration = 1 Total Loss: 0.49431: Recon Loss: 0.37720: Latent Loss: 0.11710: Sparsity Loss: 0.00000: Recon Accuracy: 0.89800
# Epoch = 28, Iteration = 2 Total Loss: 0.49166: Recon Loss: 0.37477: Latent Loss: 0.11689: Sparsity Loss: 0.00000: Recon Accuracy: 0.89923
# Epoch = 28, Iteration = 3 Total Loss: 0.48885: Recon Loss: 0.37213: Latent Loss: 0.11672: Sparsity Loss: 0.00000: Recon Accuracy: 0.89982
# Epoch = 28, Iteration = 4 Total Loss: 0.49168: Recon Loss: 0.37482: Latent Loss: 0.11686: Sparsity Loss: 0.00000: Recon Accuracy: 0.89940
# Epoch = 28, Iteration = 5 Total Loss: 0.49194: Recon Loss: 0.37540: Latent Loss: 0.11655: Sparsity Loss: 0.00000: Recon Accuracy: 0.90004
# Epoch = 28, Iteration = 6 Total Loss: 0.49057: Recon Loss: 0.37395: Latent Loss: 0.11662: Sparsity Loss: 0.00000: Recon Accuracy: 0.89934
# Epoch = 29, Iteration = 0 Total Loss: 0.48796: Recon Loss: 0.37140: Latent Loss: 0.11657: Sparsity Loss: 0.00000: Recon Accuracy: 0.90021
# Epoch = 29, Iteration = 1 Total Loss: 0.48661: Recon Loss: 0.37014: Latent Loss: 0.11647: Sparsity Loss: 0.00000: Recon Accuracy: 0.89977
# Epoch = 29, Iteration = 2 Total Loss: 0.48730: Recon Loss: 0.37074: Latent Loss: 0.11657: Sparsity Loss: 0.00000: Recon Accuracy: 0.90070
# Epoch = 29, Iteration = 3 Total Loss: 0.48161: Recon Loss: 0.36571: Latent Loss: 0.11590: Sparsity Loss: 0.00000: Recon Accuracy: 0.90109
# Epoch = 29, Iteration = 4 Total Loss: 0.48058: Recon Loss: 0.36474: Latent Loss: 0.11584: Sparsity Loss: 0.00000: Recon Accuracy: 0.90257
# Epoch = 29, Iteration = 5 Total Loss: 0.48051: Recon Loss: 0.36539: Latent Loss: 0.11512: Sparsity Loss: 0.00000: Recon Accuracy: 0.90173
# Epoch = 29, Iteration = 6 Total Loss: 0.48796: Recon Loss: 0.37311: Latent Loss: 0.11486: Sparsity Loss: 0.00000: Recon Accuracy: 0.90124
# Epoch = 30, Iteration = 0 Total Loss: 0.47816: Recon Loss: 0.36298: Latent Loss: 0.11519: Sparsity Loss: 0.00000: Recon Accuracy: 0.90284
# Epoch = 30, Iteration = 1 Total Loss: 0.47789: Recon Loss: 0.36349: Latent Loss: 0.11440: Sparsity Loss: 0.00000: Recon Accuracy: 0.90260
# Epoch = 30, Iteration = 2 Total Loss: 0.47697: Recon Loss: 0.36259: Latent Loss: 0.11438: Sparsity Loss: 0.00000: Recon Accuracy: 0.90361
# Epoch = 30, Iteration = 3 Total Loss: 0.47779: Recon Loss: 0.36324: Latent Loss: 0.11455: Sparsity Loss: 0.00000: Recon Accuracy: 0.90212
# Epoch = 30, Iteration = 4 Total Loss: 0.47183: Recon Loss: 0.35725: Latent Loss: 0.11458: Sparsity Loss: 0.00000: Recon Accuracy: 0.90362
# Epoch = 30, Iteration = 5 Total Loss: 0.47448: Recon Loss: 0.36007: Latent Loss: 0.11441: Sparsity Loss: 0.00000: Recon Accuracy: 0.90339
# Epoch = 30, Iteration = 6 Total Loss: 0.47210: Recon Loss: 0.35698: Latent Loss: 0.11512: Sparsity Loss: 0.00000: Recon Accuracy: 0.90456
# Epoch = 31, Iteration = 0 Total Loss: 0.47541: Recon Loss: 0.36054: Latent Loss: 0.11487: Sparsity Loss: 0.00000: Recon Accuracy: 0.90394
# Epoch = 31, Iteration = 1 Total Loss: 0.47227: Recon Loss: 0.35816: Latent Loss: 0.11411: Sparsity Loss: 0.00000: Recon Accuracy: 0.90449
# Epoch = 31, Iteration = 2 Total Loss: 0.46470: Recon Loss: 0.35015: Latent Loss: 0.11455: Sparsity Loss: 0.00000: Recon Accuracy: 0.90559
# Epoch = 31, Iteration = 3 Total Loss: 0.46644: Recon Loss: 0.35233: Latent Loss: 0.11411: Sparsity Loss: 0.00000: Recon Accuracy: 0.90495
# Epoch = 31, Iteration = 4 Total Loss: 0.46568: Recon Loss: 0.35207: Latent Loss: 0.11360: Sparsity Loss: 0.00000: Recon Accuracy: 0.90525
# Epoch = 31, Iteration = 5 Total Loss: 0.46800: Recon Loss: 0.35487: Latent Loss: 0.11313: Sparsity Loss: 0.00000: Recon Accuracy: 0.90536
# Epoch = 31, Iteration = 6 Total Loss: 0.46184: Recon Loss: 0.34850: Latent Loss: 0.11334: Sparsity Loss: 0.00000: Recon Accuracy: 0.90722
# Epoch = 32, Iteration = 0 Total Loss: 0.46239: Recon Loss: 0.34904: Latent Loss: 0.11335: Sparsity Loss: 0.00000: Recon Accuracy: 0.90725
# Epoch = 32, Iteration = 1 Total Loss: 0.46879: Recon Loss: 0.35561: Latent Loss: 0.11318: Sparsity Loss: 0.00000: Recon Accuracy: 0.90532
# Epoch = 32, Iteration = 2 Total Loss: 0.46757: Recon Loss: 0.35394: Latent Loss: 0.11362: Sparsity Loss: 0.00000: Recon Accuracy: 0.90564
# Epoch = 32, Iteration = 3 Total Loss: 0.46426: Recon Loss: 0.35124: Latent Loss: 0.11302: Sparsity Loss: 0.00000: Recon Accuracy: 0.90676
# Epoch = 32, Iteration = 4 Total Loss: 0.45771: Recon Loss: 0.34538: Latent Loss: 0.11233: Sparsity Loss: 0.00000: Recon Accuracy: 0.90754
# Epoch = 32, Iteration = 5 Total Loss: 0.45690: Recon Loss: 0.34494: Latent Loss: 0.11196: Sparsity Loss: 0.00000: Recon Accuracy: 0.90779
# Epoch = 32, Iteration = 6 Total Loss: 0.46578: Recon Loss: 0.35369: Latent Loss: 0.11209: Sparsity Loss: 0.00000: Recon Accuracy: 0.90722
# Epoch = 33, Iteration = 0 Total Loss: 0.45724: Recon Loss: 0.34533: Latent Loss: 0.11190: Sparsity Loss: 0.00000: Recon Accuracy: 0.90760
# Epoch = 33, Iteration = 1 Total Loss: 0.45952: Recon Loss: 0.34723: Latent Loss: 0.11229: Sparsity Loss: 0.00000: Recon Accuracy: 0.90757
# Epoch = 33, Iteration = 2 Total Loss: 0.46056: Recon Loss: 0.34865: Latent Loss: 0.11191: Sparsity Loss: 0.00000: Recon Accuracy: 0.90851
# Epoch = 33, Iteration = 3 Total Loss: 0.45306: Recon Loss: 0.34084: Latent Loss: 0.11223: Sparsity Loss: 0.00000: Recon Accuracy: 0.90892
# Epoch = 33, Iteration = 4 Total Loss: 0.45936: Recon Loss: 0.34710: Latent Loss: 0.11227: Sparsity Loss: 0.00000: Recon Accuracy: 0.90831
# Epoch = 33, Iteration = 5 Total Loss: 0.45095: Recon Loss: 0.33850: Latent Loss: 0.11244: Sparsity Loss: 0.00000: Recon Accuracy: 0.90973
# Epoch = 33, Iteration = 6 Total Loss: 0.44857: Recon Loss: 0.33670: Latent Loss: 0.11187: Sparsity Loss: 0.00000: Recon Accuracy: 0.90972
# Epoch = 34, Iteration = 0 Total Loss: 0.45874: Recon Loss: 0.34683: Latent Loss: 0.11191: Sparsity Loss: 0.00000: Recon Accuracy: 0.90892
# Epoch = 34, Iteration = 1 Total Loss: 0.45377: Recon Loss: 0.34123: Latent Loss: 0.11254: Sparsity Loss: 0.00000: Recon Accuracy: 0.90918
# Epoch = 34, Iteration = 2 Total Loss: 0.45127: Recon Loss: 0.33907: Latent Loss: 0.11220: Sparsity Loss: 0.00000: Recon Accuracy: 0.91136
# Epoch = 34, Iteration = 3 Total Loss: 0.45315: Recon Loss: 0.34087: Latent Loss: 0.11228: Sparsity Loss: 0.00000: Recon Accuracy: 0.90920
# Epoch = 34, Iteration = 4 Total Loss: 0.45071: Recon Loss: 0.33814: Latent Loss: 0.11257: Sparsity Loss: 0.00000: Recon Accuracy: 0.90943
# Epoch = 34, Iteration = 5 Total Loss: 0.44932: Recon Loss: 0.33706: Latent Loss: 0.11226: Sparsity Loss: 0.00000: Recon Accuracy: 0.91098
# Epoch = 34, Iteration = 6 Total Loss: 0.44188: Recon Loss: 0.33046: Latent Loss: 0.11142: Sparsity Loss: 0.00000: Recon Accuracy: 0.91171
# Epoch = 35, Iteration = 0 Total Loss: 0.44673: Recon Loss: 0.33517: Latent Loss: 0.11157: Sparsity Loss: 0.00000: Recon Accuracy: 0.91178
# Epoch = 35, Iteration = 1 Total Loss: 0.44908: Recon Loss: 0.33794: Latent Loss: 0.11114: Sparsity Loss: 0.00000: Recon Accuracy: 0.91107
# Epoch = 35, Iteration = 2 Total Loss: 0.44645: Recon Loss: 0.33477: Latent Loss: 0.11167: Sparsity Loss: 0.00000: Recon Accuracy: 0.91144
# Epoch = 35, Iteration = 3 Total Loss: 0.45051: Recon Loss: 0.33944: Latent Loss: 0.11107: Sparsity Loss: 0.00000: Recon Accuracy: 0.91087
# Epoch = 35, Iteration = 4 Total Loss: 0.44063: Recon Loss: 0.32987: Latent Loss: 0.11076: Sparsity Loss: 0.00000: Recon Accuracy: 0.91296
# Epoch = 35, Iteration = 5 Total Loss: 0.44218: Recon Loss: 0.33137: Latent Loss: 0.11082: Sparsity Loss: 0.00000: Recon Accuracy: 0.91304
# Epoch = 35, Iteration = 6 Total Loss: 0.44944: Recon Loss: 0.33864: Latent Loss: 0.11080: Sparsity Loss: 0.00000: Recon Accuracy: 0.91040
# Epoch = 36, Iteration = 0 Total Loss: 0.44654: Recon Loss: 0.33585: Latent Loss: 0.11069: Sparsity Loss: 0.00000: Recon Accuracy: 0.91096
# Epoch = 36, Iteration = 1 Total Loss: 0.44515: Recon Loss: 0.33424: Latent Loss: 0.11090: Sparsity Loss: 0.00000: Recon Accuracy: 0.91213
# Epoch = 36, Iteration = 2 Total Loss: 0.44187: Recon Loss: 0.33105: Latent Loss: 0.11082: Sparsity Loss: 0.00000: Recon Accuracy: 0.91241
# Epoch = 36, Iteration = 3 Total Loss: 0.44846: Recon Loss: 0.33823: Latent Loss: 0.11023: Sparsity Loss: 0.00000: Recon Accuracy: 0.91096
# Epoch = 36, Iteration = 4 Total Loss: 0.44224: Recon Loss: 0.33200: Latent Loss: 0.11024: Sparsity Loss: 0.00000: Recon Accuracy: 0.91432
# Epoch = 36, Iteration = 5 Total Loss: 0.44120: Recon Loss: 0.33079: Latent Loss: 0.11041: Sparsity Loss: 0.00000: Recon Accuracy: 0.91251
# Epoch = 36, Iteration = 6 Total Loss: 0.44830: Recon Loss: 0.33748: Latent Loss: 0.11082: Sparsity Loss: 0.00000: Recon Accuracy: 0.91197
# Epoch = 37, Iteration = 0 Total Loss: 0.44024: Recon Loss: 0.32944: Latent Loss: 0.11080: Sparsity Loss: 0.00000: Recon Accuracy: 0.91290
# Epoch = 37, Iteration = 1 Total Loss: 0.43898: Recon Loss: 0.32756: Latent Loss: 0.11143: Sparsity Loss: 0.00000: Recon Accuracy: 0.91399
# Epoch = 37, Iteration = 2 Total Loss: 0.44145: Recon Loss: 0.33029: Latent Loss: 0.11116: Sparsity Loss: 0.00000: Recon Accuracy: 0.91269
# Epoch = 37, Iteration = 3 Total Loss: 0.44531: Recon Loss: 0.33378: Latent Loss: 0.11153: Sparsity Loss: 0.00000: Recon Accuracy: 0.91297
# Epoch = 37, Iteration = 4 Total Loss: 0.43478: Recon Loss: 0.32370: Latent Loss: 0.11109: Sparsity Loss: 0.00000: Recon Accuracy: 0.91498
# Epoch = 37, Iteration = 5 Total Loss: 0.43764: Recon Loss: 0.32655: Latent Loss: 0.11109: Sparsity Loss: 0.00000: Recon Accuracy: 0.91367
# Epoch = 37, Iteration = 6 Total Loss: 0.43693: Recon Loss: 0.32600: Latent Loss: 0.11094: Sparsity Loss: 0.00000: Recon Accuracy: 0.91381
# Epoch = 38, Iteration = 0 Total Loss: 0.43169: Recon Loss: 0.32127: Latent Loss: 0.11042: Sparsity Loss: 0.00000: Recon Accuracy: 0.91443
# Epoch = 38, Iteration = 1 Total Loss: 0.43581: Recon Loss: 0.32444: Latent Loss: 0.11137: Sparsity Loss: 0.00000: Recon Accuracy: 0.91496
# Epoch = 38, Iteration = 2 Total Loss: 0.43662: Recon Loss: 0.32567: Latent Loss: 0.11095: Sparsity Loss: 0.00000: Recon Accuracy: 0.91423
# Epoch = 38, Iteration = 3 Total Loss: 0.43557: Recon Loss: 0.32504: Latent Loss: 0.11053: Sparsity Loss: 0.00000: Recon Accuracy: 0.91385
# Epoch = 38, Iteration = 4 Total Loss: 0.42930: Recon Loss: 0.31886: Latent Loss: 0.11044: Sparsity Loss: 0.00000: Recon Accuracy: 0.91599
# Epoch = 38, Iteration = 5 Total Loss: 0.43583: Recon Loss: 0.32513: Latent Loss: 0.11070: Sparsity Loss: 0.00000: Recon Accuracy: 0.91474
# Epoch = 38, Iteration = 6 Total Loss: 0.43398: Recon Loss: 0.32352: Latent Loss: 0.11047: Sparsity Loss: 0.00000: Recon Accuracy: 0.91523
# Epoch = 39, Iteration = 0 Total Loss: 0.43066: Recon Loss: 0.32068: Latent Loss: 0.10998: Sparsity Loss: 0.00000: Recon Accuracy: 0.91479
# Epoch = 39, Iteration = 1 Total Loss: 0.42988: Recon Loss: 0.31981: Latent Loss: 0.11007: Sparsity Loss: 0.00000: Recon Accuracy: 0.91559
# Epoch = 39, Iteration = 2 Total Loss: 0.43295: Recon Loss: 0.32306: Latent Loss: 0.10989: Sparsity Loss: 0.00000: Recon Accuracy: 0.91596
# Epoch = 39, Iteration = 3 Total Loss: 0.43367: Recon Loss: 0.32411: Latent Loss: 0.10956: Sparsity Loss: 0.00000: Recon Accuracy: 0.91552
# Epoch = 39, Iteration = 4 Total Loss: 0.42619: Recon Loss: 0.31648: Latent Loss: 0.10971: Sparsity Loss: 0.00000: Recon Accuracy: 0.91682
# Epoch = 39, Iteration = 5 Total Loss: 0.43374: Recon Loss: 0.32441: Latent Loss: 0.10933: Sparsity Loss: 0.00000: Recon Accuracy: 0.91524
# Epoch = 39, Iteration = 6 Total Loss: 0.43708: Recon Loss: 0.32820: Latent Loss: 0.10887: Sparsity Loss: 0.00000: Recon Accuracy: 0.91534
# Epoch = 40, Iteration = 0 Total Loss: 0.42710: Recon Loss: 0.31878: Latent Loss: 0.10832: Sparsity Loss: 0.00000: Recon Accuracy: 0.91638
# Epoch = 40, Iteration = 1 Total Loss: 0.42906: Recon Loss: 0.32049: Latent Loss: 0.10856: Sparsity Loss: 0.00000: Recon Accuracy: 0.91610
# Epoch = 40, Iteration = 2 Total Loss: 0.42968: Recon Loss: 0.32101: Latent Loss: 0.10867: Sparsity Loss: 0.00000: Recon Accuracy: 0.91615
# Epoch = 40, Iteration = 3 Total Loss: 0.43072: Recon Loss: 0.32175: Latent Loss: 0.10896: Sparsity Loss: 0.00000: Recon Accuracy: 0.91564
# Epoch = 40, Iteration = 4 Total Loss: 0.43072: Recon Loss: 0.32204: Latent Loss: 0.10867: Sparsity Loss: 0.00000: Recon Accuracy: 0.91618
# Epoch = 40, Iteration = 5 Total Loss: 0.42931: Recon Loss: 0.32009: Latent Loss: 0.10921: Sparsity Loss: 0.00000: Recon Accuracy: 0.91526
# Epoch = 40, Iteration = 6 Total Loss: 0.43095: Recon Loss: 0.32157: Latent Loss: 0.10938: Sparsity Loss: 0.00000: Recon Accuracy: 0.91587
# Epoch = 41, Iteration = 0 Total Loss: 0.42628: Recon Loss: 0.31713: Latent Loss: 0.10915: Sparsity Loss: 0.00000: Recon Accuracy: 0.91674
# Epoch = 41, Iteration = 1 Total Loss: 0.42750: Recon Loss: 0.31819: Latent Loss: 0.10930: Sparsity Loss: 0.00000: Recon Accuracy: 0.91580
# Epoch = 41, Iteration = 2 Total Loss: 0.42121: Recon Loss: 0.31121: Latent Loss: 0.11000: Sparsity Loss: 0.00000: Recon Accuracy: 0.91828
# Epoch = 41, Iteration = 3 Total Loss: 0.42857: Recon Loss: 0.31865: Latent Loss: 0.10993: Sparsity Loss: 0.00000: Recon Accuracy: 0.91632
# Epoch = 41, Iteration = 4 Total Loss: 0.42655: Recon Loss: 0.31693: Latent Loss: 0.10962: Sparsity Loss: 0.00000: Recon Accuracy: 0.91724
# Epoch = 41, Iteration = 5 Total Loss: 0.43088: Recon Loss: 0.32151: Latent Loss: 0.10937: Sparsity Loss: 0.00000: Recon Accuracy: 0.91598
# Epoch = 41, Iteration = 6 Total Loss: 0.42215: Recon Loss: 0.31300: Latent Loss: 0.10916: Sparsity Loss: 0.00000: Recon Accuracy: 0.91814
# Epoch = 42, Iteration = 0 Total Loss: 0.42731: Recon Loss: 0.31779: Latent Loss: 0.10952: Sparsity Loss: 0.00000: Recon Accuracy: 0.91778
# Epoch = 42, Iteration = 1 Total Loss: 0.42384: Recon Loss: 0.31476: Latent Loss: 0.10907: Sparsity Loss: 0.00000: Recon Accuracy: 0.91803
# Epoch = 42, Iteration = 2 Total Loss: 0.42244: Recon Loss: 0.31341: Latent Loss: 0.10903: Sparsity Loss: 0.00000: Recon Accuracy: 0.91748
# Epoch = 42, Iteration = 3 Total Loss: 0.42167: Recon Loss: 0.31199: Latent Loss: 0.10968: Sparsity Loss: 0.00000: Recon Accuracy: 0.91695
# Epoch = 42, Iteration = 4 Total Loss: 0.42324: Recon Loss: 0.31442: Latent Loss: 0.10882: Sparsity Loss: 0.00000: Recon Accuracy: 0.91704
# Epoch = 42, Iteration = 5 Total Loss: 0.42542: Recon Loss: 0.31666: Latent Loss: 0.10877: Sparsity Loss: 0.00000: Recon Accuracy: 0.91630
# Epoch = 42, Iteration = 6 Total Loss: 0.42640: Recon Loss: 0.31744: Latent Loss: 0.10896: Sparsity Loss: 0.00000: Recon Accuracy: 0.91655
# Epoch = 43, Iteration = 0 Total Loss: 0.42550: Recon Loss: 0.31738: Latent Loss: 0.10811: Sparsity Loss: 0.00000: Recon Accuracy: 0.91689
# Epoch = 43, Iteration = 1 Total Loss: 0.42278: Recon Loss: 0.31349: Latent Loss: 0.10929: Sparsity Loss: 0.00000: Recon Accuracy: 0.91735
# Epoch = 43, Iteration = 2 Total Loss: 0.41918: Recon Loss: 0.30994: Latent Loss: 0.10925: Sparsity Loss: 0.00000: Recon Accuracy: 0.91838
# Epoch = 43, Iteration = 3 Total Loss: 0.42371: Recon Loss: 0.31473: Latent Loss: 0.10899: Sparsity Loss: 0.00000: Recon Accuracy: 0.91743
# Epoch = 43, Iteration = 4 Total Loss: 0.41762: Recon Loss: 0.30873: Latent Loss: 0.10889: Sparsity Loss: 0.00000: Recon Accuracy: 0.91831
# Epoch = 43, Iteration = 5 Total Loss: 0.42344: Recon Loss: 0.31421: Latent Loss: 0.10924: Sparsity Loss: 0.00000: Recon Accuracy: 0.91811
# Epoch = 43, Iteration = 6 Total Loss: 0.42122: Recon Loss: 0.31279: Latent Loss: 0.10843: Sparsity Loss: 0.00000: Recon Accuracy: 0.91769
# Epoch = 44, Iteration = 0 Total Loss: 0.42542: Recon Loss: 0.31615: Latent Loss: 0.10927: Sparsity Loss: 0.00000: Recon Accuracy: 0.91737
# Epoch = 44, Iteration = 1 Total Loss: 0.42461: Recon Loss: 0.31508: Latent Loss: 0.10952: Sparsity Loss: 0.00000: Recon Accuracy: 0.91701
# Epoch = 44, Iteration = 2 Total Loss: 0.42104: Recon Loss: 0.31118: Latent Loss: 0.10985: Sparsity Loss: 0.00000: Recon Accuracy: 0.91780
# Epoch = 44, Iteration = 3 Total Loss: 0.41741: Recon Loss: 0.30781: Latent Loss: 0.10960: Sparsity Loss: 0.00000: Recon Accuracy: 0.91924
# Epoch = 44, Iteration = 4 Total Loss: 0.41516: Recon Loss: 0.30565: Latent Loss: 0.10951: Sparsity Loss: 0.00000: Recon Accuracy: 0.91934
# Epoch = 44, Iteration = 5 Total Loss: 0.41815: Recon Loss: 0.30888: Latent Loss: 0.10927: Sparsity Loss: 0.00000: Recon Accuracy: 0.91925
# Epoch = 44, Iteration = 6 Total Loss: 0.41950: Recon Loss: 0.31074: Latent Loss: 0.10876: Sparsity Loss: 0.00000: Recon Accuracy: 0.91819
# Epoch = 45, Iteration = 0 Total Loss: 0.41937: Recon Loss: 0.31059: Latent Loss: 0.10878: Sparsity Loss: 0.00000: Recon Accuracy: 0.91911
# Epoch = 45, Iteration = 1 Total Loss: 0.42010: Recon Loss: 0.31134: Latent Loss: 0.10876: Sparsity Loss: 0.00000: Recon Accuracy: 0.91824
# Epoch = 45, Iteration = 2 Total Loss: 0.41423: Recon Loss: 0.30568: Latent Loss: 0.10855: Sparsity Loss: 0.00000: Recon Accuracy: 0.91977
# Epoch = 45, Iteration = 3 Total Loss: 0.42144: Recon Loss: 0.31286: Latent Loss: 0.10859: Sparsity Loss: 0.00000: Recon Accuracy: 0.91782
# Epoch = 45, Iteration = 4 Total Loss: 0.41908: Recon Loss: 0.31046: Latent Loss: 0.10862: Sparsity Loss: 0.00000: Recon Accuracy: 0.91922
# Epoch = 45, Iteration = 5 Total Loss: 0.41757: Recon Loss: 0.30900: Latent Loss: 0.10856: Sparsity Loss: 0.00000: Recon Accuracy: 0.91913
# Epoch = 45, Iteration = 6 Total Loss: 0.41595: Recon Loss: 0.30776: Latent Loss: 0.10819: Sparsity Loss: 0.00000: Recon Accuracy: 0.91828
# Epoch = 46, Iteration = 0 Total Loss: 0.42304: Recon Loss: 0.31481: Latent Loss: 0.10823: Sparsity Loss: 0.00000: Recon Accuracy: 0.91868
# Epoch = 46, Iteration = 1 Total Loss: 0.41719: Recon Loss: 0.30956: Latent Loss: 0.10763: Sparsity Loss: 0.00000: Recon Accuracy: 0.91778
# Epoch = 46, Iteration = 2 Total Loss: 0.41385: Recon Loss: 0.30599: Latent Loss: 0.10786: Sparsity Loss: 0.00000: Recon Accuracy: 0.91923
# Epoch = 46, Iteration = 3 Total Loss: 0.41131: Recon Loss: 0.30310: Latent Loss: 0.10821: Sparsity Loss: 0.00000: Recon Accuracy: 0.92102
# Epoch = 46, Iteration = 4 Total Loss: 0.41440: Recon Loss: 0.30653: Latent Loss: 0.10787: Sparsity Loss: 0.00000: Recon Accuracy: 0.91928
# Epoch = 46, Iteration = 5 Total Loss: 0.41919: Recon Loss: 0.31131: Latent Loss: 0.10788: Sparsity Loss: 0.00000: Recon Accuracy: 0.91938
# Epoch = 46, Iteration = 6 Total Loss: 0.41009: Recon Loss: 0.30177: Latent Loss: 0.10832: Sparsity Loss: 0.00000: Recon Accuracy: 0.92032
# Epoch = 47, Iteration = 0 Total Loss: 0.40832: Recon Loss: 0.30016: Latent Loss: 0.10816: Sparsity Loss: 0.00000: Recon Accuracy: 0.92066
# Epoch = 47, Iteration = 1 Total Loss: 0.40978: Recon Loss: 0.30216: Latent Loss: 0.10762: Sparsity Loss: 0.00000: Recon Accuracy: 0.91963
# Epoch = 47, Iteration = 2 Total Loss: 0.41445: Recon Loss: 0.30718: Latent Loss: 0.10727: Sparsity Loss: 0.00000: Recon Accuracy: 0.91952
# Epoch = 47, Iteration = 3 Total Loss: 0.41523: Recon Loss: 0.30816: Latent Loss: 0.10707: Sparsity Loss: 0.00000: Recon Accuracy: 0.91987
# Epoch = 47, Iteration = 4 Total Loss: 0.41372: Recon Loss: 0.30708: Latent Loss: 0.10664: Sparsity Loss: 0.00000: Recon Accuracy: 0.92004
# Epoch = 47, Iteration = 5 Total Loss: 0.41619: Recon Loss: 0.30931: Latent Loss: 0.10689: Sparsity Loss: 0.00000: Recon Accuracy: 0.91876
# Epoch = 47, Iteration = 6 Total Loss: 0.41640: Recon Loss: 0.30989: Latent Loss: 0.10651: Sparsity Loss: 0.00000: Recon Accuracy: 0.91898
# Epoch = 48, Iteration = 0 Total Loss: 0.41403: Recon Loss: 0.30737: Latent Loss: 0.10665: Sparsity Loss: 0.00000: Recon Accuracy: 0.92019
# Epoch = 48, Iteration = 1 Total Loss: 0.41056: Recon Loss: 0.30406: Latent Loss: 0.10650: Sparsity Loss: 0.00000: Recon Accuracy: 0.92001
# Epoch = 48, Iteration = 2 Total Loss: 0.41085: Recon Loss: 0.30443: Latent Loss: 0.10642: Sparsity Loss: 0.00000: Recon Accuracy: 0.92027
# Epoch = 48, Iteration = 3 Total Loss: 0.41128: Recon Loss: 0.30430: Latent Loss: 0.10698: Sparsity Loss: 0.00000: Recon Accuracy: 0.92091
# Epoch = 48, Iteration = 4 Total Loss: 0.41684: Recon Loss: 0.30989: Latent Loss: 0.10694: Sparsity Loss: 0.00000: Recon Accuracy: 0.91929
# Epoch = 48, Iteration = 5 Total Loss: 0.41063: Recon Loss: 0.30411: Latent Loss: 0.10652: Sparsity Loss: 0.00000: Recon Accuracy: 0.92043
# Epoch = 48, Iteration = 6 Total Loss: 0.41552: Recon Loss: 0.30882: Latent Loss: 0.10670: Sparsity Loss: 0.00000: Recon Accuracy: 0.91904
# Epoch = 49, Iteration = 0 Total Loss: 0.40547: Recon Loss: 0.29769: Latent Loss: 0.10778: Sparsity Loss: 0.00000: Recon Accuracy: 0.92157
# Epoch = 49, Iteration = 1 Total Loss: 0.40809: Recon Loss: 0.30069: Latent Loss: 0.10740: Sparsity Loss: 0.00000: Recon Accuracy: 0.92091
# Epoch = 49, Iteration = 2 Total Loss: 0.40755: Recon Loss: 0.30032: Latent Loss: 0.10722: Sparsity Loss: 0.00000: Recon Accuracy: 0.92091
# Epoch = 49, Iteration = 3 Total Loss: 0.41243: Recon Loss: 0.30545: Latent Loss: 0.10698: Sparsity Loss: 0.00000: Recon Accuracy: 0.91958
# Epoch = 49, Iteration = 4 Total Loss: 0.40780: Recon Loss: 0.30125: Latent Loss: 0.10655: Sparsity Loss: 0.00000: Recon Accuracy: 0.92108
# Epoch = 49, Iteration = 5 Total Loss: 0.41002: Recon Loss: 0.30353: Latent Loss: 0.10649: Sparsity Loss: 0.00000: Recon Accuracy: 0.92004
# Epoch = 49, Iteration = 6 Total Loss: 0.40906: Recon Loss: 0.30205: Latent Loss: 0.10701: Sparsity Loss: 0.00000: Recon Accuracy: 0.92029
# Epoch = 50, Iteration = 0 Total Loss: 0.40809: Recon Loss: 0.30112: Latent Loss: 0.10697: Sparsity Loss: 0.00000: Recon Accuracy: 0.92045
# Epoch = 50, Iteration = 1 Total Loss: 0.41043: Recon Loss: 0.30321: Latent Loss: 0.10722: Sparsity Loss: 0.00000: Recon Accuracy: 0.92024
# Epoch = 50, Iteration = 2 Total Loss: 0.40823: Recon Loss: 0.30152: Latent Loss: 0.10671: Sparsity Loss: 0.00000: Recon Accuracy: 0.92060
# Epoch = 50, Iteration = 3 Total Loss: 0.40946: Recon Loss: 0.30239: Latent Loss: 0.10707: Sparsity Loss: 0.00000: Recon Accuracy: 0.92034
# Epoch = 50, Iteration = 4 Total Loss: 0.40925: Recon Loss: 0.30235: Latent Loss: 0.10691: Sparsity Loss: 0.00000: Recon Accuracy: 0.92137
# Epoch = 50, Iteration = 5 Total Loss: 0.40309: Recon Loss: 0.29609: Latent Loss: 0.10700: Sparsity Loss: 0.00000: Recon Accuracy: 0.92182
# Epoch = 50, Iteration = 6 Total Loss: 0.40404: Recon Loss: 0.29733: Latent Loss: 0.10671: Sparsity Loss: 0.00000: Recon Accuracy: 0.92232
# Epoch = 51, Iteration = 0 Total Loss: 0.40732: Recon Loss: 0.30070: Latent Loss: 0.10661: Sparsity Loss: 0.00000: Recon Accuracy: 0.92133
# Epoch = 51, Iteration = 1 Total Loss: 0.40033: Recon Loss: 0.29404: Latent Loss: 0.10630: Sparsity Loss: 0.00000: Recon Accuracy: 0.92160
# Epoch = 51, Iteration = 2 Total Loss: 0.40418: Recon Loss: 0.29790: Latent Loss: 0.10628: Sparsity Loss: 0.00000: Recon Accuracy: 0.92191
# Epoch = 51, Iteration = 3 Total Loss: 0.40877: Recon Loss: 0.30321: Latent Loss: 0.10555: Sparsity Loss: 0.00000: Recon Accuracy: 0.92094
# Epoch = 51, Iteration = 4 Total Loss: 0.40288: Recon Loss: 0.29682: Latent Loss: 0.10606: Sparsity Loss: 0.00000: Recon Accuracy: 0.92120
# Epoch = 51, Iteration = 5 Total Loss: 0.40456: Recon Loss: 0.29891: Latent Loss: 0.10565: Sparsity Loss: 0.00000: Recon Accuracy: 0.92132
# Epoch = 51, Iteration = 6 Total Loss: 0.40696: Recon Loss: 0.30135: Latent Loss: 0.10561: Sparsity Loss: 0.00000: Recon Accuracy: 0.92121
# Epoch = 52, Iteration = 0 Total Loss: 0.40205: Recon Loss: 0.29683: Latent Loss: 0.10521: Sparsity Loss: 0.00000: Recon Accuracy: 0.92185
# Epoch = 52, Iteration = 1 Total Loss: 0.40744: Recon Loss: 0.30235: Latent Loss: 0.10509: Sparsity Loss: 0.00000: Recon Accuracy: 0.92151
# Epoch = 52, Iteration = 2 Total Loss: 0.40556: Recon Loss: 0.30070: Latent Loss: 0.10486: Sparsity Loss: 0.00000: Recon Accuracy: 0.92145
# Epoch = 52, Iteration = 3 Total Loss: 0.40224: Recon Loss: 0.29705: Latent Loss: 0.10518: Sparsity Loss: 0.00000: Recon Accuracy: 0.92175
# Epoch = 52, Iteration = 4 Total Loss: 0.40661: Recon Loss: 0.30107: Latent Loss: 0.10554: Sparsity Loss: 0.00000: Recon Accuracy: 0.92149
# Epoch = 52, Iteration = 5 Total Loss: 0.40465: Recon Loss: 0.29932: Latent Loss: 0.10534: Sparsity Loss: 0.00000: Recon Accuracy: 0.92072
# Epoch = 52, Iteration = 6 Total Loss: 0.40697: Recon Loss: 0.30162: Latent Loss: 0.10535: Sparsity Loss: 0.00000: Recon Accuracy: 0.92139
# Epoch = 53, Iteration = 0 Total Loss: 0.40342: Recon Loss: 0.29774: Latent Loss: 0.10569: Sparsity Loss: 0.00000: Recon Accuracy: 0.92270
# Epoch = 53, Iteration = 1 Total Loss: 0.40496: Recon Loss: 0.29979: Latent Loss: 0.10517: Sparsity Loss: 0.00000: Recon Accuracy: 0.92168
# Epoch = 53, Iteration = 2 Total Loss: 0.40518: Recon Loss: 0.30047: Latent Loss: 0.10471: Sparsity Loss: 0.00000: Recon Accuracy: 0.92210
# Epoch = 53, Iteration = 3 Total Loss: 0.40201: Recon Loss: 0.29670: Latent Loss: 0.10530: Sparsity Loss: 0.00000: Recon Accuracy: 0.92225
# Epoch = 53, Iteration = 4 Total Loss: 0.40351: Recon Loss: 0.29797: Latent Loss: 0.10554: Sparsity Loss: 0.00000: Recon Accuracy: 0.92195
# Epoch = 53, Iteration = 5 Total Loss: 0.41088: Recon Loss: 0.30528: Latent Loss: 0.10560: Sparsity Loss: 0.00000: Recon Accuracy: 0.92092
# Epoch = 53, Iteration = 6 Total Loss: 0.40776: Recon Loss: 0.30168: Latent Loss: 0.10609: Sparsity Loss: 0.00000: Recon Accuracy: 0.92170
# Epoch = 54, Iteration = 0 Total Loss: 0.40735: Recon Loss: 0.30117: Latent Loss: 0.10617: Sparsity Loss: 0.00000: Recon Accuracy: 0.92188
# Reconstruction Accuracy: 0.92186
# INFO:tensorflow:TCR_Analysis\models\model_0\model.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Training Done
# DeepTCR VAE training completed!

# %%
import pandas as pd

def extract_features_from_DTCRU(DTCRU):
    """
    Extracts latent features along with CDR3 sequences, V-beta, J-beta, and labels into a DataFrame.

    Args:
        DTCRU: The feature_analytics_class instance.

    Returns:
        Pandas DataFrame containing:
        - Features (latent embeddings)
        - CDR3 Beta Sequences
        - V_beta, J_beta
        - Labels (Sample/Cluster ID)
    """

    # Convert latent features to DataFrame
    feature_df = pd.DataFrame(DTCRU.features)

    # Convert sequence data to DataFrame
    metadata_df = pd.DataFrame({
        "CDR3_Beta": DTCRU.beta_sequences,
        "V_Beta": DTCRU.v_beta,
        "J_Beta": DTCRU.j_beta,
        "Label": DTCRU.sample_id  # Use sample_id as labels
    })

    # Merge latent features with metadata
    full_df = pd.concat([metadata_df, feature_df], axis=1)

    return full_df

# Usage:
features_df = extract_features_from_DTCRU(DTCRU)

# Save to CSV if needed
features_df.to_csv("/global/scratch/users/zhoufd/TCR/saved_data/DTCRU_extracted_features_96.csv", index=False)

#features_df

# %%
# # Reduce clusters by lowering PhenoGraph resolution (t)
# DTCRU.Cluster(
#     clustering_method='phenograph',  # Keep PhenoGraph clustering
#     t=5,                     # Lower resolution (default ~30); reduce for fewer clusters
#     n_jobs=4                 # Use multiple threads for efficiency
# )
DTCRU.Cluster(
    set='all', 
    clustering_method='dbscan',  # Use DBSCAN
    t=6,  # Higher values merge clusters (default is auto-tuned)
    n_jobs=4
)
# Out:
# Clustering Done

# %%
DFs = DTCRU.Cluster_DFs
len(DFs)
# Out:
# 202

# %%
print(DFs[0])
# Out:
#      index Alpha_Sequences    Beta_Sequences V_alpha J_alpha V_beta D_beta  \
# 0        0            None  CTCSADPGVNQDTQYF    None    None  TRBV1   None
# 1      155            None     CTCSAADKDTQYF    None    None  TRBV1   None
# 2      199            None    CTCSPGQGEDTQYF    None    None  TRBV1   None
# 3      816            None   CTCSADWGIQDTQYF    None    None  TRBV1   None
# 4      958            None   CTCSAQTGGMNTQYF    None    None  TRBV1   None
# ..     ...             ...               ...     ...     ...    ...    ...
# 214  17816            None    CTCSADRWGIAQYF    None    None  TRBV1   None
# 215  17836            None    CTCSADRREDTQYF    None    None  TRBV1   None
# 216  17840            None   CTCSADTGAQDTQYF    None    None  TRBV1   None
# 217  17846            None     CTCSADSRDTQYF    None    None  TRBV1   None
# 218  17854            None  CTCSADSGLGQDTQYF    None    None  TRBV1   None
#
#       J_beta  Frequency  Labels  \
# 0    TRBJ2-5   0.025740     CNS
# 1    TRBJ2-5   0.000746     CNS
# 2    TRBJ2-5   0.000622     CNS
# 3    TRBJ2-5   0.000187     CNS
# 4    TRBJ2-5   0.000187     CNS
# ..       ...        ...     ...
# 214  TRBJ2-5   0.000029  Spleen
# 215  TRBJ2-5   0.000029  Spleen
# 216  TRBJ2-5   0.000029  Spleen
# 217  TRBJ2-5   0.000029  Spleen
# 218  TRBJ2-5   0.000029  Spleen
#
#                                                 Sample           HLA
# 0    E:\Python code\Machine learning\JupyterNote\Bi...  [N, o, n, e]
# 1    E:\Python code\Machine learning\JupyterNote\Bi...  [N, o, n, e]
# 2    E:\Python code\Machine learning\JupyterNote\Bi...  [N, o, n, e]
# 3    E:\Python code\Machine learning\JupyterNote\Bi...  [N, o, n, e]
# 4    E:\Python code\Machine learning\JupyterNote\Bi...  [N, o, n, e]
# ..                                                 ...           ...
# 214  E:\Python code\Machine learning\JupyterNote\Bi...  [N, o, n, e]
# 215  E:\Python code\Machine learning\JupyterNote\Bi...  [N, o, n, e]
# 216  E:\Python code\Machine learning\JupyterNote\Bi...  [N, o, n, e]
# 217  E:\Python code\Machine learning\JupyterNote\Bi...  [N, o, n, e]
# 218  E:\Python code\Machine learning\JupyterNote\Bi...  [N, o, n, e]
#
# [219 rows x 12 columns]

# %%
# import matplotlib.pyplot as plt

# # Initialize lists to store cluster indices and weighted CNS proportions
# cluster_ids = []
# cns_proportions = []

# # Iterate through clusters and compute weighted CNS proportions
# for i, df in enumerate(DFs):
#     total_freq = df["Frequency"].sum()  # Sum of frequencies in cluster
#     cns_freq = df.loc[df["Labels"] == "CNS", "Frequency"].sum()  # Sum of CNS frequencies
    
#     # Avoid division by zero
#     cns_ratio = cns_freq #/ total_freq if total_freq > 0 else 0
    
#     cluster_ids.append(i + 1)  # Cluster numbers start from 1
#     cns_proportions.append(cns_ratio)

# # Plot CNS proportion per cluster
# plt.figure(figsize=(12, 6))
# plt.bar(cluster_ids, cns_proportions, color="dodgerblue")

# plt.xlabel("Cluster")
# plt.ylabel("CNS Proportion (Weighted by Frequency)")
# plt.title("Weighted Proportion of CNS Sequences in Each Cluster")
# #plt.ylim(0, 1)  # Set proportion range between 0 and 1
# plt.xticks(rotation=90)  # Rotate x-axis labels if needed
# plt.show()
# import matplotlib.pyplot as plt

# # Initialize lists to store cluster indices and weighted CNS proportions
# cluster_ids = []
# cns_proportions = []

# # Iterate through clusters and compute weighted CNS proportions
# for i, df in enumerate(DFs):
#     total_freq = df["Frequency"].sum()  # Sum of frequencies in cluster
#     cns_freq = df.loc[df["Labels"] == "Spleen", "Frequency"].sum()  # Sum of CNS frequencies
    
#     # Avoid division by zero
#     cns_ratio = cns_freq #/ total_freq if total_freq > 0 else 0
    
#     cluster_ids.append(i + 1)  # Cluster numbers start from 1
#     cns_proportions.append(cns_ratio)

# # Plot CNS proportion per cluster
# plt.figure(figsize=(12, 6))
# plt.bar(cluster_ids, cns_proportions, color="dodgerblue")

# plt.xlabel("Cluster")
# plt.ylabel("Spleen Proportion (Weighted by Frequency)")
# plt.title("Weighted Proportion of CNS Sequences in Each Cluster")
# #plt.ylim(0, 1)  # Set proportion range between 0 and 1
# plt.xticks(rotation=90)  # Rotate x-axis labels if needed
# plt.show()

# %%
DTCRU.HeatMap_Sequences()

# %%
DTCRU.Structural_Diversity()
# Out:
# Finding 30 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.8308298587799072 seconds
# Jaccard graph constructed in 5.451005697250366 seconds
# Wrote graph to binary file in 0.24482178688049316 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.995881
# Louvain completed 21 runs in 6.028345584869385 seconds
# PhenoGraph complete in 13.627702236175537 seconds

# %%
DTCRU.Structural_Diversity_DF
# Out:
#                                               Sample   Class   Entropy  \
# 0  E:\Python code\Machine learning\JupyterNote\Bi...     CNS  5.514615
# 1  E:\Python code\Machine learning\JupyterNote\Bi...  Spleen  5.883617
#
#    Num of Clusters
# 0              389
# 1              389

# %%
# Extract normalized frequency and sample IDs from DeepTCR
import numpy as np

normalized_freq = np.array(DTCRU.freq)  # Already normalized per sample
sample_ids = np.array(DTCRU.sample_id)

# Count the number of sequences in CNS and Spleen
num_cns = np.sum(sample_ids == "CNS.tsv")
num_spleen = np.sum(sample_ids == "Spleen.tsv")

# Compute rescaling factor: adjust Spleen frequencies to match CNS scale
scale_factor = num_spleen / num_cns

# Rescale the Spleen frequencies only
adjusted_freq = np.where(sample_ids == "Spleen.tsv", normalized_freq * scale_factor, normalized_freq)
DTCRU.freq = adjusted_freq

# %%
DTCRU.freq
# Out:
# array([2.57398657e-02, 1.89007710e-02, 1.57299179e-02, ...,
#        2.87860906e-05, 2.87860906e-05, 2.87860906e-05])

# %%
scale_factor
# Out:
# nan

# %%
num_cns
# Out:
# 0

# %%
num_spleen
# Out:
# 0

# %%
DTCRU.freq
# Out:
# array([2.57398657e-02, 1.89007710e-02, 1.57299179e-02, ...,
#        2.87860906e-05, 2.87860906e-05, 2.87860906e-05])

# %%
DTCRU.UMAP_Plot(Load_Prev_Data=True,by_sample=True, show_legend=True,freq_weight=True,scale=10000) #by_cluster=True,by_cluster=True,freq_weight=True
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 DTCRU.UMAP_Plot(Load_Prev_Data=True,by_sample=True, show_legend=True,freq_weight=True,scale=10000)
#
# File E:\Python code\Machine learning\JupyterNote\Bio\deepTCR\DeepTCR\DeepTCR.py:1707, in vis_class.UMAP_Plot(self, set, by_class, by_cluster, by_sample, freq_weight, show_legend, scale, Load_Prev_Data, alpha, sample, sample_per_class, filename, prob_plot, plot_by_class)
#    1705         pickle.dump([X_2,features,class_id,sample_id,freq,IDX,idx], f, protocol=4)
#    1706 else:
# -> 1707     with open(os.path.join(self.Name, 'umap.pkl'), 'rb') as f:
#    1708         X_2,features,class_id,sample_id,freq,IDX,idx = pickle.load(f)
#    1710 df_plot = pd.DataFrame()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TCR_Analysis\\umap.pkl'

# %%
DTCRU.UMAP_Plot(Load_Prev_Data=True,by_cluster=True, show_legend=False,freq_weight=True,scale=5000)

# %% [markdown]
# ### Comparison between GIANA embeddings and DeepTCR embeddings

# %%
import pandas as pd

# %%
DTCRU_features_df = pd.read_csv("/global/scratch/users/zhoufd/TCR/saved_data/DTCRU_extracted_features_96.csv")

# %%
DTCRU_features_df

# %%
# File paths
embedding_path = "/global/scratch/users/zhoufd/TCR/packages/GIANA/GIANA_output_no_trbv/giana_merged_trbv_strict_filter--RotationEncodingBL62.txt_EncodingMatrix.txt"


# Load GIANA embeddings
GIANA_features_df = pd.read_csv(embedding_path, sep="\t", header=None)
GIANA_features_df

# %%
esm_features_df = pd.read_csv("/global/scratch/users/zhoufd/TCR/saved_data/tcr_esm2_pca96.csv",)

esm_features_df

# %%
import numpy as np
esm_features_df = esm_features_df.iloc[:, np.r_[0, 2:esm_features_df.shape[1]]]
DTCRU_features_df = DTCRU_features_df.iloc[:, np.r_[0, 4:DTCRU_features_df.shape[1]]]
GIANA_features_df = GIANA_features_df.iloc[:, np.r_[0, 2:GIANA_features_df.shape[1]]]

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import pdist, squareform

# Step 1: Ensure unique CDR3_Beta sequences by averaging embeddings if duplicated
DTCRU_unique = DTCRU_features_df.groupby("CDR3_Beta").mean().reset_index()
GIANA_unique = GIANA_features_df.groupby(0).mean().reset_index()  # Column 0 contains CDR3_Beta in GIANA
esm_unique = esm_features_df.groupby("cdr3").mean().reset_index()

# Step 2: Find the common CDR3 sequences among all three datasets
common_cdr3 = set(DTCRU_unique["CDR3_Beta"]).intersection(GIANA_unique[0]).intersection(esm_unique["cdr3"])

# Step 3: Keep only common sequences and sort them
DTCRU_matched = DTCRU_unique[DTCRU_unique["CDR3_Beta"].isin(common_cdr3)].sort_values("CDR3_Beta").reset_index(drop=True)
GIANA_matched = GIANA_unique[GIANA_unique[0].isin(common_cdr3)].sort_values(by=0).reset_index(drop=True)
esm_matched = esm_unique[esm_unique["cdr3"].isin(common_cdr3)].sort_values("cdr3").reset_index(drop=True)

# Step 4: Extract embeddings
DTCRU_embeddings = DTCRU_matched.iloc[:, 1:].values  # Exclude CDR3_Beta (first column)
GIANA_embeddings = GIANA_matched.iloc[:, 1:].values  # Exclude CDR3_Beta (first column)
esm_embeddings = esm_matched.iloc[:, 1:].values  # Exclude cdr3 (first column)

# Step 5: Compute pairwise distances within each embedding space
DTCRU_distances = squareform(pdist(DTCRU_embeddings, metric="euclidean"))
GIANA_distances = squareform(pdist(GIANA_embeddings, metric="euclidean"))
esm_distances = squareform(pdist(esm_embeddings, metric="euclidean"))

# Step 6: Flatten upper triangle of the distance matrices for correlation analysis
DTCRU_distances_flat = DTCRU_distances[np.triu_indices_from(DTCRU_distances, k=1)]
GIANA_distances_flat = GIANA_distances[np.triu_indices_from(GIANA_distances, k=1)]
esm_distances_flat = esm_distances[np.triu_indices_from(esm_distances, k=1)]

# %%
import numpy as np
from scipy.stats import spearmanr

# Randomly subsample 100,000 pairs for faster correlation
sample_size = min(100000, len(DTCRU_distances_flat))  # Adjust sample size if needed
indices = np.random.choice(len(DTCRU_distances_flat), size=sample_size, replace=False)

# Compute Spearman on subsampled data
spearman_DG, p_DG = spearmanr(DTCRU_distances_flat[indices], GIANA_distances_flat[indices])
spearman_DE, p_DE = spearmanr(DTCRU_distances_flat[indices], esm_distances_flat[indices])
spearman_GE, p_GE = spearmanr(GIANA_distances_flat[indices], esm_distances_flat[indices])
results = pd.DataFrame({
    "Comparison": ["DTCRU vs GIANA", "DTCRU vs ESM", "GIANA vs ESM"],
    "Spearman Correlation": [spearman_DG, spearman_DE, spearman_GE],
    "p-value": [p_DG, p_DE, p_GE]
})
results

# %%
DTCRU_features_df.shape

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, homogeneity_completeness_v_measure
import pandas as pd

# Perform K-Means clustering for all three datasets
DTCRU_clusters = KMeans(n_clusters=10, random_state=1, n_init=10).fit_predict(DTCRU_embeddings)
GIANA_clusters = KMeans(n_clusters=10, random_state=1, n_init=10).fit_predict(GIANA_embeddings)
ESM_clusters = KMeans(n_clusters=10, random_state=1, n_init=10).fit_predict(esm_embeddings)

# Compute clustering similarity scores for all pairs
ari_DG = adjusted_rand_score(DTCRU_clusters, GIANA_clusters)  # DTCRU vs GIANA
ari_DE = adjusted_rand_score(DTCRU_clusters, ESM_clusters)    # DTCRU vs ESM
ari_GE = adjusted_rand_score(GIANA_clusters, ESM_clusters)    # GIANA vs ESM

nmi_DG = normalized_mutual_info_score(DTCRU_clusters, GIANA_clusters)
nmi_DE = normalized_mutual_info_score(DTCRU_clusters, ESM_clusters)
nmi_GE = normalized_mutual_info_score(GIANA_clusters, ESM_clusters)

hom_DG, comp_DG, v_DG = homogeneity_completeness_v_measure(DTCRU_clusters, GIANA_clusters)
hom_DE, comp_DE, v_DE = homogeneity_completeness_v_measure(DTCRU_clusters, ESM_clusters)
hom_GE, comp_GE, v_GE = homogeneity_completeness_v_measure(GIANA_clusters, ESM_clusters)

# Organize results in a DataFrame
clustering_results = pd.DataFrame({
    "Comparison": ["DTCRU vs GIANA", "DTCRU vs ESM", "GIANA vs ESM"],
    "ARI": [ari_DG, ari_DE, ari_GE],
    "NMI": [nmi_DG, nmi_DE, nmi_GE],
    "Homogeneity": [hom_DG, hom_DE, hom_GE],
    "Completeness": [comp_DG, comp_DE, comp_GE],
    "V-Measure": [v_DG, v_DE, v_GE]
})
clustering_results

# %%
import umap
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Reduce dimensionality using only GIANA embeddings
umap_giana = umap.UMAP(n_components=2).fit_transform(GIANA_embeddings)

# Create dataframe for UMAP representation
df_umap = pd.DataFrame(umap_giana, columns=["UMAP1", "UMAP2"])
df_umap["DTCRU_Cluster"] = pd.Categorical(DTCRU_clusters)  # DTCRU clusters
df_umap["GIANA_Cluster"] = pd.Categorical(GIANA_clusters)  # GIANA clusters
df_umap["ESM_Cluster"] = pd.Categorical(ESM_clusters)  # ESM clusters

# Set up a 3x1 subplot (3 plots)
fig, axes = plt.subplots(3, 1, figsize=(6, 15))
titles = ["DTCRU Clusters (UMAP GIANA)", "GIANA Clusters (UMAP GIANA)", "ESM Clusters (UMAP GIANA)"]

# Define color palettes
dtcru_palette = sns.color_palette("tab10", len(df_umap["DTCRU_Cluster"].unique()))
giana_palette = sns.color_palette("tab10", len(df_umap["GIANA_Cluster"].unique()))
esm_palette = sns.color_palette("tab10", len(df_umap["ESM_Cluster"].unique()))

# Plot 1: DTCRU Clusters using GIANA UMAP
sns.scatterplot(data=df_umap, x="UMAP1", y="UMAP2", hue="DTCRU_Cluster", palette=dtcru_palette, alpha=0.6, s=5, ax=axes[0])
axes[0].set_title(titles[0])
axes[0].legend_.remove()

# Plot 2: GIANA Clusters using GIANA UMAP
sns.scatterplot(data=df_umap, x="UMAP1", y="UMAP2", hue="GIANA_Cluster", palette=giana_palette, alpha=0.6, s=5, ax=axes[1])
axes[1].set_title(titles[1])
axes[1].legend_.remove()

# Plot 3: ESM Clusters using GIANA UMAP
sns.scatterplot(data=df_umap, x="UMAP1", y="UMAP2", hue="ESM_Cluster", palette=esm_palette, alpha=0.6, s=5, ax=axes[2])
axes[2].set_title(titles[2])
axes[2].legend_.remove()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create pairwise contingency tables
contingency_DG = pd.crosstab(DTCRU_clusters, GIANA_clusters)
contingency_DE = pd.crosstab(DTCRU_clusters, ESM_clusters)
contingency_GE = pd.crosstab(GIANA_clusters, ESM_clusters)

# Function to plot heatmap
def plot_heatmap(contingency_table, xlabel, ylabel, title):
    plt.figure(figsize=(6, 5))
    sns.heatmap(contingency_table, annot=True, fmt="d", cmap="Blues", linewidths=0.5)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# Plot each heatmap
plot_heatmap(contingency_DG, "GIANA Clusters", "DeepTCR Clusters", "DeepTCR vs GIANA Clusters")
plot_heatmap(contingency_DE, "ESM Clusters", "DeepTCR Clusters", "DeepTCR vs ESM Clusters")
plot_heatmap(contingency_GE, "ESM Clusters", "GIANA Clusters", "GIANA vs ESM Clusters")
