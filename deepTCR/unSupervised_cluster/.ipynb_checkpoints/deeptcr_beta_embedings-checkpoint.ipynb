# %% [markdown]
# # Load muData

# %%
import sys
print("Python executable:", sys.executable)
print("Python version:", sys.version)
# Out:
# Python executable: E:\Anaconda\envs\tf_old\python.exe
# Python version: 3.9.18 (main, Sep 11 2023, 14:09:26) [MSC v.1916 64 bit (AMD64)]

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd

# %%
# import os
# script_dir = os.getcwd()
# data_path = os.path.join(script_dir, "DeepTCR_input", "EAE_all_cells", "all", "airr_test.tsv")

# airr_beta = pd.read_csv(data_path, sep='\t')
# airr_beta

# %%
# airr_sub = airr_beta.iloc[::2]
# airr_sub.to_csv('airr_test_sub.tsv', sep= '\t', index=False)

# %%
# airr_beta.to_csv('airr_test_2.tsv', sep = '\t', index=False)

# %% [markdown]
# ## Training

# %%
from DeepTCR.DeepTCR import DeepTCR_U

# %%
# Instantiate training object
DTCRU = DeepTCR_U('TCR_all')

# Load Data from CNS & Spleen directories
DTCRU.Get_Data(directory='DeepTCR_input/EAE_all_cells/all/', 
               Load_Prev_Data=False, aggregate_by_aa=True,
               aa_column_beta=1, count_column=4, v_beta_column=2, j_beta_column=3)

print("Data loaded successfully into DeepTCR!")
# Out:
# Loading Data...
# Embedding Sequences...
# Data Loaded
# Data loaded successfully into DeepTCR!

# %%
# Train Variational Autoencoder (VAE) with adjusted parameters
DTCRU.Train_VAE(
    latent_dim=96,          # Reduce latent dimension to prevent overfitting on 20K sequences
    batch_size=5000,         # Reduce batch size to prevent memory overload
    epochs_min=5,            # Ensure at least 5 training epochs
    stop_criterion_window=30, # Increase patience for stopping
    learning_rate=0.001,    # Slightly slower learning rate for better stability
    Load_Prev_Data=False     # Ensure fresh training
)

print("DeepTCR VAE training completed!")
# Out:
# Epoch = 0, Iteration = 0 Total Loss: 7.16725: Recon Loss: 7.13645: Latent Loss: 0.03080: Sparsity Loss: 0.00000: Recon Accuracy: 0.06258
# Epoch = 0, Iteration = 1 Total Loss: 6.92101: Recon Loss: 6.89072: Latent Loss: 0.03029: Sparsity Loss: 0.00000: Recon Accuracy: 0.07289
# Epoch = 0, Iteration = 2 Total Loss: 6.75453: Recon Loss: 6.72335: Latent Loss: 0.03118: Sparsity Loss: 0.00000: Recon Accuracy: 0.08455
# Epoch = 0, Iteration = 3 Total Loss: 6.64321: Recon Loss: 6.60864: Latent Loss: 0.03457: Sparsity Loss: 0.00000: Recon Accuracy: 0.10722
# Epoch = 0, Iteration = 4 Total Loss: 6.57832: Recon Loss: 6.53717: Latent Loss: 0.04115: Sparsity Loss: 0.00000: Recon Accuracy: 0.12020
# Epoch = 0, Iteration = 5 Total Loss: 6.50165: Recon Loss: 6.45497: Latent Loss: 0.04668: Sparsity Loss: 0.00000: Recon Accuracy: 0.13319
# Epoch = 0, Iteration = 6 Total Loss: 6.40378: Recon Loss: 6.35958: Latent Loss: 0.04420: Sparsity Loss: 0.00000: Recon Accuracy: 0.14718
# Epoch = 0, Iteration = 7 Total Loss: 6.33011: Recon Loss: 6.28994: Latent Loss: 0.04017: Sparsity Loss: 0.00000: Recon Accuracy: 0.15968
# Epoch = 0, Iteration = 8 Total Loss: 6.25131: Recon Loss: 6.21456: Latent Loss: 0.03675: Sparsity Loss: 0.00000: Recon Accuracy: 0.17603
# Epoch = 0, Iteration = 9 Total Loss: 6.13831: Recon Loss: 6.10366: Latent Loss: 0.03465: Sparsity Loss: 0.00000: Recon Accuracy: 0.18576
# Epoch = 0, Iteration = 10 Total Loss: 6.10675: Recon Loss: 6.07267: Latent Loss: 0.03408: Sparsity Loss: 0.00000: Recon Accuracy: 0.19076
# Epoch = 1, Iteration = 0 Total Loss: 5.92386: Recon Loss: 5.89017: Latent Loss: 0.03369: Sparsity Loss: 0.00000: Recon Accuracy: 0.22247
# Epoch = 1, Iteration = 1 Total Loss: 5.77519: Recon Loss: 5.74133: Latent Loss: 0.03386: Sparsity Loss: 0.00000: Recon Accuracy: 0.25141
# Epoch = 1, Iteration = 2 Total Loss: 5.63405: Recon Loss: 5.59836: Latent Loss: 0.03569: Sparsity Loss: 0.00000: Recon Accuracy: 0.27841
# Epoch = 1, Iteration = 3 Total Loss: 5.44961: Recon Loss: 5.41034: Latent Loss: 0.03927: Sparsity Loss: 0.00000: Recon Accuracy: 0.30142
# Epoch = 1, Iteration = 4 Total Loss: 5.25861: Recon Loss: 5.21444: Latent Loss: 0.04417: Sparsity Loss: 0.00000: Recon Accuracy: 0.32659
# Epoch = 1, Iteration = 5 Total Loss: 5.12086: Recon Loss: 5.07221: Latent Loss: 0.04865: Sparsity Loss: 0.00000: Recon Accuracy: 0.34907
# Epoch = 1, Iteration = 6 Total Loss: 4.81451: Recon Loss: 4.75946: Latent Loss: 0.05505: Sparsity Loss: 0.00000: Recon Accuracy: 0.38326
# Epoch = 1, Iteration = 7 Total Loss: 4.59375: Recon Loss: 4.52871: Latent Loss: 0.06503: Sparsity Loss: 0.00000: Recon Accuracy: 0.40639
# Epoch = 1, Iteration = 8 Total Loss: 4.32720: Recon Loss: 4.24552: Latent Loss: 0.08168: Sparsity Loss: 0.00000: Recon Accuracy: 0.43238
# Epoch = 1, Iteration = 9 Total Loss: 4.11307: Recon Loss: 4.01386: Latent Loss: 0.09921: Sparsity Loss: 0.00000: Recon Accuracy: 0.46792
# Epoch = 1, Iteration = 10 Total Loss: 3.89963: Recon Loss: 3.77993: Latent Loss: 0.11970: Sparsity Loss: 0.00000: Recon Accuracy: 0.48424
# Epoch = 2, Iteration = 0 Total Loss: 3.70220: Recon Loss: 3.58488: Latent Loss: 0.11731: Sparsity Loss: 0.00000: Recon Accuracy: 0.51728
# Epoch = 2, Iteration = 1 Total Loss: 3.59257: Recon Loss: 3.47751: Latent Loss: 0.11506: Sparsity Loss: 0.00000: Recon Accuracy: 0.54349
# Epoch = 2, Iteration = 2 Total Loss: 3.24467: Recon Loss: 3.13090: Latent Loss: 0.11377: Sparsity Loss: 0.00000: Recon Accuracy: 0.58296
# Epoch = 2, Iteration = 3 Total Loss: 3.15207: Recon Loss: 3.03097: Latent Loss: 0.12110: Sparsity Loss: 0.00000: Recon Accuracy: 0.59124
# Epoch = 2, Iteration = 4 Total Loss: 2.98199: Recon Loss: 2.85732: Latent Loss: 0.12467: Sparsity Loss: 0.00000: Recon Accuracy: 0.60389
# Epoch = 2, Iteration = 5 Total Loss: 2.74203: Recon Loss: 2.61216: Latent Loss: 0.12986: Sparsity Loss: 0.00000: Recon Accuracy: 0.62489
# Epoch = 2, Iteration = 6 Total Loss: 2.64806: Recon Loss: 2.51286: Latent Loss: 0.13520: Sparsity Loss: 0.00000: Recon Accuracy: 0.63677
# Epoch = 2, Iteration = 7 Total Loss: 2.45535: Recon Loss: 2.31048: Latent Loss: 0.14487: Sparsity Loss: 0.00000: Recon Accuracy: 0.65659
# Epoch = 2, Iteration = 8 Total Loss: 2.34049: Recon Loss: 2.18683: Latent Loss: 0.15367: Sparsity Loss: 0.00000: Recon Accuracy: 0.66832
# Epoch = 2, Iteration = 9 Total Loss: 2.23454: Recon Loss: 2.07431: Latent Loss: 0.16023: Sparsity Loss: 0.00000: Recon Accuracy: 0.68011
# Epoch = 2, Iteration = 10 Total Loss: 2.21815: Recon Loss: 2.05317: Latent Loss: 0.16498: Sparsity Loss: 0.00000: Recon Accuracy: 0.67328
# Epoch = 3, Iteration = 0 Total Loss: 2.00486: Recon Loss: 1.82701: Latent Loss: 0.17785: Sparsity Loss: 0.00000: Recon Accuracy: 0.70048
# Epoch = 3, Iteration = 1 Total Loss: 1.89306: Recon Loss: 1.70390: Latent Loss: 0.18916: Sparsity Loss: 0.00000: Recon Accuracy: 0.71751
# Epoch = 3, Iteration = 2 Total Loss: 1.84666: Recon Loss: 1.64652: Latent Loss: 0.20014: Sparsity Loss: 0.00000: Recon Accuracy: 0.72669
# Epoch = 3, Iteration = 3 Total Loss: 1.70808: Recon Loss: 1.50223: Latent Loss: 0.20586: Sparsity Loss: 0.00000: Recon Accuracy: 0.74249
# Epoch = 3, Iteration = 4 Total Loss: 1.63260: Recon Loss: 1.42478: Latent Loss: 0.20782: Sparsity Loss: 0.00000: Recon Accuracy: 0.74641
# Epoch = 3, Iteration = 5 Total Loss: 1.54704: Recon Loss: 1.33661: Latent Loss: 0.21043: Sparsity Loss: 0.00000: Recon Accuracy: 0.75764
# Epoch = 3, Iteration = 6 Total Loss: 1.48282: Recon Loss: 1.26612: Latent Loss: 0.21669: Sparsity Loss: 0.00000: Recon Accuracy: 0.76590
# Epoch = 3, Iteration = 7 Total Loss: 1.45282: Recon Loss: 1.23254: Latent Loss: 0.22027: Sparsity Loss: 0.00000: Recon Accuracy: 0.77166
# Epoch = 3, Iteration = 8 Total Loss: 1.35385: Recon Loss: 1.13072: Latent Loss: 0.22313: Sparsity Loss: 0.00000: Recon Accuracy: 0.77830
# Epoch = 3, Iteration = 9 Total Loss: 1.30688: Recon Loss: 1.08375: Latent Loss: 0.22313: Sparsity Loss: 0.00000: Recon Accuracy: 0.78313
# Epoch = 3, Iteration = 10 Total Loss: 1.26859: Recon Loss: 1.04561: Latent Loss: 0.22298: Sparsity Loss: 0.00000: Recon Accuracy: 0.77864
# Epoch = 4, Iteration = 0 Total Loss: 1.20729: Recon Loss: 0.98414: Latent Loss: 0.22315: Sparsity Loss: 0.00000: Recon Accuracy: 0.79337
# Epoch = 4, Iteration = 1 Total Loss: 1.18006: Recon Loss: 0.95550: Latent Loss: 0.22456: Sparsity Loss: 0.00000: Recon Accuracy: 0.79799
# Epoch = 4, Iteration = 2 Total Loss: 1.13881: Recon Loss: 0.91280: Latent Loss: 0.22602: Sparsity Loss: 0.00000: Recon Accuracy: 0.79997
# Epoch = 4, Iteration = 3 Total Loss: 1.12628: Recon Loss: 0.89985: Latent Loss: 0.22643: Sparsity Loss: 0.00000: Recon Accuracy: 0.80033
# Epoch = 4, Iteration = 4 Total Loss: 1.05552: Recon Loss: 0.82793: Latent Loss: 0.22759: Sparsity Loss: 0.00000: Recon Accuracy: 0.80793
# Epoch = 4, Iteration = 5 Total Loss: 1.06174: Recon Loss: 0.83545: Latent Loss: 0.22630: Sparsity Loss: 0.00000: Recon Accuracy: 0.80520
# Epoch = 4, Iteration = 6 Total Loss: 1.02657: Recon Loss: 0.80051: Latent Loss: 0.22606: Sparsity Loss: 0.00000: Recon Accuracy: 0.80742
# Epoch = 4, Iteration = 7 Total Loss: 0.99719: Recon Loss: 0.77054: Latent Loss: 0.22664: Sparsity Loss: 0.00000: Recon Accuracy: 0.81181
# Epoch = 4, Iteration = 8 Total Loss: 0.97559: Recon Loss: 0.74682: Latent Loss: 0.22877: Sparsity Loss: 0.00000: Recon Accuracy: 0.81368
# Epoch = 4, Iteration = 9 Total Loss: 0.96298: Recon Loss: 0.73367: Latent Loss: 0.22931: Sparsity Loss: 0.00000: Recon Accuracy: 0.81515
# Epoch = 4, Iteration = 10 Total Loss: 0.93868: Recon Loss: 0.70732: Latent Loss: 0.23136: Sparsity Loss: 0.00000: Recon Accuracy: 0.81633
# Epoch = 5, Iteration = 0 Total Loss: 0.93382: Recon Loss: 0.70754: Latent Loss: 0.22628: Sparsity Loss: 0.00000: Recon Accuracy: 0.81755
# Epoch = 5, Iteration = 1 Total Loss: 0.93213: Recon Loss: 0.70794: Latent Loss: 0.22419: Sparsity Loss: 0.00000: Recon Accuracy: 0.81531
# Epoch = 5, Iteration = 2 Total Loss: 0.91751: Recon Loss: 0.69742: Latent Loss: 0.22009: Sparsity Loss: 0.00000: Recon Accuracy: 0.81825
# Epoch = 5, Iteration = 3 Total Loss: 0.90052: Recon Loss: 0.68043: Latent Loss: 0.22009: Sparsity Loss: 0.00000: Recon Accuracy: 0.81959
# Epoch = 5, Iteration = 4 Total Loss: 0.87329: Recon Loss: 0.65476: Latent Loss: 0.21853: Sparsity Loss: 0.00000: Recon Accuracy: 0.82179
# Epoch = 5, Iteration = 5 Total Loss: 0.86780: Recon Loss: 0.65010: Latent Loss: 0.21769: Sparsity Loss: 0.00000: Recon Accuracy: 0.82326
# Epoch = 5, Iteration = 6 Total Loss: 0.85015: Recon Loss: 0.63198: Latent Loss: 0.21817: Sparsity Loss: 0.00000: Recon Accuracy: 0.82381
# Epoch = 5, Iteration = 7 Total Loss: 0.84386: Recon Loss: 0.62742: Latent Loss: 0.21644: Sparsity Loss: 0.00000: Recon Accuracy: 0.82411
# Epoch = 5, Iteration = 8 Total Loss: 0.83097: Recon Loss: 0.61885: Latent Loss: 0.21212: Sparsity Loss: 0.00000: Recon Accuracy: 0.82492
# Epoch = 5, Iteration = 9 Total Loss: 0.82231: Recon Loss: 0.61255: Latent Loss: 0.20976: Sparsity Loss: 0.00000: Recon Accuracy: 0.82704
# Epoch = 5, Iteration = 10 Total Loss: 0.80427: Recon Loss: 0.59718: Latent Loss: 0.20709: Sparsity Loss: 0.00000: Recon Accuracy: 0.82799
# Epoch = 6, Iteration = 0 Total Loss: 0.81012: Recon Loss: 0.60458: Latent Loss: 0.20554: Sparsity Loss: 0.00000: Recon Accuracy: 0.82796
# Epoch = 6, Iteration = 1 Total Loss: 0.80523: Recon Loss: 0.60330: Latent Loss: 0.20193: Sparsity Loss: 0.00000: Recon Accuracy: 0.82831
# Epoch = 6, Iteration = 2 Total Loss: 0.79695: Recon Loss: 0.59816: Latent Loss: 0.19879: Sparsity Loss: 0.00000: Recon Accuracy: 0.82896
# Epoch = 6, Iteration = 3 Total Loss: 0.79195: Recon Loss: 0.59415: Latent Loss: 0.19780: Sparsity Loss: 0.00000: Recon Accuracy: 0.82877
# Epoch = 6, Iteration = 4 Total Loss: 0.78903: Recon Loss: 0.59307: Latent Loss: 0.19596: Sparsity Loss: 0.00000: Recon Accuracy: 0.83025
# Epoch = 6, Iteration = 5 Total Loss: 0.78420: Recon Loss: 0.58951: Latent Loss: 0.19469: Sparsity Loss: 0.00000: Recon Accuracy: 0.83127
# Epoch = 6, Iteration = 6 Total Loss: 0.77642: Recon Loss: 0.58469: Latent Loss: 0.19172: Sparsity Loss: 0.00000: Recon Accuracy: 0.83179
# Epoch = 6, Iteration = 7 Total Loss: 0.77292: Recon Loss: 0.58425: Latent Loss: 0.18867: Sparsity Loss: 0.00000: Recon Accuracy: 0.83070
# Epoch = 6, Iteration = 8 Total Loss: 0.76511: Recon Loss: 0.57892: Latent Loss: 0.18619: Sparsity Loss: 0.00000: Recon Accuracy: 0.83072
# Epoch = 6, Iteration = 9 Total Loss: 0.76036: Recon Loss: 0.57525: Latent Loss: 0.18511: Sparsity Loss: 0.00000: Recon Accuracy: 0.83120
# Epoch = 6, Iteration = 10 Total Loss: 0.75987: Recon Loss: 0.57725: Latent Loss: 0.18262: Sparsity Loss: 0.00000: Recon Accuracy: 0.83157
# Epoch = 7, Iteration = 0 Total Loss: 0.75378: Recon Loss: 0.57489: Latent Loss: 0.17889: Sparsity Loss: 0.00000: Recon Accuracy: 0.83259
# Epoch = 7, Iteration = 1 Total Loss: 0.75529: Recon Loss: 0.57810: Latent Loss: 0.17719: Sparsity Loss: 0.00000: Recon Accuracy: 0.83197
# Epoch = 7, Iteration = 2 Total Loss: 0.75213: Recon Loss: 0.57765: Latent Loss: 0.17447: Sparsity Loss: 0.00000: Recon Accuracy: 0.83188
# Epoch = 7, Iteration = 3 Total Loss: 0.73803: Recon Loss: 0.56547: Latent Loss: 0.17255: Sparsity Loss: 0.00000: Recon Accuracy: 0.83357
# Epoch = 7, Iteration = 4 Total Loss: 0.74325: Recon Loss: 0.57174: Latent Loss: 0.17152: Sparsity Loss: 0.00000: Recon Accuracy: 0.83258
# Epoch = 7, Iteration = 5 Total Loss: 0.73548: Recon Loss: 0.56617: Latent Loss: 0.16931: Sparsity Loss: 0.00000: Recon Accuracy: 0.83295
# Epoch = 7, Iteration = 6 Total Loss: 0.73838: Recon Loss: 0.57020: Latent Loss: 0.16818: Sparsity Loss: 0.00000: Recon Accuracy: 0.83268
# Epoch = 7, Iteration = 7 Total Loss: 0.73278: Recon Loss: 0.56704: Latent Loss: 0.16574: Sparsity Loss: 0.00000: Recon Accuracy: 0.83249
# Epoch = 7, Iteration = 8 Total Loss: 0.72543: Recon Loss: 0.56161: Latent Loss: 0.16382: Sparsity Loss: 0.00000: Recon Accuracy: 0.83440
# Epoch = 7, Iteration = 9 Total Loss: 0.72496: Recon Loss: 0.56116: Latent Loss: 0.16380: Sparsity Loss: 0.00000: Recon Accuracy: 0.83338
# Epoch = 7, Iteration = 10 Total Loss: 0.73494: Recon Loss: 0.57414: Latent Loss: 0.16080: Sparsity Loss: 0.00000: Recon Accuracy: 0.83420
# Epoch = 8, Iteration = 0 Total Loss: 0.71936: Recon Loss: 0.55956: Latent Loss: 0.15980: Sparsity Loss: 0.00000: Recon Accuracy: 0.83354
# Epoch = 8, Iteration = 1 Total Loss: 0.71978: Recon Loss: 0.56238: Latent Loss: 0.15740: Sparsity Loss: 0.00000: Recon Accuracy: 0.83354
# Epoch = 8, Iteration = 2 Total Loss: 0.71292: Recon Loss: 0.55640: Latent Loss: 0.15652: Sparsity Loss: 0.00000: Recon Accuracy: 0.83611
# Epoch = 8, Iteration = 3 Total Loss: 0.70793: Recon Loss: 0.55405: Latent Loss: 0.15387: Sparsity Loss: 0.00000: Recon Accuracy: 0.83450
# Epoch = 8, Iteration = 4 Total Loss: 0.70508: Recon Loss: 0.55173: Latent Loss: 0.15336: Sparsity Loss: 0.00000: Recon Accuracy: 0.83630
# Epoch = 8, Iteration = 5 Total Loss: 0.70660: Recon Loss: 0.55524: Latent Loss: 0.15137: Sparsity Loss: 0.00000: Recon Accuracy: 0.83492
# Epoch = 8, Iteration = 6 Total Loss: 0.70695: Recon Loss: 0.55563: Latent Loss: 0.15131: Sparsity Loss: 0.00000: Recon Accuracy: 0.83647
# Epoch = 8, Iteration = 7 Total Loss: 0.70123: Recon Loss: 0.55216: Latent Loss: 0.14907: Sparsity Loss: 0.00000: Recon Accuracy: 0.83600
# Epoch = 8, Iteration = 8 Total Loss: 0.70137: Recon Loss: 0.55287: Latent Loss: 0.14850: Sparsity Loss: 0.00000: Recon Accuracy: 0.83621
# Epoch = 8, Iteration = 9 Total Loss: 0.70146: Recon Loss: 0.55303: Latent Loss: 0.14844: Sparsity Loss: 0.00000: Recon Accuracy: 0.83769
# Epoch = 8, Iteration = 10 Total Loss: 0.71681: Recon Loss: 0.56879: Latent Loss: 0.14801: Sparsity Loss: 0.00000: Recon Accuracy: 0.83922
# Epoch = 9, Iteration = 0 Total Loss: 0.68974: Recon Loss: 0.54434: Latent Loss: 0.14540: Sparsity Loss: 0.00000: Recon Accuracy: 0.83817
# Epoch = 9, Iteration = 1 Total Loss: 0.69032: Recon Loss: 0.54724: Latent Loss: 0.14307: Sparsity Loss: 0.00000: Recon Accuracy: 0.83808
# Epoch = 9, Iteration = 2 Total Loss: 0.68304: Recon Loss: 0.54081: Latent Loss: 0.14223: Sparsity Loss: 0.00000: Recon Accuracy: 0.83902
# Epoch = 9, Iteration = 3 Total Loss: 0.68287: Recon Loss: 0.54087: Latent Loss: 0.14200: Sparsity Loss: 0.00000: Recon Accuracy: 0.83922
# Epoch = 9, Iteration = 4 Total Loss: 0.68817: Recon Loss: 0.54607: Latent Loss: 0.14209: Sparsity Loss: 0.00000: Recon Accuracy: 0.83826
# Epoch = 9, Iteration = 5 Total Loss: 0.68756: Recon Loss: 0.54584: Latent Loss: 0.14172: Sparsity Loss: 0.00000: Recon Accuracy: 0.83860
# Epoch = 9, Iteration = 6 Total Loss: 0.68056: Recon Loss: 0.53924: Latent Loss: 0.14132: Sparsity Loss: 0.00000: Recon Accuracy: 0.83941
# Epoch = 9, Iteration = 7 Total Loss: 0.68136: Recon Loss: 0.54018: Latent Loss: 0.14117: Sparsity Loss: 0.00000: Recon Accuracy: 0.83983
# Epoch = 9, Iteration = 8 Total Loss: 0.67672: Recon Loss: 0.53765: Latent Loss: 0.13907: Sparsity Loss: 0.00000: Recon Accuracy: 0.83956
# Epoch = 9, Iteration = 9 Total Loss: 0.67271: Recon Loss: 0.53403: Latent Loss: 0.13869: Sparsity Loss: 0.00000: Recon Accuracy: 0.84081
# Epoch = 9, Iteration = 10 Total Loss: 0.67341: Recon Loss: 0.53635: Latent Loss: 0.13706: Sparsity Loss: 0.00000: Recon Accuracy: 0.84322
# Epoch = 10, Iteration = 0 Total Loss: 0.66972: Recon Loss: 0.53408: Latent Loss: 0.13564: Sparsity Loss: 0.00000: Recon Accuracy: 0.84044
# Epoch = 10, Iteration = 1 Total Loss: 0.67615: Recon Loss: 0.54132: Latent Loss: 0.13483: Sparsity Loss: 0.00000: Recon Accuracy: 0.84078
# Epoch = 10, Iteration = 2 Total Loss: 0.67237: Recon Loss: 0.53792: Latent Loss: 0.13445: Sparsity Loss: 0.00000: Recon Accuracy: 0.83972
# Epoch = 10, Iteration = 3 Total Loss: 0.66230: Recon Loss: 0.52687: Latent Loss: 0.13543: Sparsity Loss: 0.00000: Recon Accuracy: 0.84108
# Epoch = 10, Iteration = 4 Total Loss: 0.66743: Recon Loss: 0.53361: Latent Loss: 0.13382: Sparsity Loss: 0.00000: Recon Accuracy: 0.83973
# Epoch = 10, Iteration = 5 Total Loss: 0.67153: Recon Loss: 0.53709: Latent Loss: 0.13444: Sparsity Loss: 0.00000: Recon Accuracy: 0.83925
# Epoch = 10, Iteration = 6 Total Loss: 0.66340: Recon Loss: 0.53017: Latent Loss: 0.13324: Sparsity Loss: 0.00000: Recon Accuracy: 0.84077
# Epoch = 10, Iteration = 7 Total Loss: 0.66369: Recon Loss: 0.53115: Latent Loss: 0.13254: Sparsity Loss: 0.00000: Recon Accuracy: 0.84250
# Epoch = 10, Iteration = 8 Total Loss: 0.65671: Recon Loss: 0.52453: Latent Loss: 0.13217: Sparsity Loss: 0.00000: Recon Accuracy: 0.84203
# Epoch = 10, Iteration = 9 Total Loss: 0.65886: Recon Loss: 0.52764: Latent Loss: 0.13122: Sparsity Loss: 0.00000: Recon Accuracy: 0.84242
# Epoch = 10, Iteration = 10 Total Loss: 0.65183: Recon Loss: 0.52101: Latent Loss: 0.13083: Sparsity Loss: 0.00000: Recon Accuracy: 0.84337
# Epoch = 11, Iteration = 0 Total Loss: 0.65726: Recon Loss: 0.52690: Latent Loss: 0.13037: Sparsity Loss: 0.00000: Recon Accuracy: 0.84239
# Epoch = 11, Iteration = 1 Total Loss: 0.66053: Recon Loss: 0.53061: Latent Loss: 0.12992: Sparsity Loss: 0.00000: Recon Accuracy: 0.84236
# Epoch = 11, Iteration = 2 Total Loss: 0.65416: Recon Loss: 0.52450: Latent Loss: 0.12966: Sparsity Loss: 0.00000: Recon Accuracy: 0.84335
# Epoch = 11, Iteration = 3 Total Loss: 0.64489: Recon Loss: 0.51510: Latent Loss: 0.12979: Sparsity Loss: 0.00000: Recon Accuracy: 0.84435
# Epoch = 11, Iteration = 4 Total Loss: 0.65210: Recon Loss: 0.52353: Latent Loss: 0.12856: Sparsity Loss: 0.00000: Recon Accuracy: 0.84290
# Epoch = 11, Iteration = 5 Total Loss: 0.64990: Recon Loss: 0.52160: Latent Loss: 0.12830: Sparsity Loss: 0.00000: Recon Accuracy: 0.84262
# Epoch = 11, Iteration = 6 Total Loss: 0.64780: Recon Loss: 0.52009: Latent Loss: 0.12771: Sparsity Loss: 0.00000: Recon Accuracy: 0.84316
# Epoch = 11, Iteration = 7 Total Loss: 0.64670: Recon Loss: 0.51973: Latent Loss: 0.12697: Sparsity Loss: 0.00000: Recon Accuracy: 0.84304
# Epoch = 11, Iteration = 8 Total Loss: 0.64810: Recon Loss: 0.52221: Latent Loss: 0.12589: Sparsity Loss: 0.00000: Recon Accuracy: 0.84277
# Epoch = 11, Iteration = 9 Total Loss: 0.64105: Recon Loss: 0.51523: Latent Loss: 0.12582: Sparsity Loss: 0.00000: Recon Accuracy: 0.84499
# Epoch = 11, Iteration = 10 Total Loss: 0.62659: Recon Loss: 0.50210: Latent Loss: 0.12450: Sparsity Loss: 0.00000: Recon Accuracy: 0.84970
# Epoch = 12, Iteration = 0 Total Loss: 0.64166: Recon Loss: 0.51715: Latent Loss: 0.12451: Sparsity Loss: 0.00000: Recon Accuracy: 0.84383
# Epoch = 12, Iteration = 1 Total Loss: 0.64452: Recon Loss: 0.51950: Latent Loss: 0.12502: Sparsity Loss: 0.00000: Recon Accuracy: 0.84448
# Epoch = 12, Iteration = 2 Total Loss: 0.63568: Recon Loss: 0.51269: Latent Loss: 0.12299: Sparsity Loss: 0.00000: Recon Accuracy: 0.84621
# Epoch = 12, Iteration = 3 Total Loss: 0.63424: Recon Loss: 0.51219: Latent Loss: 0.12204: Sparsity Loss: 0.00000: Recon Accuracy: 0.84634
# Epoch = 12, Iteration = 4 Total Loss: 0.64197: Recon Loss: 0.52069: Latent Loss: 0.12128: Sparsity Loss: 0.00000: Recon Accuracy: 0.84537
# Epoch = 12, Iteration = 5 Total Loss: 0.63623: Recon Loss: 0.51487: Latent Loss: 0.12137: Sparsity Loss: 0.00000: Recon Accuracy: 0.84525
# Epoch = 12, Iteration = 6 Total Loss: 0.63597: Recon Loss: 0.51540: Latent Loss: 0.12057: Sparsity Loss: 0.00000: Recon Accuracy: 0.84553
# Epoch = 12, Iteration = 7 Total Loss: 0.63868: Recon Loss: 0.51810: Latent Loss: 0.12058: Sparsity Loss: 0.00000: Recon Accuracy: 0.84478
# Epoch = 12, Iteration = 8 Total Loss: 0.62998: Recon Loss: 0.50912: Latent Loss: 0.12086: Sparsity Loss: 0.00000: Recon Accuracy: 0.84688
# Epoch = 12, Iteration = 9 Total Loss: 0.63537: Recon Loss: 0.51428: Latent Loss: 0.12109: Sparsity Loss: 0.00000: Recon Accuracy: 0.84671
# Epoch = 12, Iteration = 10 Total Loss: 0.62276: Recon Loss: 0.50259: Latent Loss: 0.12017: Sparsity Loss: 0.00000: Recon Accuracy: 0.84780
# Epoch = 13, Iteration = 0 Total Loss: 0.62597: Recon Loss: 0.50480: Latent Loss: 0.12117: Sparsity Loss: 0.00000: Recon Accuracy: 0.84750
# Epoch = 13, Iteration = 1 Total Loss: 0.62480: Recon Loss: 0.50364: Latent Loss: 0.12116: Sparsity Loss: 0.00000: Recon Accuracy: 0.84739
# Epoch = 13, Iteration = 2 Total Loss: 0.62661: Recon Loss: 0.50619: Latent Loss: 0.12042: Sparsity Loss: 0.00000: Recon Accuracy: 0.84840
# Epoch = 13, Iteration = 3 Total Loss: 0.62306: Recon Loss: 0.50356: Latent Loss: 0.11950: Sparsity Loss: 0.00000: Recon Accuracy: 0.84818
# Epoch = 13, Iteration = 4 Total Loss: 0.62258: Recon Loss: 0.50333: Latent Loss: 0.11925: Sparsity Loss: 0.00000: Recon Accuracy: 0.84802
# Epoch = 13, Iteration = 5 Total Loss: 0.62084: Recon Loss: 0.50233: Latent Loss: 0.11851: Sparsity Loss: 0.00000: Recon Accuracy: 0.84924
# Epoch = 13, Iteration = 6 Total Loss: 0.62298: Recon Loss: 0.50467: Latent Loss: 0.11831: Sparsity Loss: 0.00000: Recon Accuracy: 0.84879
# Epoch = 13, Iteration = 7 Total Loss: 0.62018: Recon Loss: 0.50199: Latent Loss: 0.11818: Sparsity Loss: 0.00000: Recon Accuracy: 0.85051
# Epoch = 13, Iteration = 8 Total Loss: 0.61600: Recon Loss: 0.49787: Latent Loss: 0.11813: Sparsity Loss: 0.00000: Recon Accuracy: 0.85097
# Epoch = 13, Iteration = 9 Total Loss: 0.61449: Recon Loss: 0.49635: Latent Loss: 0.11814: Sparsity Loss: 0.00000: Recon Accuracy: 0.85236
# Epoch = 13, Iteration = 10 Total Loss: 0.61300: Recon Loss: 0.49389: Latent Loss: 0.11911: Sparsity Loss: 0.00000: Recon Accuracy: 0.85188
# Epoch = 14, Iteration = 0 Total Loss: 0.60954: Recon Loss: 0.49167: Latent Loss: 0.11787: Sparsity Loss: 0.00000: Recon Accuracy: 0.85261
# Epoch = 14, Iteration = 1 Total Loss: 0.61181: Recon Loss: 0.49441: Latent Loss: 0.11740: Sparsity Loss: 0.00000: Recon Accuracy: 0.85400
# Epoch = 14, Iteration = 2 Total Loss: 0.62209: Recon Loss: 0.50504: Latent Loss: 0.11705: Sparsity Loss: 0.00000: Recon Accuracy: 0.85222
# Epoch = 14, Iteration = 3 Total Loss: 0.60956: Recon Loss: 0.49225: Latent Loss: 0.11731: Sparsity Loss: 0.00000: Recon Accuracy: 0.85404
# Epoch = 14, Iteration = 4 Total Loss: 0.60696: Recon Loss: 0.48940: Latent Loss: 0.11757: Sparsity Loss: 0.00000: Recon Accuracy: 0.85415
# Epoch = 14, Iteration = 5 Total Loss: 0.61136: Recon Loss: 0.49354: Latent Loss: 0.11782: Sparsity Loss: 0.00000: Recon Accuracy: 0.85321
# Epoch = 14, Iteration = 6 Total Loss: 0.59969: Recon Loss: 0.48220: Latent Loss: 0.11749: Sparsity Loss: 0.00000: Recon Accuracy: 0.85646
# Epoch = 14, Iteration = 7 Total Loss: 0.61299: Recon Loss: 0.49537: Latent Loss: 0.11762: Sparsity Loss: 0.00000: Recon Accuracy: 0.85515
# Epoch = 14, Iteration = 8 Total Loss: 0.60545: Recon Loss: 0.48810: Latent Loss: 0.11735: Sparsity Loss: 0.00000: Recon Accuracy: 0.85734
# Epoch = 14, Iteration = 9 Total Loss: 0.59646: Recon Loss: 0.47936: Latent Loss: 0.11709: Sparsity Loss: 0.00000: Recon Accuracy: 0.85979
# Epoch = 14, Iteration = 10 Total Loss: 0.60798: Recon Loss: 0.49192: Latent Loss: 0.11607: Sparsity Loss: 0.00000: Recon Accuracy: 0.85851
# Epoch = 15, Iteration = 0 Total Loss: 0.59596: Recon Loss: 0.47921: Latent Loss: 0.11675: Sparsity Loss: 0.00000: Recon Accuracy: 0.86060
# Epoch = 15, Iteration = 1 Total Loss: 0.59963: Recon Loss: 0.48311: Latent Loss: 0.11652: Sparsity Loss: 0.00000: Recon Accuracy: 0.85952
# Epoch = 15, Iteration = 2 Total Loss: 0.59724: Recon Loss: 0.48065: Latent Loss: 0.11659: Sparsity Loss: 0.00000: Recon Accuracy: 0.86123
# Epoch = 15, Iteration = 3 Total Loss: 0.59179: Recon Loss: 0.47484: Latent Loss: 0.11694: Sparsity Loss: 0.00000: Recon Accuracy: 0.86252
# Epoch = 15, Iteration = 4 Total Loss: 0.59267: Recon Loss: 0.47536: Latent Loss: 0.11731: Sparsity Loss: 0.00000: Recon Accuracy: 0.86241
# Epoch = 15, Iteration = 5 Total Loss: 0.58357: Recon Loss: 0.46623: Latent Loss: 0.11734: Sparsity Loss: 0.00000: Recon Accuracy: 0.86492
# Epoch = 15, Iteration = 6 Total Loss: 0.58738: Recon Loss: 0.46928: Latent Loss: 0.11810: Sparsity Loss: 0.00000: Recon Accuracy: 0.86471
# Epoch = 15, Iteration = 7 Total Loss: 0.58093: Recon Loss: 0.46299: Latent Loss: 0.11794: Sparsity Loss: 0.00000: Recon Accuracy: 0.86648
# Epoch = 15, Iteration = 8 Total Loss: 0.58186: Recon Loss: 0.46356: Latent Loss: 0.11830: Sparsity Loss: 0.00000: Recon Accuracy: 0.86636
# Epoch = 15, Iteration = 9 Total Loss: 0.58111: Recon Loss: 0.46187: Latent Loss: 0.11923: Sparsity Loss: 0.00000: Recon Accuracy: 0.86811
# Epoch = 15, Iteration = 10 Total Loss: 0.58501: Recon Loss: 0.46503: Latent Loss: 0.11998: Sparsity Loss: 0.00000: Recon Accuracy: 0.86325
# Epoch = 16, Iteration = 0 Total Loss: 0.57755: Recon Loss: 0.45727: Latent Loss: 0.12028: Sparsity Loss: 0.00000: Recon Accuracy: 0.87027
# Epoch = 16, Iteration = 1 Total Loss: 0.57654: Recon Loss: 0.45661: Latent Loss: 0.11992: Sparsity Loss: 0.00000: Recon Accuracy: 0.87006
# Epoch = 16, Iteration = 2 Total Loss: 0.56992: Recon Loss: 0.45022: Latent Loss: 0.11969: Sparsity Loss: 0.00000: Recon Accuracy: 0.87202
# Epoch = 16, Iteration = 3 Total Loss: 0.57072: Recon Loss: 0.45069: Latent Loss: 0.12004: Sparsity Loss: 0.00000: Recon Accuracy: 0.87348
# Epoch = 16, Iteration = 4 Total Loss: 0.56954: Recon Loss: 0.44953: Latent Loss: 0.12000: Sparsity Loss: 0.00000: Recon Accuracy: 0.87370
# Epoch = 16, Iteration = 5 Total Loss: 0.56768: Recon Loss: 0.44820: Latent Loss: 0.11947: Sparsity Loss: 0.00000: Recon Accuracy: 0.87313
# Epoch = 16, Iteration = 6 Total Loss: 0.56129: Recon Loss: 0.44128: Latent Loss: 0.12001: Sparsity Loss: 0.00000: Recon Accuracy: 0.87494
# Epoch = 16, Iteration = 7 Total Loss: 0.55902: Recon Loss: 0.43905: Latent Loss: 0.11997: Sparsity Loss: 0.00000: Recon Accuracy: 0.87525
# Epoch = 16, Iteration = 8 Total Loss: 0.56322: Recon Loss: 0.44187: Latent Loss: 0.12134: Sparsity Loss: 0.00000: Recon Accuracy: 0.87747
# Epoch = 16, Iteration = 9 Total Loss: 0.55751: Recon Loss: 0.43518: Latent Loss: 0.12232: Sparsity Loss: 0.00000: Recon Accuracy: 0.87786
# Epoch = 16, Iteration = 10 Total Loss: 0.56668: Recon Loss: 0.44355: Latent Loss: 0.12313: Sparsity Loss: 0.00000: Recon Accuracy: 0.87428
# Epoch = 17, Iteration = 0 Total Loss: 0.55919: Recon Loss: 0.43453: Latent Loss: 0.12466: Sparsity Loss: 0.00000: Recon Accuracy: 0.87999
# Epoch = 17, Iteration = 1 Total Loss: 0.55599: Recon Loss: 0.43239: Latent Loss: 0.12360: Sparsity Loss: 0.00000: Recon Accuracy: 0.88008
# Epoch = 17, Iteration = 2 Total Loss: 0.55264: Recon Loss: 0.42947: Latent Loss: 0.12317: Sparsity Loss: 0.00000: Recon Accuracy: 0.88025
# Epoch = 17, Iteration = 3 Total Loss: 0.55149: Recon Loss: 0.42911: Latent Loss: 0.12237: Sparsity Loss: 0.00000: Recon Accuracy: 0.87992
# Epoch = 17, Iteration = 4 Total Loss: 0.55428: Recon Loss: 0.43111: Latent Loss: 0.12317: Sparsity Loss: 0.00000: Recon Accuracy: 0.88116
# Epoch = 17, Iteration = 5 Total Loss: 0.55729: Recon Loss: 0.43438: Latent Loss: 0.12291: Sparsity Loss: 0.00000: Recon Accuracy: 0.88148
# Epoch = 17, Iteration = 6 Total Loss: 0.54502: Recon Loss: 0.42225: Latent Loss: 0.12277: Sparsity Loss: 0.00000: Recon Accuracy: 0.88291
# Epoch = 17, Iteration = 7 Total Loss: 0.55312: Recon Loss: 0.42983: Latent Loss: 0.12329: Sparsity Loss: 0.00000: Recon Accuracy: 0.88177
# Epoch = 17, Iteration = 8 Total Loss: 0.54571: Recon Loss: 0.42222: Latent Loss: 0.12349: Sparsity Loss: 0.00000: Recon Accuracy: 0.88440
# Epoch = 17, Iteration = 9 Total Loss: 0.53999: Recon Loss: 0.41645: Latent Loss: 0.12354: Sparsity Loss: 0.00000: Recon Accuracy: 0.88619
# Epoch = 17, Iteration = 10 Total Loss: 0.53065: Recon Loss: 0.40767: Latent Loss: 0.12298: Sparsity Loss: 0.00000: Recon Accuracy: 0.88783
# Epoch = 18, Iteration = 0 Total Loss: 0.53741: Recon Loss: 0.41377: Latent Loss: 0.12364: Sparsity Loss: 0.00000: Recon Accuracy: 0.88703
# Epoch = 18, Iteration = 1 Total Loss: 0.54007: Recon Loss: 0.41592: Latent Loss: 0.12414: Sparsity Loss: 0.00000: Recon Accuracy: 0.88645
# Epoch = 18, Iteration = 2 Total Loss: 0.53760: Recon Loss: 0.41330: Latent Loss: 0.12430: Sparsity Loss: 0.00000: Recon Accuracy: 0.88690
# Epoch = 18, Iteration = 3 Total Loss: 0.54402: Recon Loss: 0.41903: Latent Loss: 0.12499: Sparsity Loss: 0.00000: Recon Accuracy: 0.88424
# Epoch = 18, Iteration = 4 Total Loss: 0.53847: Recon Loss: 0.41335: Latent Loss: 0.12512: Sparsity Loss: 0.00000: Recon Accuracy: 0.88609
# Epoch = 18, Iteration = 5 Total Loss: 0.52762: Recon Loss: 0.40405: Latent Loss: 0.12356: Sparsity Loss: 0.00000: Recon Accuracy: 0.88803
# Epoch = 18, Iteration = 6 Total Loss: 0.53586: Recon Loss: 0.41284: Latent Loss: 0.12303: Sparsity Loss: 0.00000: Recon Accuracy: 0.88712
# Epoch = 18, Iteration = 7 Total Loss: 0.53905: Recon Loss: 0.41644: Latent Loss: 0.12261: Sparsity Loss: 0.00000: Recon Accuracy: 0.88775
# Epoch = 18, Iteration = 8 Total Loss: 0.53095: Recon Loss: 0.40849: Latent Loss: 0.12247: Sparsity Loss: 0.00000: Recon Accuracy: 0.88786
# Epoch = 18, Iteration = 9 Total Loss: 0.52869: Recon Loss: 0.40550: Latent Loss: 0.12319: Sparsity Loss: 0.00000: Recon Accuracy: 0.88927
# Epoch = 18, Iteration = 10 Total Loss: 0.52182: Recon Loss: 0.39811: Latent Loss: 0.12371: Sparsity Loss: 0.00000: Recon Accuracy: 0.89088
# Epoch = 19, Iteration = 0 Total Loss: 0.52946: Recon Loss: 0.40487: Latent Loss: 0.12459: Sparsity Loss: 0.00000: Recon Accuracy: 0.88854
# Epoch = 19, Iteration = 1 Total Loss: 0.53409: Recon Loss: 0.41005: Latent Loss: 0.12404: Sparsity Loss: 0.00000: Recon Accuracy: 0.88954
# Epoch = 19, Iteration = 2 Total Loss: 0.52151: Recon Loss: 0.39855: Latent Loss: 0.12295: Sparsity Loss: 0.00000: Recon Accuracy: 0.89068
# Epoch = 19, Iteration = 3 Total Loss: 0.52448: Recon Loss: 0.40217: Latent Loss: 0.12231: Sparsity Loss: 0.00000: Recon Accuracy: 0.89104
# Epoch = 19, Iteration = 4 Total Loss: 0.51970: Recon Loss: 0.39746: Latent Loss: 0.12224: Sparsity Loss: 0.00000: Recon Accuracy: 0.89346
# Epoch = 19, Iteration = 5 Total Loss: 0.52636: Recon Loss: 0.40417: Latent Loss: 0.12219: Sparsity Loss: 0.00000: Recon Accuracy: 0.89206
# Epoch = 19, Iteration = 6 Total Loss: 0.51906: Recon Loss: 0.39666: Latent Loss: 0.12240: Sparsity Loss: 0.00000: Recon Accuracy: 0.89256
# Epoch = 19, Iteration = 7 Total Loss: 0.52040: Recon Loss: 0.39780: Latent Loss: 0.12259: Sparsity Loss: 0.00000: Recon Accuracy: 0.89196
# Epoch = 19, Iteration = 8 Total Loss: 0.51606: Recon Loss: 0.39266: Latent Loss: 0.12340: Sparsity Loss: 0.00000: Recon Accuracy: 0.89421
# Epoch = 19, Iteration = 9 Total Loss: 0.50938: Recon Loss: 0.38567: Latent Loss: 0.12372: Sparsity Loss: 0.00000: Recon Accuracy: 0.89600
# Epoch = 19, Iteration = 10 Total Loss: 0.52089: Recon Loss: 0.39687: Latent Loss: 0.12402: Sparsity Loss: 0.00000: Recon Accuracy: 0.89589
# Epoch = 20, Iteration = 0 Total Loss: 0.50788: Recon Loss: 0.38463: Latent Loss: 0.12325: Sparsity Loss: 0.00000: Recon Accuracy: 0.89633
# Epoch = 20, Iteration = 1 Total Loss: 0.51106: Recon Loss: 0.38770: Latent Loss: 0.12337: Sparsity Loss: 0.00000: Recon Accuracy: 0.89575
# Epoch = 20, Iteration = 2 Total Loss: 0.51687: Recon Loss: 0.39289: Latent Loss: 0.12398: Sparsity Loss: 0.00000: Recon Accuracy: 0.89503
# Epoch = 20, Iteration = 3 Total Loss: 0.50932: Recon Loss: 0.38599: Latent Loss: 0.12334: Sparsity Loss: 0.00000: Recon Accuracy: 0.89610
# Epoch = 20, Iteration = 4 Total Loss: 0.51005: Recon Loss: 0.38681: Latent Loss: 0.12324: Sparsity Loss: 0.00000: Recon Accuracy: 0.89690
# Epoch = 20, Iteration = 5 Total Loss: 0.52004: Recon Loss: 0.39660: Latent Loss: 0.12344: Sparsity Loss: 0.00000: Recon Accuracy: 0.89531
# Epoch = 20, Iteration = 6 Total Loss: 0.50332: Recon Loss: 0.38073: Latent Loss: 0.12259: Sparsity Loss: 0.00000: Recon Accuracy: 0.89636
# Epoch = 20, Iteration = 7 Total Loss: 0.50678: Recon Loss: 0.38427: Latent Loss: 0.12251: Sparsity Loss: 0.00000: Recon Accuracy: 0.89661
# Epoch = 20, Iteration = 8 Total Loss: 0.50637: Recon Loss: 0.38435: Latent Loss: 0.12202: Sparsity Loss: 0.00000: Recon Accuracy: 0.89616
# Epoch = 20, Iteration = 9 Total Loss: 0.50291: Recon Loss: 0.38090: Latent Loss: 0.12202: Sparsity Loss: 0.00000: Recon Accuracy: 0.89700
# Epoch = 20, Iteration = 10 Total Loss: 0.49362: Recon Loss: 0.37207: Latent Loss: 0.12155: Sparsity Loss: 0.00000: Recon Accuracy: 0.89956
# Epoch = 21, Iteration = 0 Total Loss: 0.51214: Recon Loss: 0.39071: Latent Loss: 0.12143: Sparsity Loss: 0.00000: Recon Accuracy: 0.89678
# Epoch = 21, Iteration = 1 Total Loss: 0.50783: Recon Loss: 0.38672: Latent Loss: 0.12111: Sparsity Loss: 0.00000: Recon Accuracy: 0.89768
# Epoch = 21, Iteration = 2 Total Loss: 0.50479: Recon Loss: 0.38414: Latent Loss: 0.12065: Sparsity Loss: 0.00000: Recon Accuracy: 0.89743
# Epoch = 21, Iteration = 3 Total Loss: 0.50802: Recon Loss: 0.38701: Latent Loss: 0.12101: Sparsity Loss: 0.00000: Recon Accuracy: 0.89662
# Epoch = 21, Iteration = 4 Total Loss: 0.49445: Recon Loss: 0.37353: Latent Loss: 0.12092: Sparsity Loss: 0.00000: Recon Accuracy: 0.89956
# Epoch = 21, Iteration = 5 Total Loss: 0.50012: Recon Loss: 0.37958: Latent Loss: 0.12054: Sparsity Loss: 0.00000: Recon Accuracy: 0.89916
# Epoch = 21, Iteration = 6 Total Loss: 0.49608: Recon Loss: 0.37520: Latent Loss: 0.12087: Sparsity Loss: 0.00000: Recon Accuracy: 0.90028
# Epoch = 21, Iteration = 7 Total Loss: 0.49327: Recon Loss: 0.37248: Latent Loss: 0.12078: Sparsity Loss: 0.00000: Recon Accuracy: 0.90079
# Epoch = 21, Iteration = 8 Total Loss: 0.49597: Recon Loss: 0.37481: Latent Loss: 0.12116: Sparsity Loss: 0.00000: Recon Accuracy: 0.89944
# Epoch = 21, Iteration = 9 Total Loss: 0.48862: Recon Loss: 0.36714: Latent Loss: 0.12149: Sparsity Loss: 0.00000: Recon Accuracy: 0.90196
# Epoch = 21, Iteration = 10 Total Loss: 0.50195: Recon Loss: 0.37999: Latent Loss: 0.12196: Sparsity Loss: 0.00000: Recon Accuracy: 0.90091
# Epoch = 22, Iteration = 0 Total Loss: 0.49237: Recon Loss: 0.37122: Latent Loss: 0.12115: Sparsity Loss: 0.00000: Recon Accuracy: 0.90109
# Epoch = 22, Iteration = 1 Total Loss: 0.51018: Recon Loss: 0.38842: Latent Loss: 0.12176: Sparsity Loss: 0.00000: Recon Accuracy: 0.89710
# Epoch = 22, Iteration = 2 Total Loss: 0.49760: Recon Loss: 0.37722: Latent Loss: 0.12038: Sparsity Loss: 0.00000: Recon Accuracy: 0.89905
# Epoch = 22, Iteration = 3 Total Loss: 0.49048: Recon Loss: 0.36978: Latent Loss: 0.12070: Sparsity Loss: 0.00000: Recon Accuracy: 0.90200
# Epoch = 22, Iteration = 4 Total Loss: 0.50276: Recon Loss: 0.38194: Latent Loss: 0.12082: Sparsity Loss: 0.00000: Recon Accuracy: 0.89949
# Epoch = 22, Iteration = 5 Total Loss: 0.49880: Recon Loss: 0.37791: Latent Loss: 0.12089: Sparsity Loss: 0.00000: Recon Accuracy: 0.90073
# Epoch = 22, Iteration = 6 Total Loss: 0.49339: Recon Loss: 0.37241: Latent Loss: 0.12098: Sparsity Loss: 0.00000: Recon Accuracy: 0.90075
# Epoch = 22, Iteration = 7 Total Loss: 0.49009: Recon Loss: 0.36900: Latent Loss: 0.12109: Sparsity Loss: 0.00000: Recon Accuracy: 0.90147
# Epoch = 22, Iteration = 8 Total Loss: 0.49162: Recon Loss: 0.36948: Latent Loss: 0.12214: Sparsity Loss: 0.00000: Recon Accuracy: 0.90224
# Epoch = 22, Iteration = 9 Total Loss: 0.48819: Recon Loss: 0.36603: Latent Loss: 0.12216: Sparsity Loss: 0.00000: Recon Accuracy: 0.90191
# Epoch = 22, Iteration = 10 Total Loss: 0.47916: Recon Loss: 0.35745: Latent Loss: 0.12171: Sparsity Loss: 0.00000: Recon Accuracy: 0.90439
# Epoch = 23, Iteration = 0 Total Loss: 0.48679: Recon Loss: 0.36535: Latent Loss: 0.12144: Sparsity Loss: 0.00000: Recon Accuracy: 0.90294
# Epoch = 23, Iteration = 1 Total Loss: 0.49082: Recon Loss: 0.36858: Latent Loss: 0.12224: Sparsity Loss: 0.00000: Recon Accuracy: 0.90209
# Epoch = 23, Iteration = 2 Total Loss: 0.49382: Recon Loss: 0.37140: Latent Loss: 0.12242: Sparsity Loss: 0.00000: Recon Accuracy: 0.90122
# Epoch = 23, Iteration = 3 Total Loss: 0.48593: Recon Loss: 0.36284: Latent Loss: 0.12309: Sparsity Loss: 0.00000: Recon Accuracy: 0.90447
# Epoch = 23, Iteration = 4 Total Loss: 0.48023: Recon Loss: 0.35739: Latent Loss: 0.12284: Sparsity Loss: 0.00000: Recon Accuracy: 0.90500
# Epoch = 23, Iteration = 5 Total Loss: 0.48639: Recon Loss: 0.36316: Latent Loss: 0.12323: Sparsity Loss: 0.00000: Recon Accuracy: 0.90292
# Epoch = 23, Iteration = 6 Total Loss: 0.49187: Recon Loss: 0.36808: Latent Loss: 0.12379: Sparsity Loss: 0.00000: Recon Accuracy: 0.90352
# Epoch = 23, Iteration = 7 Total Loss: 0.48189: Recon Loss: 0.35812: Latent Loss: 0.12377: Sparsity Loss: 0.00000: Recon Accuracy: 0.90507
# Epoch = 23, Iteration = 8 Total Loss: 0.48100: Recon Loss: 0.35740: Latent Loss: 0.12360: Sparsity Loss: 0.00000: Recon Accuracy: 0.90508
# Epoch = 23, Iteration = 9 Total Loss: 0.48851: Recon Loss: 0.36520: Latent Loss: 0.12332: Sparsity Loss: 0.00000: Recon Accuracy: 0.90366
# Epoch = 23, Iteration = 10 Total Loss: 0.47842: Recon Loss: 0.35559: Latent Loss: 0.12282: Sparsity Loss: 0.00000: Recon Accuracy: 0.90576
# Epoch = 24, Iteration = 0 Total Loss: 0.47302: Recon Loss: 0.35133: Latent Loss: 0.12169: Sparsity Loss: 0.00000: Recon Accuracy: 0.90646
# Epoch = 24, Iteration = 1 Total Loss: 0.48330: Recon Loss: 0.36165: Latent Loss: 0.12165: Sparsity Loss: 0.00000: Recon Accuracy: 0.90440
# Epoch = 24, Iteration = 2 Total Loss: 0.48464: Recon Loss: 0.36369: Latent Loss: 0.12095: Sparsity Loss: 0.00000: Recon Accuracy: 0.90389
# Epoch = 24, Iteration = 3 Total Loss: 0.47947: Recon Loss: 0.35883: Latent Loss: 0.12064: Sparsity Loss: 0.00000: Recon Accuracy: 0.90438
# Epoch = 24, Iteration = 4 Total Loss: 0.48447: Recon Loss: 0.36434: Latent Loss: 0.12013: Sparsity Loss: 0.00000: Recon Accuracy: 0.90452
# Epoch = 24, Iteration = 5 Total Loss: 0.48014: Recon Loss: 0.36003: Latent Loss: 0.12011: Sparsity Loss: 0.00000: Recon Accuracy: 0.90494
# Epoch = 24, Iteration = 6 Total Loss: 0.47489: Recon Loss: 0.35546: Latent Loss: 0.11943: Sparsity Loss: 0.00000: Recon Accuracy: 0.90600
# Epoch = 24, Iteration = 7 Total Loss: 0.47804: Recon Loss: 0.35849: Latent Loss: 0.11955: Sparsity Loss: 0.00000: Recon Accuracy: 0.90551
# Epoch = 24, Iteration = 8 Total Loss: 0.47402: Recon Loss: 0.35496: Latent Loss: 0.11905: Sparsity Loss: 0.00000: Recon Accuracy: 0.90636
# Epoch = 24, Iteration = 9 Total Loss: 0.47014: Recon Loss: 0.35082: Latent Loss: 0.11933: Sparsity Loss: 0.00000: Recon Accuracy: 0.90685
# Epoch = 24, Iteration = 10 Total Loss: 0.49722: Recon Loss: 0.37868: Latent Loss: 0.11854: Sparsity Loss: 0.00000: Recon Accuracy: 0.90172
# Epoch = 25, Iteration = 0 Total Loss: 0.48005: Recon Loss: 0.36137: Latent Loss: 0.11868: Sparsity Loss: 0.00000: Recon Accuracy: 0.90469
# Epoch = 25, Iteration = 1 Total Loss: 0.49381: Recon Loss: 0.37466: Latent Loss: 0.11916: Sparsity Loss: 0.00000: Recon Accuracy: 0.90392
# Epoch = 25, Iteration = 2 Total Loss: 0.47364: Recon Loss: 0.35533: Latent Loss: 0.11832: Sparsity Loss: 0.00000: Recon Accuracy: 0.90597
# Epoch = 25, Iteration = 3 Total Loss: 0.47561: Recon Loss: 0.35764: Latent Loss: 0.11796: Sparsity Loss: 0.00000: Recon Accuracy: 0.90625
# Epoch = 25, Iteration = 4 Total Loss: 0.48607: Recon Loss: 0.36741: Latent Loss: 0.11866: Sparsity Loss: 0.00000: Recon Accuracy: 0.90574
# Epoch = 25, Iteration = 5 Total Loss: 0.47948: Recon Loss: 0.35997: Latent Loss: 0.11951: Sparsity Loss: 0.00000: Recon Accuracy: 0.90582
# Epoch = 25, Iteration = 6 Total Loss: 0.47597: Recon Loss: 0.35652: Latent Loss: 0.11946: Sparsity Loss: 0.00000: Recon Accuracy: 0.90577
# Epoch = 25, Iteration = 7 Total Loss: 0.47275: Recon Loss: 0.35208: Latent Loss: 0.12067: Sparsity Loss: 0.00000: Recon Accuracy: 0.90705
# Epoch = 25, Iteration = 8 Total Loss: 0.47503: Recon Loss: 0.35423: Latent Loss: 0.12080: Sparsity Loss: 0.00000: Recon Accuracy: 0.90652
# Epoch = 25, Iteration = 9 Total Loss: 0.47041: Recon Loss: 0.34961: Latent Loss: 0.12080: Sparsity Loss: 0.00000: Recon Accuracy: 0.90708
# Epoch = 25, Iteration = 10 Total Loss: 0.47261: Recon Loss: 0.35099: Latent Loss: 0.12162: Sparsity Loss: 0.00000: Recon Accuracy: 0.90869
# Epoch = 26, Iteration = 0 Total Loss: 0.46925: Recon Loss: 0.34837: Latent Loss: 0.12088: Sparsity Loss: 0.00000: Recon Accuracy: 0.90823
# Epoch = 26, Iteration = 1 Total Loss: 0.47526: Recon Loss: 0.35455: Latent Loss: 0.12071: Sparsity Loss: 0.00000: Recon Accuracy: 0.90703
# Epoch = 26, Iteration = 2 Total Loss: 0.46823: Recon Loss: 0.34798: Latent Loss: 0.12025: Sparsity Loss: 0.00000: Recon Accuracy: 0.90842
# Epoch = 26, Iteration = 3 Total Loss: 0.46492: Recon Loss: 0.34466: Latent Loss: 0.12026: Sparsity Loss: 0.00000: Recon Accuracy: 0.90890
# Epoch = 26, Iteration = 4 Total Loss: 0.47188: Recon Loss: 0.35167: Latent Loss: 0.12021: Sparsity Loss: 0.00000: Recon Accuracy: 0.90684
# Epoch = 26, Iteration = 5 Total Loss: 0.46739: Recon Loss: 0.34776: Latent Loss: 0.11963: Sparsity Loss: 0.00000: Recon Accuracy: 0.90891
# Epoch = 26, Iteration = 6 Total Loss: 0.47173: Recon Loss: 0.35280: Latent Loss: 0.11893: Sparsity Loss: 0.00000: Recon Accuracy: 0.90712
# Epoch = 26, Iteration = 7 Total Loss: 0.46328: Recon Loss: 0.34450: Latent Loss: 0.11878: Sparsity Loss: 0.00000: Recon Accuracy: 0.90897
# Epoch = 26, Iteration = 8 Total Loss: 0.46346: Recon Loss: 0.34493: Latent Loss: 0.11853: Sparsity Loss: 0.00000: Recon Accuracy: 0.90910
# Epoch = 26, Iteration = 9 Total Loss: 0.46709: Recon Loss: 0.34877: Latent Loss: 0.11832: Sparsity Loss: 0.00000: Recon Accuracy: 0.90809
# Epoch = 26, Iteration = 10 Total Loss: 0.44652: Recon Loss: 0.32800: Latent Loss: 0.11851: Sparsity Loss: 0.00000: Recon Accuracy: 0.91286
# Epoch = 27, Iteration = 0 Total Loss: 0.46668: Recon Loss: 0.34838: Latent Loss: 0.11830: Sparsity Loss: 0.00000: Recon Accuracy: 0.90798
# Epoch = 27, Iteration = 1 Total Loss: 0.46398: Recon Loss: 0.34613: Latent Loss: 0.11785: Sparsity Loss: 0.00000: Recon Accuracy: 0.90899
# Epoch = 27, Iteration = 2 Total Loss: 0.46088: Recon Loss: 0.34313: Latent Loss: 0.11774: Sparsity Loss: 0.00000: Recon Accuracy: 0.90890
# Epoch = 27, Iteration = 3 Total Loss: 0.46555: Recon Loss: 0.34809: Latent Loss: 0.11746: Sparsity Loss: 0.00000: Recon Accuracy: 0.90767
# Epoch = 27, Iteration = 4 Total Loss: 0.45625: Recon Loss: 0.33942: Latent Loss: 0.11683: Sparsity Loss: 0.00000: Recon Accuracy: 0.90992
# Epoch = 27, Iteration = 5 Total Loss: 0.45979: Recon Loss: 0.34293: Latent Loss: 0.11686: Sparsity Loss: 0.00000: Recon Accuracy: 0.91071
# Epoch = 27, Iteration = 6 Total Loss: 0.46177: Recon Loss: 0.34496: Latent Loss: 0.11681: Sparsity Loss: 0.00000: Recon Accuracy: 0.90960
# Epoch = 27, Iteration = 7 Total Loss: 0.46159: Recon Loss: 0.34502: Latent Loss: 0.11656: Sparsity Loss: 0.00000: Recon Accuracy: 0.90956
# Epoch = 27, Iteration = 8 Total Loss: 0.45677: Recon Loss: 0.34051: Latent Loss: 0.11626: Sparsity Loss: 0.00000: Recon Accuracy: 0.90997
# Epoch = 27, Iteration = 9 Total Loss: 0.45907: Recon Loss: 0.34312: Latent Loss: 0.11595: Sparsity Loss: 0.00000: Recon Accuracy: 0.91017
# Epoch = 27, Iteration = 10 Total Loss: 0.44941: Recon Loss: 0.33307: Latent Loss: 0.11634: Sparsity Loss: 0.00000: Recon Accuracy: 0.91103
# Epoch = 28, Iteration = 0 Total Loss: 0.44981: Recon Loss: 0.33324: Latent Loss: 0.11657: Sparsity Loss: 0.00000: Recon Accuracy: 0.91155
# Epoch = 28, Iteration = 1 Total Loss: 0.45948: Recon Loss: 0.34308: Latent Loss: 0.11640: Sparsity Loss: 0.00000: Recon Accuracy: 0.90950
# Epoch = 28, Iteration = 2 Total Loss: 0.45443: Recon Loss: 0.33844: Latent Loss: 0.11599: Sparsity Loss: 0.00000: Recon Accuracy: 0.91190
# Epoch = 28, Iteration = 3 Total Loss: 0.45081: Recon Loss: 0.33547: Latent Loss: 0.11534: Sparsity Loss: 0.00000: Recon Accuracy: 0.91251
# Epoch = 28, Iteration = 4 Total Loss: 0.45754: Recon Loss: 0.34281: Latent Loss: 0.11472: Sparsity Loss: 0.00000: Recon Accuracy: 0.90874
# Epoch = 28, Iteration = 5 Total Loss: 0.45369: Recon Loss: 0.33919: Latent Loss: 0.11449: Sparsity Loss: 0.00000: Recon Accuracy: 0.91136
# Epoch = 28, Iteration = 6 Total Loss: 0.45567: Recon Loss: 0.34167: Latent Loss: 0.11399: Sparsity Loss: 0.00000: Recon Accuracy: 0.91077
# Epoch = 28, Iteration = 7 Total Loss: 0.45364: Recon Loss: 0.33987: Latent Loss: 0.11377: Sparsity Loss: 0.00000: Recon Accuracy: 0.90965
# Epoch = 28, Iteration = 8 Total Loss: 0.45835: Recon Loss: 0.34495: Latent Loss: 0.11340: Sparsity Loss: 0.00000: Recon Accuracy: 0.91005
# Epoch = 28, Iteration = 9 Total Loss: 0.45460: Recon Loss: 0.34129: Latent Loss: 0.11330: Sparsity Loss: 0.00000: Recon Accuracy: 0.91015
# Epoch = 28, Iteration = 10 Total Loss: 0.46069: Recon Loss: 0.34722: Latent Loss: 0.11346: Sparsity Loss: 0.00000: Recon Accuracy: 0.90817
# Epoch = 29, Iteration = 0 Total Loss: 0.44923: Recon Loss: 0.33627: Latent Loss: 0.11296: Sparsity Loss: 0.00000: Recon Accuracy: 0.91124
# Epoch = 29, Iteration = 1 Total Loss: 0.45257: Recon Loss: 0.33931: Latent Loss: 0.11326: Sparsity Loss: 0.00000: Recon Accuracy: 0.91058
# Epoch = 29, Iteration = 2 Total Loss: 0.45691: Recon Loss: 0.34375: Latent Loss: 0.11316: Sparsity Loss: 0.00000: Recon Accuracy: 0.91019
# Epoch = 29, Iteration = 3 Total Loss: 0.45671: Recon Loss: 0.34373: Latent Loss: 0.11298: Sparsity Loss: 0.00000: Recon Accuracy: 0.91033
# Epoch = 29, Iteration = 4 Total Loss: 0.45382: Recon Loss: 0.34061: Latent Loss: 0.11321: Sparsity Loss: 0.00000: Recon Accuracy: 0.91134
# Epoch = 29, Iteration = 5 Total Loss: 0.45660: Recon Loss: 0.34320: Latent Loss: 0.11340: Sparsity Loss: 0.00000: Recon Accuracy: 0.91041
# Epoch = 29, Iteration = 6 Total Loss: 0.45170: Recon Loss: 0.33817: Latent Loss: 0.11353: Sparsity Loss: 0.00000: Recon Accuracy: 0.91102
# Epoch = 29, Iteration = 7 Total Loss: 0.45239: Recon Loss: 0.33878: Latent Loss: 0.11361: Sparsity Loss: 0.00000: Recon Accuracy: 0.91067
# Epoch = 29, Iteration = 8 Total Loss: 0.44967: Recon Loss: 0.33590: Latent Loss: 0.11378: Sparsity Loss: 0.00000: Recon Accuracy: 0.91157
# Epoch = 29, Iteration = 9 Total Loss: 0.45664: Recon Loss: 0.34206: Latent Loss: 0.11458: Sparsity Loss: 0.00000: Recon Accuracy: 0.91058
# Epoch = 29, Iteration = 10 Total Loss: 0.43939: Recon Loss: 0.32382: Latent Loss: 0.11557: Sparsity Loss: 0.00000: Recon Accuracy: 0.91417
# Epoch = 30, Iteration = 0 Total Loss: 0.45161: Recon Loss: 0.33661: Latent Loss: 0.11500: Sparsity Loss: 0.00000: Recon Accuracy: 0.91232
# Epoch = 30, Iteration = 1 Total Loss: 0.44792: Recon Loss: 0.33325: Latent Loss: 0.11467: Sparsity Loss: 0.00000: Recon Accuracy: 0.91198
# Epoch = 30, Iteration = 2 Total Loss: 0.45423: Recon Loss: 0.33908: Latent Loss: 0.11515: Sparsity Loss: 0.00000: Recon Accuracy: 0.91080
# Epoch = 30, Iteration = 3 Total Loss: 0.45400: Recon Loss: 0.33862: Latent Loss: 0.11538: Sparsity Loss: 0.00000: Recon Accuracy: 0.91115
# Epoch = 30, Iteration = 4 Total Loss: 0.44615: Recon Loss: 0.33115: Latent Loss: 0.11499: Sparsity Loss: 0.00000: Recon Accuracy: 0.91259
# Epoch = 30, Iteration = 5 Total Loss: 0.45612: Recon Loss: 0.34164: Latent Loss: 0.11448: Sparsity Loss: 0.00000: Recon Accuracy: 0.90972
# Epoch = 30, Iteration = 6 Total Loss: 0.44970: Recon Loss: 0.33560: Latent Loss: 0.11410: Sparsity Loss: 0.00000: Recon Accuracy: 0.91246
# Epoch = 30, Iteration = 7 Total Loss: 0.44864: Recon Loss: 0.33435: Latent Loss: 0.11428: Sparsity Loss: 0.00000: Recon Accuracy: 0.91227
# Reconstruction Accuracy: 0.91303
# INFO:tensorflow:TCR_all\models\model_0\model.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# Training Done
# DeepTCR VAE training completed!

# %%
def extract_features_from_DTCRU(DTCRU):
    
    # Convert latent features to DataFrame
    feature_df = pd.DataFrame(DTCRU.features)

    # Convert sequence data to DataFrame
    metadata_df = pd.DataFrame({
        "CDR3_Beta": DTCRU.beta_sequences,
        "V_Beta": DTCRU.v_beta,
        "J_Beta": DTCRU.j_beta,
        "Label": DTCRU.sample_id  # Use sample_id as labels
    })

    # Merge latent features with metadata
    full_df = pd.concat([metadata_df, feature_df], axis=1)

    return full_df

# Usage:
features_df = extract_features_from_DTCRU(DTCRU)

# Save to CSV if needed
features_df.to_csv("DTCRU_features_all.csv", index=False)

#features_df

# %%
import pickle

# Save object
with open("trained_DTCRU.pkl", "wb") as f:
    pickle.dump(DTCRU, f)

# %%
# Load object elsewhere
# with open("trained_DTCRU.pkl", "rb") as f:
#     DTCRU = pickle.load(f)

# %% [markdown]
# ## Inference on another set

# %%
DTCRU_sub = DeepTCR_U('TCR_sub')

# Load Data from CNS & Spleen directories
DTCRU_sub.Get_Data(directory='DeepTCR_input/EAE_all_cells/subset/', 
               Load_Prev_Data=False, aggregate_by_aa=True,
               aa_column_beta=1, count_column=4, v_beta_column=2, j_beta_column=3)

print("Data loaded successfully into DeepTCR!")
# Out:
# Loading Data...
# Embedding Sequences...
# Data Loaded
# Data loaded successfully into DeepTCR!

# %%
beta_sequences = DTCRU_sub.beta_sequences
v_beta = DTCRU_sub.v_beta
j_beta = DTCRU_sub.j_beta

# %%
features = DTCRU.Sequence_Inference(beta_sequences=beta_sequences,v_beta=v_beta,j_beta=j_beta)
# Out:
# INFO:tensorflow:Restoring parameters from TCR_all\models\model_0\model.ckpt

# %%
features_test = pd.DataFrame(features)
features_test['CDR3_Beta'] = beta_sequences
features_test['V_Beta'] = v_beta
features_test['J_Beta'] = j_beta
features_test
# Out:
#               0         1         2         3         4         5         6  \
# 0      1.927736 -0.325494 -1.289528 -0.667871  1.343621  1.640524  0.529073
# 1      1.240850 -0.254140  0.172752 -2.288209 -1.026195  0.161669  0.732343
# 2      0.648429 -0.310852 -0.751538 -2.075875  0.953956  0.476057 -0.784178
# 3      0.883649 -2.164834 -1.264386 -0.301381  0.867770 -2.040733 -0.499014
# 4     -2.617029 -0.173909 -0.048285  0.601322 -0.175705  0.291086  1.096598
# ...         ...       ...       ...       ...       ...       ...       ...
# 28333 -2.584733  1.885605  1.570128 -1.734949 -1.357308  0.491948  2.246891
# 28334 -1.496957  0.868863  2.333445 -1.072088 -3.228289 -1.062316 -2.665640
# 28335  2.177528 -2.221092 -1.406214 -0.459722 -0.003915 -1.997506 -1.610139
# 28336  0.009766 -1.150632 -0.130172 -3.664297 -1.179268 -2.208973 -1.929785
# 28337  0.486057 -0.494190 -0.397723 -1.808961  0.741553 -0.260887 -0.018085
#
#               7         8         9  ...        89        90        91  \
# 0     -1.866985 -0.197934 -0.152909  ... -0.836662 -0.961576 -0.927438
# 1     -1.252805 -1.329372 -0.210637  ...  0.193886  0.772260  0.155478
# 2     -1.814294 -0.562034  1.811179  ... -0.562499  0.343086 -1.132334
# 3     -0.442009 -0.170598  0.723008  ... -0.179151  0.031750  0.303946
# 4      0.201749 -0.777236 -0.683485  ...  1.072669 -0.538583  1.417212
# ...         ...       ...       ...  ...       ...       ...       ...
# 28333  0.580095 -1.376365 -2.088816  ...  0.852970 -0.080570 -0.286510
# 28334  1.225740  0.737425 -2.230101  ... -1.184740 -0.789198  0.304572
# 28335 -1.635593  2.207399  1.349981  ... -0.592503 -0.092522 -0.559201
# 28336 -1.522628  0.700594 -0.623779  ... -0.614030 -0.402437 -0.837617
# 28337 -2.258924  1.216704  0.297795  ...  0.475355  0.124190 -1.064504
#
#              92        93        94        95         CDR3_Beta    V_Beta  \
# 0      0.200496 -0.808862  0.169232  0.557335     CASSQDGDSDYTF     TRBV5
# 1     -0.170235  0.015353  0.482350  1.344745  CTCSADPGVNQDTQYF     TRBV1
# 2      0.214602 -0.558522  0.124542  0.402762        CASGEDTQYF  TRBV12-2
# 3      0.147918 -0.356394  0.849468  0.330684   CASGETGGNYAEQFF  TRBV12-2
# 4      0.393328  0.080456  0.672388 -1.170654   CASSPDRDPGNTLYF    TRBV19
# ...         ...       ...       ...       ...               ...       ...
# 28333 -0.348826 -0.213772 -0.345129 -0.241531   CASSLAGFNQDTQYF    TRBV16
# 28334 -0.895250  1.044052  0.143376  0.110983    CASSLAGEVYEQYF    TRBV14
# 28335  0.417333 -0.335641  0.455898  0.133016       CASSLAGEVFF    TRBV15
# 28336  0.526591 -0.735353  0.712252  0.707593    CASSLAGEGDTQYF    TRBV15
# 28337  1.240337 -0.998003  0.375548  0.246021        CVVRKDTQYF    TRBV29
#
#         J_Beta
# 0      TRBJ1-2
# 1      TRBJ2-5
# 2      TRBJ2-5
# 3      TRBJ2-1
# 4      TRBJ1-3
# ...        ...
# 28333  TRBJ2-5
# 28334  TRBJ2-7
# 28335  TRBJ1-1
# 28336  TRBJ2-5
# 28337  TRBJ2-5
#
# [28338 rows x 99 columns]

# %%
features_test.to_csv("DTCRU_features_all_sub.csv", index=False)

# %% [markdown]
# ### comparison

# %%
keys = ['CDR3_Beta', 'V_Beta', 'J_Beta']  # replace with your three columns

out = features_df.merge(
    features_test,
    on=keys,                 # all three must match
    how='inner',             # only intersections
    suffixes=('_df1', '_df2'),
    validate='many_to_many'  # or 'one_to_one' / 'one_to_many' as appropriate
)

out = out.reindex(sorted(out.columns), axis=1)
out
# Out:
#           0_df1     0_df2    10_df1    10_df2    11_df1    11_df2    12_df1  \
# 0      1.927215  1.927736  1.843885  1.843499 -1.276194 -1.276251 -0.994876
# 1      1.239994  1.240850 -1.166020 -1.166334  1.790808  1.789923 -1.150646
# 2      0.647911  0.648429 -1.059300 -1.059575 -0.216499 -0.216338  0.808184
# 3      0.882616  0.883649 -2.345308 -2.346045  0.643742  0.643332 -1.867817
# 4     -2.617388 -2.617029 -0.246022 -0.245655  1.977145  1.976990  0.096618
# ...         ...       ...       ...       ...       ...       ...       ...
# 27193 -1.285489 -1.284808  0.690959  0.691834  2.780107  2.779326 -1.027416
# 27194 -1.274166 -1.273468 -0.760201 -0.760024 -0.060627 -0.060469  0.420193
# 27195 -0.174187 -0.173536 -0.590455 -0.590459  1.217303  1.217304  0.168122
# 27196 -0.086368 -0.085625 -1.022660 -1.022859  1.159395  1.160106 -0.537833
# 27197  0.485801  0.486057  1.539264  1.539245 -1.748011 -1.747856  1.815730
#
#          12_df2    13_df1    13_df2  ...    94_df1    94_df2    95_df1  \
# 0     -0.995766 -2.818777 -2.818895  ...  0.170265  0.169232  0.556819
# 1     -1.151046  0.295712  0.295318  ...  0.482545  0.482350  1.344052
# 2      0.807519 -2.404762 -2.404939  ...  0.125088  0.124542  0.402434
# 3     -1.868448 -0.258343 -0.258979  ...  0.849508  0.849468  0.329896
# 4      0.096505  1.582911  1.582093  ...  0.673055  0.672388 -1.171613
# ...         ...       ...       ...  ...       ...       ...       ...
# 27193 -1.028163 -0.148013 -0.148140  ...  0.502688  0.502264 -1.368599
# 27194  0.419569  1.979386  1.978673  ...  0.507515  0.507078 -0.811315
# 27195  0.168101 -0.210748 -0.211216  ...  0.296187  0.296162 -0.228699
# 27196 -0.537815  1.326274  1.325671  ...  0.438089  0.437847 -0.174970
# 27197  1.815210 -1.657211 -1.657525  ...  0.376191  0.375548  0.245344
#
#          95_df2     9_df1     9_df2          CDR3_Beta   J_Beta  \
# 0      0.557335 -0.153665 -0.152909      CASSQDGDSDYTF  TRBJ1-2
# 1      1.344745 -0.211016 -0.210637   CTCSADPGVNQDTQYF  TRBJ2-5
# 2      0.402762  1.811019  1.811179         CASGEDTQYF  TRBJ2-5
# 3      0.330684  0.721999  0.723008    CASGETGGNYAEQFF  TRBJ2-1
# 4     -1.170654 -0.684722 -0.683485    CASSPDRDPGNTLYF  TRBJ1-3
# ...         ...       ...       ...                ...      ...
# 27193 -1.367601 -0.543837 -0.543099   CASSIRLGGRAETLYF  TRBJ2-3
# 27194 -0.810999  0.652925  0.653961   CASSIRLGGSQNTLYF  TRBJ2-4
# 27195 -0.228163  0.611859  0.612814   CASSIRLGGVQDTQYF  TRBJ2-5
# 27196 -0.174705  0.628637  0.629135  CASSIRLGGYNYAEQFF  TRBJ2-1
# 27197  0.246021  0.296830  0.297795         CVVRKDTQYF  TRBJ2-5
#
#                    Label    V_Beta
# 0      all\airr_test.tsv     TRBV5
# 1      all\airr_test.tsv     TRBV1
# 2      all\airr_test.tsv  TRBV12-2
# 3      all\airr_test.tsv  TRBV12-2
# 4      all\airr_test.tsv    TRBV19
# ...                  ...       ...
# 27193  all\airr_test.tsv    TRBV19
# 27194  all\airr_test.tsv    TRBV19
# 27195  all\airr_test.tsv    TRBV19
# 27196  all\airr_test.tsv    TRBV19
# 27197  all\airr_test.tsv    TRBV29
#
# [27198 rows x 196 columns]

# %% [markdown]
# # Saved embs

# %%
aa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 aa
#
# NameError: name 'aa' is not defined

# %%
# # Reduce clusters by lowering PhenoGraph resolution (t)
# DTCRU.Cluster(
#     clustering_method='phenograph',  # Keep PhenoGraph clustering
#     t=5,                     # Lower resolution (default ~30); reduce for fewer clusters
#     n_jobs=4                 # Use multiple threads for efficiency
# )
DTCRU.Cluster(
    set='all', 
    clustering_method='dbscan',  # Use DBSCAN
    t=6,  # Higher values merge clusters (default is auto-tuned)
    n_jobs=4
)

# %%
DFs = DTCRU.Cluster_DFs
len(DFs)

# %%
print(DFs[2])

# %%
# import matplotlib.pyplot as plt

# # Initialize lists to store cluster indices and weighted CNS proportions
# cluster_ids = []
# cns_proportions = []

# # Iterate through clusters and compute weighted CNS proportions
# for i, df in enumerate(DFs):
#     total_freq = df["Frequency"].sum()  # Sum of frequencies in cluster
#     cns_freq = df.loc[df["Labels"] == "CNS", "Frequency"].sum()  # Sum of CNS frequencies
    
#     # Avoid division by zero
#     cns_ratio = cns_freq #/ total_freq if total_freq > 0 else 0
    
#     cluster_ids.append(i + 1)  # Cluster numbers start from 1
#     cns_proportions.append(cns_ratio)

# # Plot CNS proportion per cluster
# plt.figure(figsize=(12, 6))
# plt.bar(cluster_ids, cns_proportions, color="dodgerblue")

# plt.xlabel("Cluster")
# plt.ylabel("CNS Proportion (Weighted by Frequency)")
# plt.title("Weighted Proportion of CNS Sequences in Each Cluster")
# #plt.ylim(0, 1)  # Set proportion range between 0 and 1
# plt.xticks(rotation=90)  # Rotate x-axis labels if needed
# plt.show()
# import matplotlib.pyplot as plt

# # Initialize lists to store cluster indices and weighted CNS proportions
# cluster_ids = []
# cns_proportions = []

# # Iterate through clusters and compute weighted CNS proportions
# for i, df in enumerate(DFs):
#     total_freq = df["Frequency"].sum()  # Sum of frequencies in cluster
#     cns_freq = df.loc[df["Labels"] == "Spleen", "Frequency"].sum()  # Sum of CNS frequencies
    
#     # Avoid division by zero
#     cns_ratio = cns_freq #/ total_freq if total_freq > 0 else 0
    
#     cluster_ids.append(i + 1)  # Cluster numbers start from 1
#     cns_proportions.append(cns_ratio)

# # Plot CNS proportion per cluster
# plt.figure(figsize=(12, 6))
# plt.bar(cluster_ids, cns_proportions, color="dodgerblue")

# plt.xlabel("Cluster")
# plt.ylabel("Spleen Proportion (Weighted by Frequency)")
# plt.title("Weighted Proportion of CNS Sequences in Each Cluster")
# #plt.ylim(0, 1)  # Set proportion range between 0 and 1
# plt.xticks(rotation=90)  # Rotate x-axis labels if needed
# plt.show()

# %%
DTCRU.HeatMap_Sequences()

# %%
DTCRU.Structural_Diversity()

# %%
DTCRU.Structural_Diversity_DF

# %%
# Extract normalized frequency and sample IDs from DeepTCR
import numpy as np

normalized_freq = np.array(DTCRU.freq)  # Already normalized per sample
sample_ids = np.array(DTCRU.sample_id)

# Count the number of sequences in CNS and Spleen
num_cns = np.sum(sample_ids == "CNS.tsv")
num_spleen = np.sum(sample_ids == "Spleen.tsv")

# Compute rescaling factor: adjust Spleen frequencies to match CNS scale
scale_factor = num_spleen / num_cns

# Rescale the Spleen frequencies only
adjusted_freq = np.where(sample_ids == "Spleen.tsv", normalized_freq * scale_factor, normalized_freq)
DTCRU.freq = adjusted_freq

# %%
DTCRU.freq

# %%
scale_factor

# %%
num_cns

# %%
num_spleen

# %%
DTCRU.freq

# %%
DTCRU.UMAP_Plot(Load_Prev_Data=True,by_sample=True, show_legend=True,freq_weight=True,scale=10000) #by_cluster=True,by_cluster=True,freq_weight=True

# %%
DTCRU.UMAP_Plot(Load_Prev_Data=True,by_cluster=True, show_legend=False,freq_weight=True,scale=5000)

# %% [markdown]
# ### Comparison between GIANA embeddings and DeepTCR embeddings

# %%
import pandas as pd

# %%
DTCRU_features_df = pd.read_csv(r"E:\Python code\Machine learning\JupyterNote\Bio\deepTCR\DTCRU_extracted_features_96.csv")

# %%
DTCRU_features_df

# %%
# File paths
embedding_path = r"E:\Python code\Machine learning\JupyterNote\Bio\GIANA\LEE_data\cdr3_only\cdr3_id--RotationEncodingBL62_EncodingMatrix_CFadded.txt"

# Load GIANA embeddings
GIANA_features_df = pd.read_csv(embedding_path, sep="\t", header=None)
GIANA_features_df = GIANA_features_df.iloc[:,1:]
GIANA_features_df = GIANA_features_df.drop(columns=GIANA_features_df.columns[1])
GIANA_features_df = GIANA_features_df.rename(columns={1: 0})
GIANA_features_df

# %%
# for i in range(len(GIANA_features_df)):
#     GIANA_features_df.iloc[i,0] = "C" + GIANA_features_df.iloc[i,0] + "F"

# GIANA_features_df.to_csv('cdr3_id--RotationEncodingBL62_EncodingMatrix_CFadded.csv', header = None, sep="\t")

# %%
import numpy as np
DTCRU_features_df = DTCRU_features_df.iloc[:, np.r_[0, 4:DTCRU_features_df.shape[1]]]
# GIANA_features_df = GIANA_features_df.iloc[:, np.r_[0, 2:GIANA_features_df.shape[1]]]

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import pdist, squareform

# Step 1: Ensure unique CDR3_Beta sequences by averaging embeddings if duplicated
DTCRU_unique = DTCRU_features_df.groupby("CDR3_Beta").mean().reset_index()
GIANA_unique = GIANA_features_df.groupby(0).mean().reset_index()  # Column 0 contains CDR3_Beta in GIANA

# Step 2: Find the common CDR3 sequences among all three datasets
common_cdr3 = set(DTCRU_unique["CDR3_Beta"]).intersection(GIANA_unique[0])

# Step 3: Keep only common sequences and sort them
DTCRU_matched = DTCRU_unique[DTCRU_unique["CDR3_Beta"].isin(common_cdr3)].sort_values("CDR3_Beta").reset_index(drop=True)
GIANA_matched = GIANA_unique[GIANA_unique[0].isin(common_cdr3)].sort_values(by=0).reset_index(drop=True)

# Step 4: Extract embeddings
DTCRU_embeddings = DTCRU_matched.iloc[:, 1:].values  # Exclude CDR3_Beta (first column)
GIANA_embeddings = GIANA_matched.iloc[:, 1:].values  # Exclude CDR3_Beta (first column)

# Step 5: Compute pairwise distances within each embedding space
DTCRU_distances = squareform(pdist(DTCRU_embeddings, metric="euclidean"))
GIANA_distances = squareform(pdist(GIANA_embeddings, metric="euclidean"))

# Step 6: Flatten upper triangle of the distance matrices for correlation analysis
DTCRU_distances_flat = DTCRU_distances[np.triu_indices_from(DTCRU_distances, k=1)]
GIANA_distances_flat = GIANA_distances[np.triu_indices_from(GIANA_distances, k=1)]

# %%
import numpy as np
from scipy.stats import spearmanr

# Randomly subsample 100,000 pairs for faster correlation
sample_size = min(100000, len(DTCRU_distances_flat))  # Adjust sample size if needed
indices = np.random.choice(len(DTCRU_distances_flat), size=sample_size, replace=False)

# Compute Spearman on subsampled data
spearman_DG, p_DG = spearmanr(DTCRU_distances_flat[indices], GIANA_distances_flat[indices])

results = pd.DataFrame({
    "Comparison": ["DTCRU vs GIANA"],
    "Spearman Correlation": [spearman_DG],
    "p-value": [p_DG]
})
results

# %%
DTCRU_features_df.shape

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score, homogeneity_completeness_v_measure
import pandas as pd

# Perform K-Means clustering for all three datasets
DTCRU_clusters = KMeans(n_clusters=10, random_state=1, n_init=10).fit_predict(DTCRU_embeddings)
GIANA_clusters = KMeans(n_clusters=10, random_state=1, n_init=10).fit_predict(GIANA_embeddings)

# Compute clustering similarity scores for all pairs
ari_DG = adjusted_rand_score(DTCRU_clusters, GIANA_clusters)  # DTCRU vs GIANA

nmi_DG = normalized_mutual_info_score(DTCRU_clusters, GIANA_clusters)

hom_DG, comp_DG, v_DG = homogeneity_completeness_v_measure(DTCRU_clusters, GIANA_clusters)

# Organize results in a DataFrame
clustering_results = pd.DataFrame({
    "Comparison": ["DTCRU vs GIANA"],
    "ARI": [ari_DG],
    "NMI": [nmi_DG],
    "Homogeneity": [hom_DG],
    "Completeness": [comp_DG],
    "V-Measure": [v_DG]
})

clustering_results

# %%
import umap
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Reduce dimensionality using only GIANA embeddings
umap_giana = umap.UMAP(n_components=2).fit_transform(GIANA_embeddings)

# Create dataframe for UMAP representation
df_umap = pd.DataFrame(umap_giana, columns=["UMAP1", "UMAP2"])
df_umap["DTCRU_Cluster"] = pd.Categorical(DTCRU_clusters)  # DTCRU clusters
df_umap["GIANA_Cluster"] = pd.Categorical(GIANA_clusters)  # GIANA clusters

# Set up a 3x1 subplot (3 plots)
fig, axes = plt.subplots(2, 1, figsize=(6, 15))
titles = ["DTCRU Clusters (UMAP GIANA)", "GIANA Clusters (UMAP GIANA)"]

# Define color palettes
dtcru_palette = sns.color_palette("tab10", len(df_umap["DTCRU_Cluster"].unique()))
giana_palette = sns.color_palette("tab10", len(df_umap["GIANA_Cluster"].unique()))

# Plot 1: DTCRU Clusters using GIANA UMAP
sns.scatterplot(data=df_umap, x="UMAP1", y="UMAP2", hue="DTCRU_Cluster", palette=dtcru_palette, alpha=0.6, s=5, ax=axes[0])
axes[0].set_title(titles[0])
axes[0].legend_.remove()

# Plot 2: GIANA Clusters using GIANA UMAP
sns.scatterplot(data=df_umap, x="UMAP1", y="UMAP2", hue="GIANA_Cluster", palette=giana_palette, alpha=0.6, s=5, ax=axes[1])
axes[1].set_title(titles[1])
axes[1].legend_.remove()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create pairwise contingency tables
contingency_DG = pd.crosstab(DTCRU_clusters, GIANA_clusters)

# Function to plot heatmap
def plot_heatmap(contingency_table, xlabel, ylabel, title):
    plt.figure(figsize=(6, 5))
    sns.heatmap(contingency_table, annot=True, fmt="d", cmap="Blues", linewidths=0.5)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# Plot each heatmap
plot_heatmap(contingency_DG, "GIANA Clusters", "DeepTCR Clusters", "DeepTCR vs GIANA Clusters")
