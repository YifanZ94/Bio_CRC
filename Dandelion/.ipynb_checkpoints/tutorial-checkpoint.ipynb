# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
import scanpy as sc
import igraph
import scvelo as scv
import loompy as lmp
import anndata
import muon as mu

import warnings
import warnings

warnings.filterwarnings(
    "ignore",
    category=DeprecationWarning,
    module=r"scvelo\.plotting\.utils"
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as pl
# ----> 4 import scanpy as sc
#       5 import igraph
#       6 import scvelo as scv
#
# File ~/.conda/envs/TCR_custom/lib/python3.11/site-packages/scanpy/__init__.py:9
#       5 import sys
#       7 from packaging.version import Version
# ----> 9 from ._utils import check_versions
#      10 from ._version import __version__
#      12 check_versions()
#
# File ~/.conda/envs/TCR_custom/lib/python3.11/site-packages/scanpy/_utils/__init__.py:35
#      33 import h5py
#      34 import numpy as np
# ---> 35 from anndata import __version__ as anndata_version
#      36 from packaging.version import Version
#      37 from scipy import sparse
#
# File ~/.conda/envs/TCR_custom/lib/python3.11/site-packages/anndata/__init__.py:29
# ...

# %%
import dandelion as ddl

ddl.logging.print_versions()
